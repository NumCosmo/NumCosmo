# %%
#!/usr/bin/env python

try:
    import gi
    gi.require_version('NumCosmo', '1.0')
    gi.require_version('NumCosmoMath', '1.0')
except:
    pass

import math
import matplotlib.pyplot as plt
from gi.repository import GObject
from gi.repository import NumCosmo as Nc
from gi.repository import NumCosmoMath as Ncm
import numpy as np
import sys
sys.path.insert(0,'../../scripts')

import pyccl as ccl
from nc_ccl import create_nc_obj, ccl_cosmo_set_high_prec

Ncm.cfg_init()
Ncm.cfg_set_log_handler (lambda msg: sys.stdout.write (msg) and sys.stdout.flush ())

import numpy as np
import matplotlib.pyplot as plt
import pickle as pkl
import scipy.integrate
import astropy.units as u
import GCRCatalogs
import pandas as pd

# %matplotlib inline
catalog = 'skysim5000_v1.1.1'
skysim_cat = GCRCatalogs.load_catalog(catalog)
cosmo_ss  = skysim_cat.cosmology
# Out:
# WARNING: version mismatch between CFITSIO header (v4) and linked library (v3.47).
#
#
# WARNING: version mismatch between CFITSIO header (v4) and linked library (v3.47).
#
#
# WARNING: version mismatch between CFITSIO header (v4) and linked library (v3.47).

# %%
cosmo = Nc.HICosmoDEXcdm()
reion = Nc.HIReionCamb.new () 
prim = Nc.HIPrimPowerLaw.new () 

cosmo.add_submodel (reion)
cosmo.add_submodel (prim)

dist = Nc.Distance.new (2.0)

tf = Nc.TransferFunc.new_from_name ("NcTransferFuncEH")

psml = Nc.PowspecMLTransfer.new (tf)

#psml = Nc.PowspecMLCBE.new ()
psml.require_kmin (1.0e-6)
psml.require_kmax (1.0e3)

psf = Ncm.PowspecFilter.new (psml, Ncm.PowspecFilterType.TOPHAT)
psf.set_best_lnr0 ()


cosmo.props.H0      = cosmo_ss.H0.value
cosmo.props.Omegab  = cosmo_ss.Ob0
cosmo.props.Omegac  = cosmo_ss.Odm0
cosmo.props.Omegax  = cosmo_ss.Ode0

cosmo.omega_x2omega_k ()
cosmo.param_set_by_name ("Omegak", 0.0)

prim.props.n_SA = cosmo_ss.n_s
print(cosmo_ss.sigma8,cosmo.sigma8(psf),cosmo.Omega_k0())

old_amplitude = math.exp (prim.props.ln10e10ASA)
prim.props.ln10e10ASA = math.log ((cosmo_ss.sigma8 / cosmo.sigma8(psf))**2 * old_amplitude)
print(cosmo_ss.sigma8, cosmo.sigma8(psf))
# Out:
# 0.8 0.8490796381180891 0.0
# 0.8 0.8

# %%
#CosmoSim_proxy model
#M_0, z_0
theta_pivot = [3e14/0.71, 0.6]
#\mu_0, a_\mu^z, a_\mu^M
theta_mu = [3.19, -0.7, 2]
#\sigma_0, a_\sigma^z, a_\sigma^M
theta_sigma = [0.33, 0.,-0.08]
#Richness object

area = 439.78987
lnRl = 0.0
lnRu = 2.0
zl = 0.0
zu = 1.0

#Numcosmo_proxy model
cluster_z = Nc.ClusterRedshift.new_from_name("NcClusterRedshiftNodist{'z-min': <%20.15e>, 'z-max':<%20.15e>}" % (zl, zu))
'''
cluster_m = Nc.ClusterMass.new_from_name("NcClusterMassAscaso{'M0':<%20.15e>,'z0':<%20.15e>,'lnRichness-min':<%20.15e>, 'lnRichness-max':<%20.15e>}" % (3e14/(0.71),0.6, lnRl, lnRu))
cluster_m.param_set_by_name('mup0', 3.19)
cluster_m.param_set_by_name('mup1', 2/np.log(10))
cluster_m.param_set_by_name('mup2', -0.7/np.log(10))
cluster_m.param_set_by_name('sigmap0', 0.33)
cluster_m.param_set_by_name('sigmap1', -0.08/np.log(10))
cluster_m.param_set_by_name('sigmap2', 0/np.log(10))
'''
#Nodist
cluster_m = Nc.ClusterMass.new_from_name("NcClusterMassNodist{'lnM-min':<%20.15e>, 'lnM-max':<%20.15e>}" % (math.log(10)*np.log10(1e13),math.log(10)*np.log10(1e15)))

# %%
#Numcosmo Cluster Abundance

#First we need to define the multiplicity function here we will use the tinker
mulf = Nc.MultiplicityFuncTinker.new()
mulf.set_linear_interp (True)
mulf.set_mdef(Nc.MultiplicityFuncMassDef.CRITICAL)
mulf.set_Delta(200)
#Second we need to construct a filtered power spectrum 

hmf = Nc.HaloMassFunction.new(dist,psf,mulf)
hmf.set_area_sd(area)

ca = Nc.ClusterAbundance.new(hmf,None)
mset = Ncm.MSet.new_array([cosmo,cluster_m,cluster_z])

# %%
#With proxy

#ncount = Nc.DataClusterNCount.new (ca, "NcClusterRedshiftNodist", "NcClusterMassAscaso")
#ncount.catalog_load ("ncount_ascaso2.fits")

#True table

ncount = Nc.DataClusterNCount.new (ca, "NcClusterRedshiftNodist", "NcClusterMassNodist")
ncount.catalog_load ("ncount_nodist.fits")

# %%
cosmo.props.Omegac_fit = True
prim.props.ln10e10ASA_fit = True
#cluster_m.props.mup0_fit = True
mset.prepare_fparam_map ()

# %%
ncount.set_binned (False)

# %%
dset = Ncm.Dataset.new ()
dset.append_data (ncount)

# %%
lh = Ncm.Likelihood (dataset = dset)
fit = Ncm.Fit.new (Ncm.FitType.NLOPT, "ln-neldermead", lh, mset, Ncm.FitGradType.NUMDIFF_FORWARD)
fit.log_info ()
# Out:
# #----------------------------------------------------------------------------------
# # Data used:
# #   - Cluster abundance unbinned
# #----------------------------------------------------------------------------------
# # Model[03000]:
# #   - NcHICosmo : XCDM - Constant EOS
# #----------------------------------------------------------------------------------
# # Model parameters
# #   -         H0[00]:  71                  [FIXED]
# #   -     Omegac[01]:  0.22                [FREE]
# #   -     Omegak[02]:  0                   [FIXED]
# #   -    Tgamma0[03]:  2.7245              [FIXED]
# #   -         Yp[04]:  0.24                [FIXED]
# #   -       ENnu[05]:  3.046               [FIXED]
# #   -     Omegab[06]:  0.0448              [FIXED]
# #   -          w[07]: -1                   [FIXED]
# #----------------------------------------------------------------------------------
# # Model[05000]:
# #   - NcHIPrim : Power Law model for primordial spectra
# #----------------------------------------------------------------------------------
# # Model parameters
# #   - ln10e10ASA[00]:  3.05991748699301    [FREE]
# #   - T_SA_ratio[01]:  0.2                 [FIXED]
# #   -       n_SA[02]:  0.963               [FIXED]
# #   -        n_T[03]:  0                   [FIXED]
# #----------------------------------------------------------------------------------
# # Model[07000]:
# #   - NcClusterMass : No mass distribution
# #----------------------------------------------------------------------------------
# # Model parameters
# #----------------------------------------------------------------------------------
# # Model[08000]:
# #   - NcClusterRedshift : No redshift distribution
# #----------------------------------------------------------------------------------
# # Model parameters
# #----------------------------------------------------------------------------------
# # Model[13000]:
# #   - NcHIReion : Reion-CAMB
# #----------------------------------------------------------------------------------
# # Model parameters
# #   -       z_re[00]:  13                  [FIXED]
# #   -    z_He_re[01]:  3.5                 [FIXED]

# %%
#
# Setting single thread calculation.
#
Ncm.func_eval_set_max_threads (150)
Ncm.func_eval_log_pool_stats ()

#
# Additional functions as we want the chains for sigma8 and Omegam, which are derived parameters
#
mfunc_oa = Ncm.ObjArray.new ()

mfunc_Omegam = Ncm.MSetFuncList.new ("NcHICosmo:Omega_m0", None)
mfunc_sigma8 = Ncm.MSetFuncList.new ("NcHICosmo:sigma8", psf)


mfunc_oa.add (mfunc_sigma8)
mfunc_oa.add (mfunc_Omegam)

print (mfunc_sigma8.eval0 (mset))
print (mfunc_Omegam.eval0 (mset))

#
# New Gaussian prior to provide the initial points for the chain.
# It was created with size 0 (number of parameters), but once 
# initialized with mset the correct size is assigned. 
#
# The initial sampler will use a diagonal covariance with the
# diagonal terms being the parameters scale set by each model.
#
init_sampler = Ncm.MSetTransKernGauss.new (0)
init_sampler.set_mset (mset)
init_sampler.set_prior_from_mset ()
init_sampler.set_cov_from_rescale (1.0) #1

#
# Creates the ESMCMC walker object, this object is responsible
# for moving the walkers in each interation, the stretch move
# is affine invariant and therefore gives good results even for
# very correlated parametric space.
# 
sampler = 'apes'
#sampler  = 'stretch'
nwalkers = int (math.ceil (500)) #500
ssize    = 15000 #1000000

if sampler == 'apes':
  walker = Ncm.FitESMCMCWalkerAPES.new (nwalkers, mset.fparams_len ())
elif sampler == "stretch":
  walker = Ncm.FitESMCMCWalkerStretch.new (nwalkers, mset.fparams_len ())
#
# The methods below set the walk scale, which controls the size of the
# step done between two walkers and circumscribe the walkers inside
# the box defined by the parameters inside the mset object.
#
#walker.set_scale (3.0)
#walker.set_box_mset (mset)
#
# Initialize the ESMCMC object using the objects above. It will
# use 50 walkers, i.e., each point in the MCMC chain contains
# 50 points in the parametric space. Each step uses the last point
# in the chain (the last 50 parametric points) to calculate the
# proposal points.
#
esmcmc  = Ncm.FitESMCMC.new_funcs_array (fit, nwalkers, init_sampler, walker, Ncm.FitRunMsgs.SIMPLE, mfunc_oa)

#
# These methods enable the auto-trim options on ESMCMC. This option 
# makes the sampler check the chains' health and trim any unnecessary 
# burn-in part. We set the number of divisions to 100 so we test the
# chains in blocks of n/100. The last method asserts that each 2min
# the catalog will be checked.
#
#esmcmc.set_auto_trim (True)
#esmcmc.set_auto_trim_div (100)
#esmcmc.set_max_runs_time (2.0 * 60.0)
#esmcmc.set_nthreads (4)

#With self calibration
#esmcmc.set_data_file ("mcmc_ascaso_unbinned.fits")
#without self calibration
#esmcmc.set_data_file ("mcmc_ascaso_unbinned_noself.fits")
esmcmc.set_data_file ("mcmc_nodist_unbinned.fits")

esmcmc.set_nthreads (150)

#
# Running the esmcmc, it will first calculate 1000 points, after that
# it will estimate the error in the parameters mean. Using the current
# errors the algorithm tries to calculated how many extra steps are 
# necessary to obtain the required error `10^-3' in every parameters,
# and it will run such extra steps. It will repeat this procedure
# until it attains the required error in every parameter.
# 
#

esmcmc.start_run ()
#esmcmc.run (ssize / nwalkers)
#esmcmc.run (10)
esmcmc.run_lre (50, 1.0e-3)
esmcmc.end_run ()

#
# Calculates the parameter means and covariance and set it into 
# the fit object and then print.
# 
esmcmc.mean_covar ()
fit.log_covar ()
# Out:
# # NcmThreadPool:Unused:      0
# # NcmThreadPool:Max Unused:  2
# # NcmThreadPool:Running:     0
# # NcmThreadPool:Unprocessed: 0
# # NcmThreadPool:Unused:      150
# 0.8
# 0.2648
# #----------------------------------------------------------------------------------
# # NcmFitESMCMC: Starting Ensamble Sampler Markov Chain Monte Carlo.
# #   Number of walkers: 0500.
# #   Number of threads: 0150.
# #   Using MPI:         no - use MPI enabled but no slaves available.
# # NcmFitESMCMC: No RNG was defined, using algorithm: `mt19937' and seed: 2389498340.
# # NcmMSetCatalog: Current mean:   2.094e+07    0.93257      0.26447      0.21967      3.2381
# # NcmMSetCatalog: Current msd:    0            0.015942     0.00043119   0.00043119   0.032073
# # NcmMSetCatalog: Current sd:     0            0.35647      0.0096416    0.0096416    0.71717
# # NcmMSetCatalog: Current var:    0            0.12707      9.2961e-05   9.2961e-05   0.51433
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac: -nan         -nan         -nan         -nan         -nan
# # NcmMSetCatalog: Maximal Shrink factor = 1e+10
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `1':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:last ensemble variance of -2ln(L):                      0 (2n = 4), min(-2ln(L)) =       20940271.4803748.
# # Task:NcmFitESMCMC, completed: 500 of 500, elapsed time: 00:01:25.3987
# # Task:NcmFitESMCMC, mean time: 00:00:00.1707 +/- 00:00:00.1707
# # Task:NcmFitESMCMC, time left: 00:00:00.0000 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, current time:        Wed Oct 26 2022, 15:10:00
# # Task:NcmFitESMCMC, estimated to end at: Wed Oct 26 2022, 15:10:00 +/- 00:00:00.0000
# # NcmFitESMCMC: Running first 49 pre-runs...
# #----------------------------------------------------------------------------------
# # NcmFitESMCMC: Calculating [000049] Ensemble Sampler Markov Chain Monte Carlo runs [APES-Move:VKDE:Cauchy]
# # Task:NcmFitESMCMC, started at: Wed Oct 26 2022, 15:08:34
# # NcmMSetCatalog: Current mean:   2.094e+07    1.3295       0.42644      0.38164      3.453
# # NcmMSetCatalog: Current msd:    0            0.014406     0.0043786    0.0043786    0.015408
# # NcmMSetCatalog: Current sd:     0            0.78904      0.23983      0.23983      0.84395
# # NcmMSetCatalog: Current var:    0            0.62258      0.057516     0.057516     0.71226
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac: -nan          1.0077       0.97923      0.97923      1.0065
# # NcmMSetCatalog: Maximal Shrink factor = 1.00818
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `6':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 99.0800% (last update 99.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):                      0 (2n = 4), min(-2ln(L)) =       20940271.4803748.
# # Task:NcmFitESMCMC, completed: 3000 of 25000, elapsed time: 00:02:25.9965
# # Task:NcmFitESMCMC, mean time: 00:00:00.0487 +/- 00:00:00.0298
# # Task:NcmFitESMCMC, time left: 00:17:50.3918 +/- 00:10:56.6682
# # Task:NcmFitESMCMC, current time:        Wed Oct 26 2022, 15:11:00
# # Task:NcmFitESMCMC, estimated to end at: Wed Oct 26 2022, 15:28:51 +/- 00:10:56.6682
# # NcmMSetCatalog: Current mean:   2.094e+07    1.3769       0.44815      0.40335      3.4676
# # NcmMSetCatalog: Current msd:    0            0.012287     0.0036999    0.0036999    0.012738
# # NcmMSetCatalog: Current sd:     0            0.82425      0.2482       0.2482       0.85448
# # NcmMSetCatalog: Current var:    0            0.67939      0.061603     0.061603     0.73013
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac: -nan          1.0016       0.98828      0.98828      1.0019
# # NcmMSetCatalog: Maximal Shrink factor = 1.00224
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `9':
# # NcmMSetCatalog: Constant break point at `8':
# # NcmFitESMCMC:acceptance ratio 99.1250% (last update 99.4000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):                      0 (2n = 4), min(-2ln(L)) =       20940271.4803748.
# # Task:NcmFitESMCMC, completed: 4500 of 25000, elapsed time: 00:02:59.5754
# # Task:NcmFitESMCMC, mean time: 00:00:00.0399 +/- 00:00:00.0204
# # Task:NcmFitESMCMC, time left: 00:13:37.8828 +/- 00:06:57.4121
# # Task:NcmFitESMCMC, current time:        Wed Oct 26 2022, 15:11:34
# # Task:NcmFitESMCMC, estimated to end at: Wed Oct 26 2022, 15:25:12 +/- 00:06:57.4121
# # NcmMSetCatalog: Current mean:   2.094e+07    1.4247       0.46896      0.42416      3.4862
# # NcmMSetCatalog: Current msd:    0            0.0097722    0.002925     0.002925     0.0098984
# # NcmMSetCatalog: Current sd:     0            0.84629      0.25332      0.25332      0.85723
# # NcmMSetCatalog: Current var:    0            0.71622      0.064169     0.064169     0.73484
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac: -nan          0.99769      0.9967       0.9967       0.99629
# # NcmMSetCatalog: Maximal Shrink factor = 0.996787
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `15':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 99.2857% (last update 99.6000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):                      0 (2n = 4), min(-2ln(L)) =       20940271.4803748.
# # Task:NcmFitESMCMC, completed: 7500 of 25000, elapsed time: 00:04:05.5272
# # Task:NcmFitESMCMC, mean time: 00:00:00.0327 +/- 00:00:00.0127
# # Task:NcmFitESMCMC, time left: 00:09:32.7549 +/- 00:03:42.8331
# # Task:NcmFitESMCMC, current time:        Wed Oct 26 2022, 15:12:40
# # Task:NcmFitESMCMC, estimated to end at: Wed Oct 26 2022, 15:22:12 +/- 00:03:42.8331
# # NcmMSetCatalog: Current mean:   2.094e+07    1.438        0.47443      0.42963      3.4917
# # NcmMSetCatalog: Current msd:    0            0.0089696    0.0026795    0.0026795    0.00903
# # NcmMSetCatalog: Current sd:     0            0.85093      0.2542       0.2542       0.85666
# # NcmMSetCatalog: Current var:    0            0.72409      0.064615     0.064615     0.73386
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac: -nan          0.99799      0.99852      0.99852      0.99726
# # NcmMSetCatalog: Maximal Shrink factor = 0.998526
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `18':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 99.2353% (last update 99.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):                      0 (2n = 4), min(-2ln(L)) =       20940271.4803748.
# # Task:NcmFitESMCMC, completed: 9000 of 25000, elapsed time: 00:04:40.6862
# # Task:NcmFitESMCMC, mean time: 00:00:00.0312 +/- 00:00:00.0108
# # Task:NcmFitESMCMC, time left: 00:08:18.9193 +/- 00:02:53.5682
# # Task:NcmFitESMCMC, current time:        Wed Oct 26 2022, 15:13:15
# # Task:NcmFitESMCMC, estimated to end at: Wed Oct 26 2022, 15:21:34 +/- 00:02:53.5682
# # NcmMSetCatalog: Current mean:   2.094e+07    1.4494       0.48052      0.43572      3.4956
# # NcmMSetCatalog: Current msd:    0            0.0078213    0.0023318    0.0023318    0.0078427
# # NcmMSetCatalog: Current sd:     0            0.85678      0.25543      0.25543      0.85912
# # NcmMSetCatalog: Current var:    0            0.73407      0.065245     0.065245     0.73809
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac: -nan          0.99802      1.0002       1.0002       0.99861
# # NcmMSetCatalog: Maximal Shrink factor = 1.00034
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `24':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 99.2261% (last update 99.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):                      0 (2n = 4), min(-2ln(L)) =       20940271.4803748.
# # Task:NcmFitESMCMC, completed: 12000 of 25000, elapsed time: 00:05:47.5733
# # Task:NcmFitESMCMC, mean time: 00:00:00.0290 +/- 00:00:00.0084
# # Task:NcmFitESMCMC, time left: 00:06:16.4975 +/- 00:01:49.8282
# # Task:NcmFitESMCMC, current time:        Wed Oct 26 2022, 15:14:22
# # Task:NcmFitESMCMC, estimated to end at: Wed Oct 26 2022, 15:20:38 +/- 00:01:49.8282
# # NcmMSetCatalog: Current mean:   2.094e+07    1.4512       0.48224      0.43744      3.495
# # NcmMSetCatalog: Current msd:    0            0.0073651    0.0022026    0.0022026    0.0073959
# # NcmMSetCatalog: Current sd:     0            0.85575      0.25591      0.25591      0.85932
# # NcmMSetCatalog: Current var:    0            0.73231      0.065492     0.065492     0.73844
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac: -nan          0.99804      0.99885      0.99885      0.99894
# # NcmMSetCatalog: Maximal Shrink factor = 0.999243
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `27':
# # NcmMSetCatalog: Constant break point at `26':
# # NcmFitESMCMC:acceptance ratio 99.2231% (last update 98.8000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):                      0 (2n = 4), min(-2ln(L)) =       20940271.4803748.
# # Task:NcmFitESMCMC, completed: 13500 of 25000, elapsed time: 00:06:22.9696
# # Task:NcmFitESMCMC, mean time: 00:00:00.0284 +/- 00:00:00.0077
# # Task:NcmFitESMCMC, time left: 00:05:26.2034 +/- 00:01:28.1022
# # Task:NcmFitESMCMC, current time:        Wed Oct 26 2022, 15:14:57
# # Task:NcmFitESMCMC, estimated to end at: Wed Oct 26 2022, 15:20:23 +/- 00:01:28.1022
# # NcmMSetCatalog: Current mean:   2.094e+07    1.4579       0.48514      0.44034      3.4938
# # NcmMSetCatalog: Current msd:    0            0.0066841    0.0019877    0.0019877    0.0067156
# # NcmMSetCatalog: Current sd:     0            0.85858      0.25533      0.25533      0.86264
# # NcmMSetCatalog: Current var:    0            0.73717      0.065192     0.065192     0.74414
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac: -nan          1.0003       1.0008       1.0008       0.99938
# # NcmMSetCatalog: Maximal Shrink factor = 1.00079
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `33':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 99.2625% (last update 99.4000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):                      0 (2n = 4), min(-2ln(L)) =       20940271.4803748.
# # Task:NcmFitESMCMC, completed: 16500 of 25000, elapsed time: 00:07:29.5739
# # Task:NcmFitESMCMC, mean time: 00:00:00.0272 +/- 00:00:00.0065
# # Task:NcmFitESMCMC, time left: 00:03:51.5728 +/- 00:00:55.0900
# # Task:NcmFitESMCMC, current time:        Wed Oct 26 2022, 15:16:04
# # Task:NcmFitESMCMC, estimated to end at: Wed Oct 26 2022, 15:19:55 +/- 00:00:55.0900
# # NcmMSetCatalog: Current mean:   2.094e+07    1.46         0.48667      0.44187      3.4933
# # NcmMSetCatalog: Current msd:    0            0.0064115    0.0019077    0.0019077    0.0064399
# # NcmMSetCatalog: Current sd:     0            0.86019      0.25594      0.25594      0.864
# # NcmMSetCatalog: Current var:    0            0.73993      0.065506     0.065506     0.7465
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac: -nan          1.0004       1.001        1.001        0.99959
# # NcmMSetCatalog: Maximal Shrink factor = 1.00109
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `36':
# # NcmMSetCatalog: Constant break point at `35':
# # NcmFitESMCMC:acceptance ratio 99.2571% (last update 98.8000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):                      0 (2n = 4), min(-2ln(L)) =       20940271.4803748.
# # Task:NcmFitESMCMC, completed: 18000 of 25000, elapsed time: 00:08:01.1866
# # Task:NcmFitESMCMC, mean time: 00:00:00.0267 +/- 00:00:00.0060
# # Task:NcmFitESMCMC, time left: 00:03:07.1141 +/- 00:00:42.1885
# # Task:NcmFitESMCMC, current time:        Wed Oct 26 2022, 15:16:35
# # Task:NcmFitESMCMC, estimated to end at: Wed Oct 26 2022, 15:19:43 +/- 00:00:42.1885
# # NcmMSetCatalog: Current mean:   2.094e+07    1.4621       0.48855      0.44375      3.4907
# # NcmMSetCatalog: Current msd:    0            0.0059518    0.0017681    0.0017681    0.0059619
# # NcmMSetCatalog: Current sd:     0            0.86249      0.25623      0.25623      0.86396
# # NcmMSetCatalog: Current var:    0            0.7439       0.065653     0.065653     0.74643
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac: -nan          1.0011       1.0014       1.0014       0.99984
# # NcmMSetCatalog: Maximal Shrink factor = 1.00142
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `42':
# # NcmMSetCatalog: Constant break point at `41':
# # NcmFitESMCMC:acceptance ratio 99.2439% (last update 99.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):                      0 (2n = 4), min(-2ln(L)) =       20940271.4803748.
# # Task:NcmFitESMCMC, completed: 21000 of 25000, elapsed time: 00:09:06.7978
# # Task:NcmFitESMCMC, mean time: 00:00:00.0260 +/- 00:00:00.0053
# # Task:NcmFitESMCMC, time left: 00:01:44.1450 +/- 00:00:21.2832
# # Task:NcmFitESMCMC, current time:        Wed Oct 26 2022, 15:17:41
# # Task:NcmFitESMCMC, estimated to end at: Wed Oct 26 2022, 15:19:25 +/- 00:00:21.2832
# # NcmMSetCatalog: Current mean:   2.094e+07    1.4633       0.48937      0.44457      3.4907
# # NcmMSetCatalog: Current msd:    0            0.0057548    0.0017102    0.0017102    0.0057573
# # NcmMSetCatalog: Current sd:     0            0.86322      0.25653      0.25653      0.86359
# # NcmMSetCatalog: Current var:    0            0.74515      0.065807     0.065807     0.74579
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac: -nan          1.0011       1.0012       1.0012       1
# # NcmMSetCatalog: Maximal Shrink factor = 1.00123
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `45':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 99.2318% (last update 98.4000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):                      0 (2n = 4), min(-2ln(L)) =       20940271.4803748.
# # Task:NcmFitESMCMC, completed: 22500 of 25000, elapsed time: 00:09:38.8974
# # Task:NcmFitESMCMC, mean time: 00:00:00.0257 +/- 00:00:00.0050
# # Task:NcmFitESMCMC, time left: 00:01:04.3179 +/- 00:00:12.5845
# # Task:NcmFitESMCMC, current time:        Wed Oct 26 2022, 15:18:13
# # Task:NcmFitESMCMC, estimated to end at: Wed Oct 26 2022, 15:19:17 +/- 00:00:12.5845
# # NcmMSetCatalog: Current mean:   2.094e+07    1.4684       0.49063      0.44583      3.4931
# # NcmMSetCatalog: Current msd:    0            0.0054696    0.0016226    0.0016226    0.0054577
# # NcmMSetCatalog: Current sd:     0            0.86482      0.25655      0.25655      0.86294
# # NcmMSetCatalog: Current var:    0            0.74791      0.065817     0.065817     0.74466
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac: -nan          1.0011       1.0012       1.0012       0.99999
# # NcmMSetCatalog: Maximal Shrink factor = 1.00124
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `50':
# # NcmMSetCatalog: Constant break point at `49':
# # NcmFitESMCMC:acceptance ratio 99.2245% (last update 99.2000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):                      0 (2n = 4), min(-2ln(L)) =       20940271.4803748.
# # Task:NcmFitESMCMC, completed: 25000 of 25000, elapsed time: 00:10:31.7809
# # Task:NcmFitESMCMC, mean time: 00:00:00.0253 +/- 00:00:00.0046
# # Task:NcmFitESMCMC, time left: 00:00:00.0000 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, current time:        Wed Oct 26 2022, 15:19:06
# # Task:NcmFitESMCMC, estimated to end at: Wed Oct 26 2022, 15:19:06 +/- 00:00:00.0000
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 5 was incorrect on entry to DLASCL.
# # NcmFitESMCMC: Largest relative error 1.000000e-03 not attained: 4.865903e-03
# # NcmFitESMCMC: ln (eVol) =      0.600626965161233; ln (gVol) =      0.467859356514052; lnNorm =      -10470134.7578314
# # NcmFitESMCMC: Running more 114 runs...
# #----------------------------------------------------------------------------------
# # NcmFitESMCMC: Calculating [000114] Ensemble Sampler Markov Chain Monte Carlo runs [APES-Move:VKDE:Cauchy]
# # Task:NcmFitESMCMC, started at: Wed Oct 26 2022, 15:08:34
# # NcmMSetCatalog: Current mean:   2.094e+07    1.467        0.49108      0.44628      3.492
# # NcmMSetCatalog: Current msd:   -nan          0.0080033    0.0020509    0.0020509    0.005151
# # NcmMSetCatalog: Current sd:     0            0.86286      0.25668      0.25668      0.86194
# # NcmMSetCatalog: Current var:    0            0.74453      0.065886     0.065886     0.74293
# # NcmMSetCatalog: Current tau:   -nan          2.4089       1.7876       1.7876       1
# # NcmMSetCatalog: Current skfac: -nan          1.0008       1.0009       1.0009       0.99992
# # NcmMSetCatalog: Maximal Shrink factor = 1.0009
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `56':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 99.2364% (last update 99.4000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):                      0 (2n = 4), min(-2ln(L)) =       20940271.4803748.
# # Task:NcmFitESMCMC, completed: 28000 of 82000, elapsed time: 00:11:35.9323
# # Task:NcmFitESMCMC, mean time: 00:00:00.0249 +/- 00:00:00.0042
# # Task:NcmFitESMCMC, time left: 00:22:22.0850 +/- 00:03:48.7766
# # Task:NcmFitESMCMC, current time:        Wed Oct 26 2022, 15:20:10
# # Task:NcmFitESMCMC, estimated to end at: Wed Oct 26 2022, 15:42:32 +/- 00:03:48.7766
# # NcmMSetCatalog: Current mean:   2.094e+07    1.4683       0.49223      0.44743      3.4924
# # NcmMSetCatalog: Current msd:   -nan          0.0076153    0.0019534    0.0019534    0.0048964
# # NcmMSetCatalog: Current sd:     0            0.86389      0.25723      0.25723      0.86211
# # NcmMSetCatalog: Current var:    0            0.7463       0.066169     0.066169     0.74323
# # NcmMSetCatalog: Current tau:   -nan          2.4089       1.7876       1.7876       1
# # NcmMSetCatalog: Current skfac: -nan          1.0009       1.0006       1.0006       1
# # NcmMSetCatalog: Maximal Shrink factor = 1.00081
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `62':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 99.2328% (last update 99.4000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):                      0 (2n = 4), min(-2ln(L)) =       20940271.4803748.
# # Task:NcmFitESMCMC, completed: 31000 of 82000, elapsed time: 00:12:39.0264
# # Task:NcmFitESMCMC, mean time: 00:00:00.0245 +/- 00:00:00.0039
# # Task:NcmFitESMCMC, time left: 00:20:48.6578 +/- 00:03:19.6983
# # Task:NcmFitESMCMC, current time:        Wed Oct 26 2022, 15:21:13
# # Task:NcmFitESMCMC, estimated to end at: Wed Oct 26 2022, 15:42:02 +/- 00:03:19.6983

# %%
ntests   = 100.0
nwalkers = 500
burnin   = 30
mcat = Ncm.MSetCatalog.new_from_file_ro ("mcmc_nodist_unbinned.fits", nwalkers * burnin)

mcat.log_current_chain_stats ()
mcat.calc_max_ess_time (ntests, Ncm.FitRunMsgs.SIMPLE);
mcat.calc_heidel_diag (ntests, 0.0, Ncm.FitRunMsgs.SIMPLE);

mset.pretty_log ()
mcat.log_full_covar ()
mcat.log_current_stats ()

be, post_lnnorm_sd = mcat.get_post_lnnorm ()
lnevol, glnvol = mcat.get_post_lnvol (0.6827)

Ncm.cfg_msg_sepa ()
print ("# Bayesian evidence:                                 % 22.15g +/- % 22.15g" % (be, post_lnnorm_sd))
print ("# 1 sigma posterior volume:                          % 22.15g" % lnevol)
print ("# 1 sigma posterior volume (Gaussian approximation): % 22.15g" % glnvol)

# %%
#proxy noself 47 min 52 segundos 1-sigma posterior volume -10.49
#proxy self 1 hora 43 min 34 segundos 1-sigma posterior volume -14.47
#nodist 14 min 44 segundos 1-sigma posterior volume -10.97
