# %%
#!/usr/bin/env python

import math
import healpy as hp
import numpy as np
import sys
import time
import os
sys.path.insert(1, '../../../PySSC/')

from classy import Class
import PySSC
from scipy.stats import norm
from matplotlib import pyplot as plt

from numcosmo_py import Ncm, Nc

Ncm.cfg_init()
Ncm.cfg_set_log_handler(lambda msg: sys.stdout.write(msg) and sys.stdout.flush())

# %%
cosmo_resample = Nc.HICosmoDEXcdm()
reion_resample = Nc.HIReionCamb.new()
prim_resample = Nc.HIPrimPowerLaw.new()
cosmo_resample.omega_x2omega_k()

cosmo_resample.param_set_by_name ("H0", 67.81)
cosmo_resample.param_set_by_name ("Omegac", 0.2612)
cosmo_resample.param_set_by_name ("Omegab", 0.0486)
cosmo_resample.param_set_by_name ("w", -1.0)
cosmo_resample.param_set_by_name ("Omegak", 0.0)

cosmo_resample.add_submodel(reion_resample)
cosmo_resample.add_submodel(prim_resample)

dist = Nc.Distance.new(2.0)

tf = Nc.TransferFunc.new_from_name("NcTransferFuncEH")

psml = Nc.PowspecMLTransfer.new(tf)
psml.require_kmin(1.0e-8)
psml.require_kmax(1.0e6)

psf = Ncm.PowspecFilter.new(psml, Ncm.PowspecFilterType.TOPHAT)
psf.set_best_lnr0()
prim_resample.props.n_SA = 0.9660


z_obs = Ncm.Vector.new_array(np.linspace(0.1, 0.8, 8))
lnM_obs = Ncm.Vector.new_array(np.linspace(np.log(10) * 14.0, np.log(10) * 15, 2))

print(z_obs.dup_array())
print(lnM_obs.dup_array())
# Out:
# [0.1, 0.2, 0.30000000000000004, 0.4, 0.5, 0.6, 0.7000000000000001, 0.8]
# [32.23619130191664, 34.53877639491069]

# %% [markdown]
# # Construct the $S_{ij}$  Matrix

# %%
nz = 400
z_arr = np.linspace(0, 1.9, num=nz + 1)[1:]

nbins_T = z_obs.len() - 1

kernels_T = np.zeros((nbins_T, nz))
for i in range(nbins_T):
    zminbin = z_obs.get(i)
    zmaxbin = z_obs.get(i + 1)
    Dz = zmaxbin - zminbin

    for iz in range(nz):
        z = z_arr[iz]
        if (z > zminbin) and (z <= zmaxbin):
            kernels_T[i, iz] = 1 / Dz

fig = plt.figure()
ax = fig.add_subplot(111)

im = ax.matshow(kernels_T)
ax.set_aspect("auto")
plt.colorbar(im)
pass

# %%
NSIDE = 2 * 512
NPIX = hp.nside2npix(NSIDE)
m = np.zeros(hp.nside2npix(NSIDE))
pix_theta_ecl, pix_phi_ecl = hp.pix2ang(NSIDE, np.arange(NPIX))

# Guaranteed mask
mask1_guaranteed = np.zeros(NPIX)
mask2_guaranteed = np.zeros(NPIX)
mask3_guaranteed = np.zeros(NPIX)

mask1_guaranteed_condition = (
    (pix_phi_ecl > 3.0 * np.pi / 4.0)
    & (pix_phi_ecl < 13.0 * np.pi / 12.0)
    & (pix_theta_ecl < np.pi / 2.0 - 30.0 * np.pi / 180)
    & (pix_theta_ecl > np.pi / 2.0 - 80.0 * np.pi / 180)
)
mask2_guaranteed_condition = (
    (pix_phi_ecl > 11.0 * np.pi / 6.0)
    & (pix_theta_ecl < np.pi / 2.0 - 20.0 * np.pi / 180)
    & (pix_theta_ecl > np.pi / 2.0 - 40.0 * np.pi / 180)
)
mask3_guaranteed_condition = (
    (pix_phi_ecl < np.pi / 4.0)
    & (pix_theta_ecl < np.pi / 2.0 - 20.0 * np.pi / 180)
    & (pix_theta_ecl > np.pi / 2.0 - 40.0 * np.pi / 180)
)

mask1_guaranteed[mask1_guaranteed_condition] = 1
mask2_guaranteed[mask2_guaranteed_condition] = 1
mask3_guaranteed[mask3_guaranteed_condition] = 1

mask_guaranteed = mask1_guaranteed + mask2_guaranteed + mask3_guaranteed

# Total mask
mask1_full = np.zeros(NPIX)
mask2_full = np.zeros(NPIX)
mask3_full = np.zeros(NPIX)

mask1_full_condition = (
    (pix_phi_ecl > 2.0 * np.pi / 3.0)
    & (pix_phi_ecl < 3.0 * np.pi / 2.0)
    & (pix_theta_ecl < np.pi / 2.0 - 10.0 * np.pi / 180)
    & (pix_theta_ecl > np.pi / 2.0 - 80.0 * np.pi / 180)
)
mask2_full_condition = (
    (pix_phi_ecl > 11.0 * np.pi / 6.0)
    & (pix_theta_ecl < np.pi / 2.0)
    & (pix_theta_ecl > np.pi / 2.0 - 45.0 * np.pi / 180)
)
mask3_full_condition = (
    (pix_phi_ecl < np.pi / 4.0)
    & (pix_theta_ecl < np.pi / 2.0)
    & (pix_theta_ecl > np.pi / 2.0 - 45.0 * np.pi / 180)
)

mask1_full[mask1_full_condition] = 1
mask2_full[mask2_full_condition] = 1
mask3_full[mask3_full_condition] = 1

mask_full = mask1_full + mask2_full + mask3_full

# %% [markdown]
# `S matrix `

# %%
cosmo_sij = Nc.HICosmoDEXcdm()
cosmo_sij.omega_x2omega_k()

cosmo_sij.param_set_by_name ("H0", 67.81)
cosmo_sij.param_set_by_name ("Omegac", 0.2612)
cosmo_sij.param_set_by_name ("Omegab", 0.0486)
cosmo_sij.param_set_by_name ("w", -1.0)
cosmo_sij.param_set_by_name ("Omegak", 0.0)

reion_sij = Nc.HIReionCamb.new()
prim_sij = Nc.HIPrimPowerLaw.new()

prim_sij.props.ln10e10ASA = 3.027449698161606

cosmo_sij.add_submodel(reion_sij)
cosmo_sij.add_submodel(prim_sij)

# Full sky
t0 = time.time()
S_lacasa_full = PySSC.Sij(z_arr, kernels_T, cosmo_Class=cosmo_sij)
t1 = time.time()
print("Full sky time (seconds) = " + str(t1 - t0))

S_fit = Ncm.Matrix.new(S_lacasa_full.shape[0], S_lacasa_full.shape[1])
for i in range(len(S_lacasa_full)):
    for j in range(len(S_lacasa_full[i])):
        S_fit.set(i, j, S_lacasa_full[i][j])


S_fit.log_vals("Sij: ", "% 22.15g")
# Out:
# Full sky time (seconds) = 0.34113407135009766
# Sij:    1.92175205877645e-05  -3.03940429181774e-06  -6.13267746083644e-07  -1.98416530133711e-07  -9.01835132135309e-08  -3.50713697574375e-08  -1.62884212049099e-08
# Sij:   -3.03940429181774e-06   7.41146312478369e-06  -1.31034891678634e-06  -3.46504158861848e-07  -1.18176054912998e-07  -5.17946097934648e-08  -2.92215648127833e-08
# Sij:   -6.13267746083644e-07  -1.31034891678634e-06   3.72376949794711e-06   -7.0167046785694e-07  -2.29473536237457e-07  -7.73712907142391e-08  -3.69163500312817e-08
# Sij:   -1.98416530133711e-07  -3.46504158861848e-07   -7.0167046785694e-07   2.39727654957993e-06  -4.80727998063613e-07  -1.57265044361002e-07  -5.98165060549361e-08
# Sij:   -9.01835132135309e-08  -1.18176054912998e-07  -2.29473536237457e-07  -4.80727998063613e-07    1.5828634357491e-06  -3.29998435362026e-07    -1.218551539022e-07
# Sij:   -3.50713697574375e-08  -5.17946097934648e-08  -7.73712907142391e-08  -1.57265044361002e-07  -3.29998435362026e-07   1.21424035306122e-06  -2.41864780678195e-07
# Sij:   -1.62884212049099e-08  -2.92215648127833e-08  -3.69163500312817e-08  -5.98165060549361e-08    -1.218551539022e-07  -2.41864780678195e-07   8.93591838257377e-07

# %% [markdown]
# # Define proxy modelling

# %%
cluster_m = Nc.ClusterMassNodist(lnM_min=np.log(10) * 14.0, lnM_max=np.log(10) * 16 )
cluster_z = Nc.ClusterRedshiftNodist(z_min=0.0, z_max=2.0)

# %% [markdown]
# # Initialize the `ClusterAbundance` object

# %%
mulf = Nc.MultiplicityFuncTinker.new()
mulf.set_mdef(Nc.MultiplicityFuncMassDef.CRITICAL)
mulf.set_Delta(200.0)

hmf = Nc.HaloMassFunction.new(dist, psf, mulf)
hbias_Tinker = Nc.HaloBiasTinker.new(hmf)
cad = Nc.ClusterAbundance.new(hmf, hbias_Tinker)
cad.prepare(cosmo_resample, cluster_z, cluster_m)
guaranteed_area = 2959.1
cad.set_area(guaranteed_area * (np.pi / 180) ** 2)

# %% [markdown]
# # Data model
#
# $f(x_i)$ for the Gaussian distribution $$-2\ln L = \sum_{ij}\left[(f(x_i) - y_i)C^{-1}_{ij}(f(x_j) - y_j)\right] + \dots$$

# %%
mset_sij = Ncm.MSet.new_array([cosmo_sij,cluster_m,cluster_z])
ser = Ncm.Serialize.new(Ncm.SerializeOpt.NONE)

ncounts_gauss = Nc.DataClusterNCountsGauss.new(cad)
ncounts_gauss.set_size((z_obs.len()-1)*(lnM_obs.len()-1))
ncounts_gauss.set_init(True)
ncounts_gauss.set_fix_cov(False)
ncounts_gauss.use_norma(True)
ncounts_gauss.set_z_obs(z_obs)
ncounts_gauss.set_lnM_obs(lnM_obs)
ncounts_gauss.set_has_ssc(True)
rng = Ncm.RNG.seeded_new (None, 42)

# %% [markdown]
# # Creating the fit object and calculating the MC

# %%
#preparing the resample model

parameters = [[0.8,4.9, 0.1] , [0.8,4.9,-4.9] , [0.8,2.1,0.1] , [0.1,4.9,0.1] , [0.8,2.1,-4.9] , [0.1,4.9,-4.9] , [0.1,2.1,0.1] , [0.1,2.1,-4.9]]

for case in parameters:
    cosmo_resample.param_set_by_name("w", case[2])
    cosmo_resample.param_set_by_name("Omegac", case[0])
    prim_resample.param_set_by_name("ln10e10ASA", case[1])

    mset_resample = Ncm.MSet.new_array([cosmo_resample,cluster_m,cluster_z])

    print("MCMC w = %.2f, omegac = %.2f, ln10e10ASA = %.2f  in a area of  %.1f deg²" % (cosmo_resample.props.w ,cosmo_resample.props.Omegac, prim_resample.props.ln10e10ASA, guaranteed_area))

    S_lacasa_full = PySSC.Sij(z_arr, kernels_T, cosmo_Class=cosmo_resample)
    S_resample = Ncm.Matrix.new(S_lacasa_full.shape[0], S_lacasa_full.shape[1])
    for i in range(len(S_lacasa_full)):
        for j in range(len(S_lacasa_full[i])):
            S_resample.set(i, j, S_lacasa_full[i][j])

    ncounts_gauss.set_s_matrix(S_fit)
    ncounts_gauss.set_resample_s_matrix(S_resample)

    ncounts_gauss.get_resample_s_matrix().log_vals("Sij_resample: ", "% 22.15g")
    print("\n")
    ncounts_gauss.get_s_matrix().log_vals("Sij_fit: ", "% 22.15g")

    ncounts_gauss.resample(mset_resample, rng)
    ncounts_gauss.peek_mean().log_vals("y: ", "%.3f", True)

    dset = Ncm.Dataset.new()
    dset.append_data(ncounts_gauss)


    cosmo_sij.props.Omegac_fit = True
    cosmo_sij.props.Omegab_fit = False
    cosmo_sij.props.w_fit = True
    prim_sij.props.ln10e10ASA_fit = True
    mfunc_oa = Ncm.ObjArray.new()
    mfunc_sigma8 = Ncm.MSetFuncList.new("NcHICosmo:sigma8", psf)
    mfunc_oa.add(mfunc_sigma8)
    print(mfunc_sigma8.eval0(mset_resample))


    mset_fit = mset_sij.dup(ser)
    mset_fit.prepare_fparam_map()

    mset_fit.pretty_log()
    mset_resample.pretty_log()
        
    lh = Ncm.Likelihood.new(dset)

    fit = Ncm.Fit.new(
        Ncm.FitType.NLOPT, "ln-neldermead", lh, mset_fit, Ncm.FitGradType.NUMDIFF_FORWARD
    )

    init_sampler = Ncm.MSetTransKernGauss.new(0)
    init_sampler.set_mset(mset_fit)
    init_sampler.set_prior_from_mset()
    init_sampler.set_cov_from_rescale(1.0)  # 1

    sampler = "apes"

    nwalkers = int(math.ceil(500))  # 500
    ssize = 400000  # 1000000

    walker = Ncm.FitESMCMCWalkerAPES.new(nwalkers, mset_fit.fparams_len())

    esmcmc = Ncm.FitESMCMC.new_funcs_array(
        fit, nwalkers, init_sampler, walker, Ncm.FitRunMsgs.SIMPLE, mfunc_oa
    )

    esmcmc.set_data_file("mcmc_%.2f,%.2f,%.2f.fits" % (cosmo_resample.props.w ,cosmo_resample.props.Omegac, prim_resample.props.ln10e10ASA))

    esmcmc.set_nthreads(4)
    t0 = time.time()
    esmcmc.start_run()
    esmcmc.run(ssize / nwalkers)
    # esmcmc.run (10)
    # esmcmc.run_lre (50, 1.0e-3)
    esmcmc.end_run()
    t1 = time.time()

    esmcmc.mean_covar()

    print("MCMC correct version." )

    ncounts_gauss.set_s_matrix(S_resample)

    ncounts_gauss.get_resample_s_matrix().log_vals("Sij_resample: ", "% 22.15g")
    print("\n")
    ncounts_gauss.get_s_matrix().log_vals("Sij_fit: ", "% 22.15g")

    ncounts_gauss.peek_mean().log_vals("y: ", "%.3f", True)

    dset = Ncm.Dataset.new()
    dset.append_data(ncounts_gauss)

    cosmo_sij.props.Omegac_fit = True
    cosmo_sij.props.Omegab_fit = False
    cosmo_sij.props.w_fit = True
    prim_sij.props.ln10e10ASA_fit = True
    mfunc_oa = Ncm.ObjArray.new()
    mfunc_sigma8 = Ncm.MSetFuncList.new("NcHICosmo:sigma8", psf)
    mfunc_oa.add(mfunc_sigma8)
    print(mfunc_sigma8.eval0(mset_resample))

    mset_fit = mset_sij.dup(ser)
    mset_fit.prepare_fparam_map()
    mset_fit.pretty_log()
    mset_resample.pretty_log()

    lh = Ncm.Likelihood.new(dset)

    fit = Ncm.Fit.new(
        Ncm.FitType.NLOPT, "ln-neldermead", lh, mset_fit, Ncm.FitGradType.NUMDIFF_FORWARD
    )

    init_sampler = Ncm.MSetTransKernGauss.new(0)
    init_sampler.set_mset(mset_fit)
    init_sampler.set_prior_from_mset()
    init_sampler.set_cov_from_rescale(1.0)  # 1

    sampler = "apes"

    nwalkers = int(math.ceil(500))  # 500
    ssize = 200000  # 1000000

    walker = Ncm.FitESMCMCWalkerAPES.new(nwalkers, mset_fit.fparams_len())

    esmcmc = Ncm.FitESMCMC.new_funcs_array(
        fit, nwalkers, init_sampler, walker, Ncm.FitRunMsgs.SIMPLE, mfunc_oa
    )

    esmcmc.set_data_file("mcmc_%.2f,%.2f,%.2f_correct.fits" % (cosmo_resample.props.w ,cosmo_resample.props.Omegac, prim_resample.props.ln10e10ASA))

    esmcmc.set_nthreads(4)
    t0 = time.time()
    esmcmc.start_run()
    esmcmc.run(ssize / nwalkers)
    # esmcmc.run (10)
    # esmcmc.run_lre (50, 1.0e-3)
    esmcmc.end_run()
    t1 = time.time()

    esmcmc.mean_covar()
# Out:
# MCMC w = -4.50, omegac = 0.70, ln10e10ASA = 2.50  in a area of  2959.1 deg²
# Sij_resample:    8.34261209706909e-06  -1.24649705363446e-06  -1.73753105182808e-07  -2.97173407510564e-08  -6.57963681693218e-09  -1.37287946927585e-08  -1.59926236604932e-08
# Sij_resample:   -1.24649705363446e-06   3.12860996163074e-06  -5.49143513812213e-07  -7.01170032356958e-08  -2.19519217275244e-08  -2.05699784968494e-08   1.30622058241525e-08
# Sij_resample:   -1.73753105182808e-07  -5.49143513812213e-07   1.66460433595467e-06  -2.84490528792749e-07  -5.29585736316912e-08  -1.76140288662292e-08  -1.07151411787732e-08
# Sij_resample:   -2.97173407510564e-08  -7.01170032356958e-08  -2.84490528792749e-07   1.05763209023867e-06  -2.27909823357733e-07  -4.01238099561009e-08  -2.30794355690962e-08
# Sij_resample:   -6.57963681693218e-09  -2.19519217275244e-08  -5.29585736316912e-08  -2.27909823357733e-07   6.40041772944136e-07  -1.70987436123079e-07  -3.51405694805275e-08
# Sij_resample:   -1.37287946927585e-08  -2.05699784968494e-08  -1.76140288662292e-08  -4.01238099561009e-08  -1.70987436123079e-07   5.09331297793174e-07  -1.33390891442546e-07
# Sij_resample:   -1.59926236604932e-08   1.30622058241525e-08  -1.07151411787732e-08  -2.30794355690962e-08  -3.51405694805275e-08  -1.33390891442546e-07   4.05012080244329e-07
#
#
# Sij_fit:    1.92175205877645e-05  -3.03940429181774e-06  -6.13267746083644e-07  -1.98416530133711e-07  -9.01835132135309e-08  -3.50713697574375e-08  -1.62884212049099e-08
# Sij_fit:   -3.03940429181774e-06   7.41146312478369e-06  -1.31034891678634e-06  -3.46504158861848e-07  -1.18176054912998e-07  -5.17946097934648e-08  -2.92215648127833e-08
# Sij_fit:   -6.13267746083644e-07  -1.31034891678634e-06   3.72376949794711e-06   -7.0167046785694e-07  -2.29473536237457e-07  -7.73712907142391e-08  -3.69163500312817e-08
# Sij_fit:   -1.98416530133711e-07  -3.46504158861848e-07   -7.0167046785694e-07   2.39727654957993e-06  -4.80727998063613e-07  -1.57265044361002e-07  -5.98165060549361e-08
# Sij_fit:   -9.01835132135309e-08  -1.18176054912998e-07  -2.29473536237457e-07  -4.80727998063613e-07    1.5828634357491e-06  -3.29998435362026e-07    -1.218551539022e-07
# Sij_fit:   -3.50713697574375e-08  -5.17946097934648e-08  -7.73712907142391e-08  -1.57265044361002e-07  -3.29998435362026e-07   1.21424035306122e-06  -2.41864780678195e-07
# Sij_fit:   -1.62884212049099e-08  -2.92215648127833e-08  -3.69163500312817e-08  -5.98165060549361e-08    -1.218551539022e-07  -2.41864780678195e-07   8.93591838257377e-07
# y: 11882.889 25826.100 39281.563 49841.175 57331.938 60603.436 62280.454
# 1.1809700414605755
# #----------------------------------------------------------------------------------
# # Model[03000]:
# #   - NcHICosmo : XCDM - Constant EOS
# #----------------------------------------------------------------------------------
# # Model parameters
# #   -         H0[00]:  67.81               [FIXED]
# #   -     Omegac[01]:  0.2612              [FREE]
# #   -     Omegak[02]:  0                   [FIXED]
# #   -    Tgamma0[03]:  2.7245              [FIXED]
# #   -         Yp[04]:  0.24                [FIXED]
# #   -       ENnu[05]:  3.046               [FIXED]
# #   -     Omegab[06]:  0.0486              [FIXED]
# #   -          w[07]: -1                   [FREE]
# #----------------------------------------------------------------------------------
# # Model[05000]:
# #   - NcHIPrim : Power Law model for primordial spectra
# #----------------------------------------------------------------------------------
# # Model parameters
# #   - ln10e10ASA[00]:  3.02744969816161    [FREE]
# #   - T_SA_ratio[01]:  0.2                 [FIXED]
# #   -       n_SA[02]:  0.9742              [FIXED]
# #   -        n_T[03]:  0                   [FIXED]
# #----------------------------------------------------------------------------------
# # Model[07000]:
# #   - NcClusterMass : No mass distribution
# #----------------------------------------------------------------------------------
# # Model parameters
# #----------------------------------------------------------------------------------
# # Model[08000]:
# #   - NcClusterRedshift : No redshift distribution
# #----------------------------------------------------------------------------------
# # Model parameters
# #----------------------------------------------------------------------------------
# # Model[13000]:
# #   - NcHIReion : Reion-CAMB
# #----------------------------------------------------------------------------------
# # Model parameters
# #   -       z_re[00]:  13                  [FIXED]
# #   -    z_He_re[01]:  3.5                 [FIXED]
# #----------------------------------------------------------------------------------
# # Model[03000]:
# #   - NcHICosmo : XCDM - Constant EOS
# #----------------------------------------------------------------------------------
# # Model parameters
# #   -         H0[00]:  67.81               [FIXED]
# #   -     Omegac[01]:  0.7                 [FIXED]
# #   -     Omegak[02]:  0                   [FIXED]
# #   -    Tgamma0[03]:  2.7245              [FIXED]
# #   -         Yp[04]:  0.24                [FIXED]
# #   -       ENnu[05]:  3.046               [FIXED]
# #   -     Omegab[06]:  0.0486              [FIXED]
# #   -          w[07]: -4.5                 [FIXED]
# #----------------------------------------------------------------------------------
# # Model[05000]:
# #   - NcHIPrim : Power Law model for primordial spectra
# #----------------------------------------------------------------------------------
# # Model parameters
# #   - ln10e10ASA[00]:  2.5                 [FIXED]
# #   - T_SA_ratio[01]:  0.2                 [FIXED]
# #   -       n_SA[02]:  0.966               [FIXED]
# #   -        n_T[03]:  0                   [FIXED]
# #----------------------------------------------------------------------------------
# # Model[07000]:
# #   - NcClusterMass : No mass distribution
# #----------------------------------------------------------------------------------
# # Model parameters
# #----------------------------------------------------------------------------------
# # Model[08000]:
# #   - NcClusterRedshift : No redshift distribution
# #----------------------------------------------------------------------------------
# # Model parameters
# #----------------------------------------------------------------------------------
# # Model[13000]:
# #   - NcHIReion : Reion-CAMB
# #----------------------------------------------------------------------------------
# # Model parameters
# #   -       z_re[00]:  13                  [FIXED]
# #   -    z_He_re[01]:  3.5                 [FIXED]
# #----------------------------------------------------------------------------------
# # NcmFitESMCMC: Starting Ensemble Sampler Markov Chain Monte Carlo.
# #   Number of walkers: 0500.
# #   Number of threads: 0004.
# #   Using MPI:         no - use MPI enabled but no slaves available.
# # NcmMSetCatalog: Current mean:   4.5602e+06   0.99253      0.2611      -0.99954      3.2687
# # NcmMSetCatalog: Current msd:    3.3884e+05   0.016703     0.00043004   0.00042622   0.030849
# # NcmMSetCatalog: Current sd:     7.5766e+06   0.37349      0.0096161    0.0095305    0.68981
# # NcmMSetCatalog: Current var:    5.7405e+13   0.13949      9.2469e-05   9.0831e-05   0.47584
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac: -nan         -nan         -nan         -nan         -nan
# # NcmMSetCatalog: Maximal Shrink factor = 1e+10
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `1':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       57485675799455.4 (2n = 6), min(-2ln(L)) =       135652.466373916.
# # Task:NcmFitESMCMC, completed: 500 of 500, elapsed time: 00:01:28.7910
# # Task:NcmFitESMCMC, mean time: 00:00:00.1775 +/- 00:00:00.1775
# # Task:NcmFitESMCMC, time left: 00:00:00.0000 +/- 00:00:00.0000
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 17:16:44
# # Task:NcmFitESMCMC, estimated to end at: Tue Nov 07 2023, 17:16:44 +/- 00:00:00.0000
# #----------------------------------------------------------------------------------
# # NcmFitESMCMC: Calculating [000799] Ensemble Sampler Markov Chain Monte Carlo runs [APES-Move:Interp-VKDE:Cauchy]
# # Task:NcmFitESMCMC, started at: Tue Nov 07 2023, 17:15:15
# # NcmMSetCatalog: Current mean:   2.4628e+06   1.4133       0.28284     -1.0113       3.8041
# # NcmMSetCatalog: Current msd:    1.8407e+05   0.018926     0.001105     0.00072567   0.026085
# # NcmMSetCatalog: Current sd:     5.8207e+06   0.5985       0.034942     0.022948     0.82488
# # NcmMSetCatalog: Current var:    3.388e+13    0.3582       0.0012209    0.00052659   0.68043
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.96552      0.83347      0.8508       0.89325      0.86577
# # NcmMSetCatalog: Maximal Shrink factor = 1.07258
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `2':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 92.6000% (last update 92.6000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       1608482202302.52 (2n = 6), min(-2ln(L)) =       42878.6716278418.
# # Task:NcmFitESMCMC, completed: 1000 of 400000, elapsed time: 00:02:36.9613
# # Task:NcmFitESMCMC, mean time: 00:00:00.1569 +/- 00:00:00.1119
# # Task:NcmFitESMCMC, time left: 17:23:37.0040 +/- 12:23:55.5458
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 17:17:52
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 10:41:29 +/- 12:23:55.5458
# # NcmMSetCatalog: Current mean:   1.657e+06    1.633        0.34069     -1.0468       3.927
# # NcmMSetCatalog: Current msd:    1.2619e+05   0.015935     0.0026381    0.0016488    0.018962
# # NcmMSetCatalog: Current sd:     4.8873e+06   0.61717      0.10217      0.063859     0.73438
# # NcmMSetCatalog: Current var:    2.3886e+13   0.3809       0.010439     0.0040779    0.53932
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.97153      0.88855      0.88356      0.88221      0.92452
# # NcmMSetCatalog: Maximal Shrink factor = 1.01122
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `3':
# # NcmMSetCatalog: Constant break point at `0':
# # NcmFitESMCMC:acceptance ratio 93.2000% (last update 93.8000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       20907570591.5331 (2n = 6), min(-2ln(L)) =       4364.53622590935.
# # Task:NcmFitESMCMC, completed: 1500 of 400000, elapsed time: 00:03:41.2497
# # Task:NcmFitESMCMC, mean time: 00:00:00.1475 +/- 00:00:00.0860
# # Task:NcmFitESMCMC, time left: 16:19:32.6535 +/- 09:31:08.5327
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 17:18:57
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 09:38:29 +/- 09:31:08.5327
# # NcmMSetCatalog: Current mean:   1.2444e+06   1.6174       0.4232      -1.1122       3.7623
# # NcmMSetCatalog: Current msd:    95975        0.01256      0.0038967    0.0032831    0.016423
# # NcmMSetCatalog: Current sd:     4.2921e+06   0.56169      0.17427      0.14683      0.73446
# # NcmMSetCatalog: Current var:    1.8422e+13   0.31549      0.030369     0.021558     0.53943
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.97699      0.92295      0.89395      0.91282      0.93699
# # NcmMSetCatalog: Maximal Shrink factor = 0.979445
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `4':
# # NcmMSetCatalog: Constant break point at `1':
# # NcmFitESMCMC:acceptance ratio 93.7333% (last update 94.8000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       73908676.7575489 (2n = 6), min(-2ln(L)) =       187.364352182356.
# # Task:NcmFitESMCMC, completed: 2000 of 400000, elapsed time: 00:04:49.0003
# # Task:NcmFitESMCMC, mean time: 00:00:00.1445 +/- 00:00:00.0728
# # Task:NcmFitESMCMC, time left: 15:58:25.4427 +/- 08:03:07.3689
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 17:20:04
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 09:18:30 +/- 08:03:07.3689
# # NcmMSetCatalog: Current mean:   9.9573e+05   1.5436       0.49786     -1.1742       3.5579
# # NcmMSetCatalog: Current msd:    77418        0.010543     0.004352     0.0037356    0.015614
# # NcmMSetCatalog: Current sd:     3.8709e+06   0.52716      0.2176       0.18678      0.78068
# # NcmMSetCatalog: Current var:    1.4984e+13   0.27789      0.047349     0.034886     0.60946
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.98094      0.93866      0.90828      0.92337      0.93751
# # NcmMSetCatalog: Maximal Shrink factor = 0.998381
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `5':
# # NcmMSetCatalog: Constant break point at `2':
# # NcmFitESMCMC:acceptance ratio 92.3000% (last update 88.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       2625736.29014643 (2n = 6), min(-2ln(L)) =       132.659207631995.
# # Task:NcmFitESMCMC, completed: 2500 of 400000, elapsed time: 00:05:52.8265
# # Task:NcmFitESMCMC, mean time: 00:00:00.1411 +/- 00:00:00.0636
# # Task:NcmFitESMCMC, time left: 15:34:55.2792 +/- 07:01:22.4226
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 17:21:08
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 08:56:03 +/- 07:01:22.4226
# # NcmMSetCatalog: Current mean:   8.2985e+05   1.4793       0.55676     -1.2194       3.394
# # NcmMSetCatalog: Current msd:    64867        0.0091813    0.0043621    0.0036683    0.014658
# # NcmMSetCatalog: Current sd:     3.5529e+06   0.50288      0.23892      0.20092      0.80284
# # NcmMSetCatalog: Current var:    1.2623e+13   0.25289      0.057084     0.040369     0.64455
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.98379      0.94695      0.92068      0.9332       0.9407
# # NcmMSetCatalog: Maximal Shrink factor = 1.01602
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `6':
# # NcmMSetCatalog: Constant break point at `3':
# # NcmFitESMCMC:acceptance ratio 84.8800% (last update 55.2000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       148233.948967416 (2n = 6), min(-2ln(L)) =       132.659207631995.
# # Task:NcmFitESMCMC, completed: 3000 of 400000, elapsed time: 00:06:57.2487
# # Task:NcmFitESMCMC, mean time: 00:00:00.1391 +/- 00:00:00.0572
# # Task:NcmFitESMCMC, time left: 15:20:12.7639 +/- 06:18:20.3828
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 17:22:13
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 08:42:25 +/- 06:18:20.3828
# # NcmMSetCatalog: Current mean:   7.1136e+05   1.4329       0.59975     -1.2507       3.276
# # NcmMSetCatalog: Current msd:    55815        0.008107     0.0041471    0.003433     0.013495
# # NcmMSetCatalog: Current sd:     3.3021e+06   0.47962      0.24535      0.2031       0.79836
# # NcmMSetCatalog: Current var:    1.0904e+13   0.23003      0.060194     0.041249     0.63738
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.98593      0.95367      0.93133      0.94449      0.94645
# # NcmMSetCatalog: Maximal Shrink factor = 1.04095
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `7':
# # NcmMSetCatalog: Constant break point at `4':
# # NcmFitESMCMC:acceptance ratio 75.7667% (last update 30.2000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       61152.1810145495 (2n = 6), min(-2ln(L)) =       129.183940056355.
# # Task:NcmFitESMCMC, completed: 3500 of 400000, elapsed time: 00:08:03.5446
# # Task:NcmFitESMCMC, mean time: 00:00:00.1381 +/- 00:00:00.0525
# # Task:NcmFitESMCMC, time left: 15:12:55.6585 +/- 05:47:10.8846
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 17:23:19
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 08:36:15 +/- 05:47:10.8846
# # NcmMSetCatalog: Current mean:   6.2249e+05   1.3991       0.63084     -1.2787       3.1892
# # NcmMSetCatalog: Current msd:    48979        0.0072386    0.0038619    0.0033348    0.012365
# # NcmMSetCatalog: Current sd:     3.0977e+06   0.45781      0.24425      0.21091      0.78204
# # NcmMSetCatalog: Current var:    9.5957e+12   0.20959      0.059658     0.044484     0.61159
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.98758      0.95933      0.93998      0.95745      0.95224
# # NcmMSetCatalog: Maximal Shrink factor = 1.04777
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `8':
# # NcmMSetCatalog: Constant break point at `5':
# # NcmFitESMCMC:acceptance ratio 67.3143% (last update 16.6000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       18381.2336465058 (2n = 6), min(-2ln(L)) =       129.183940056355.
# # Task:NcmFitESMCMC, completed: 4000 of 400000, elapsed time: 00:09:13.7681
# # Task:NcmFitESMCMC, mean time: 00:00:00.1384 +/- 00:00:00.0492
# # Task:NcmFitESMCMC, time left: 15:13:40.3916 +/- 05:24:43.8999
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 17:24:29
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 08:38:10 +/- 05:24:43.8999
# # NcmMSetCatalog: Current mean:   5.5336e+05   1.3731       0.65403     -1.3064       3.122
# # NcmMSetCatalog: Current msd:    43634        0.006531     0.0035781    0.0033713    0.011358
# # NcmMSetCatalog: Current sd:     2.927e+06    0.43811      0.24003      0.22615      0.76192
# # NcmMSetCatalog: Current var:    8.5675e+12   0.19194      0.057612     0.051146     0.58052
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.98889      0.96388      0.94733      0.97099      0.95716
# # NcmMSetCatalog: Maximal Shrink factor = 1.05498
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `9':
# # NcmMSetCatalog: Constant break point at `5':
# # NcmFitESMCMC:acceptance ratio 60.3250% (last update 11.4000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       15520.9346779087 (2n = 6), min(-2ln(L)) =       129.183940056355.
# # Task:NcmFitESMCMC, completed: 4500 of 400000, elapsed time: 00:10:25.2536
# # Task:NcmFitESMCMC, mean time: 00:00:00.1389 +/- 00:00:00.0465
# # Task:NcmFitESMCMC, time left: 15:15:50.8037 +/- 05:06:40.8190
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 17:25:41
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 08:41:31 +/- 05:06:40.8190
# # NcmMSetCatalog: Current mean:   4.9806e+05   1.3526       0.67214     -1.3294       3.0688
# # NcmMSetCatalog: Current msd:    39340        0.0059453    0.0033185    0.0033642    0.010475
# # NcmMSetCatalog: Current sd:     2.7818e+06   0.4204       0.23465      0.23788      0.74067
# # NcmMSetCatalog: Current var:    7.7381e+12   0.17673      0.055063     0.056588     0.54859
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.98995      0.96771      0.95364      0.9866       0.96139
# # NcmMSetCatalog: Maximal Shrink factor = 1.08128
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `10':
# # NcmMSetCatalog: Constant break point at `6':
# # NcmFitESMCMC:acceptance ratio 54.7556% (last update 10.2000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       14302.6110522692 (2n = 6), min(-2ln(L)) =       129.183940056355.
# # Task:NcmFitESMCMC, completed: 5000 of 400000, elapsed time: 00:11:29.0917
# # Task:NcmFitESMCMC, mean time: 00:00:00.1378 +/- 00:00:00.0438
# # Task:NcmFitESMCMC, time left: 15:07:16.5547 +/- 04:48:10.1335
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 17:26:44
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 08:34:01 +/- 04:48:10.1335
# # NcmMSetCatalog: Current mean:   4.5282e+05   1.3359       0.68703     -1.3466       3.0255
# # NcmMSetCatalog: Current msd:    35815        0.0054549    0.0030893    0.0032803    0.0097061
# # NcmMSetCatalog: Current sd:     2.6561e+06   0.40454      0.22911      0.24327      0.71982
# # NcmMSetCatalog: Current var:    7.055e+12    0.16366      0.052489     0.059183     0.51815
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.99083      0.97101      0.95901      1.0029       0.96507
# # NcmMSetCatalog: Maximal Shrink factor = 1.11396
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `11':
# # NcmMSetCatalog: Constant break point at `6':
# # NcmFitESMCMC:acceptance ratio 50.1200% (last update  8.4000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       13449.6326926567 (2n = 6), min(-2ln(L)) =       129.183940056355.
# # Task:NcmFitESMCMC, completed: 5500 of 400000, elapsed time: 00:12:39.3045
# # Task:NcmFitESMCMC, mean time: 00:00:00.1381 +/- 00:00:00.0418
# # Task:NcmFitESMCMC, time left: 15:07:40.7687 +/- 04:34:44.7450
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 17:27:55
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 08:35:35 +/- 04:34:44.7450
# # NcmMSetCatalog: Current mean:   4.1511e+05   1.3219       0.69971     -1.3586       2.9896
# # NcmMSetCatalog: Current msd:    32870        0.0050382    0.0028883    0.0031768    0.0090343
# # NcmMSetCatalog: Current sd:     2.5461e+06   0.39026      0.22373      0.24607      0.69979
# # NcmMSetCatalog: Current var:    6.4826e+12   0.1523       0.050054     0.060552     0.48971
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.99156      0.97379      0.96351      1.0186       0.96824
# # NcmMSetCatalog: Maximal Shrink factor = 1.1387
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `12':
# # NcmMSetCatalog: Constant break point at `6':
# # NcmFitESMCMC:acceptance ratio 46.8182% (last update 13.8000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       12556.3853967583 (2n = 6), min(-2ln(L)) =       129.183940056355.
# # Task:NcmFitESMCMC, completed: 6000 of 400000, elapsed time: 00:13:43.4170
# # Task:NcmFitESMCMC, mean time: 00:00:00.1372 +/- 00:00:00.0398
# # Task:NcmFitESMCMC, time left: 15:01:09.7086 +/- 04:21:07.0903
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 17:28:59
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 08:30:08 +/- 04:21:07.0903
# # NcmMSetCatalog: Current mean:   3.8321e+05   1.3101       0.71046     -1.3692       2.9592
# # NcmMSetCatalog: Current msd:    30372        0.0046802    0.0027106    0.0030997    0.0084456
# # NcmMSetCatalog: Current sd:     2.4487e+06   0.37733      0.21854      0.2499       0.68091
# # NcmMSetCatalog: Current var:    5.9961e+12   0.14238      0.047758     0.062451     0.46364
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.99219      0.9762       0.96734      1.0331       0.97099
# # NcmMSetCatalog: Maximal Shrink factor = 1.15518
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `13':
# # NcmMSetCatalog: Constant break point at `6':
# # NcmFitESMCMC:acceptance ratio 43.7500% (last update 10.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       11682.2445246211 (2n = 6), min(-2ln(L)) =       129.183940056355.
# # Task:NcmFitESMCMC, completed: 6500 of 400000, elapsed time: 00:14:48.0506
# # Task:NcmFitESMCMC, mean time: 00:00:00.1366 +/- 00:00:00.0380
# # Task:NcmFitESMCMC, time left: 14:56:00.3574 +/- 04:09:23.2567
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 17:30:03
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 08:26:04 +/- 04:09:23.2567
# # NcmMSetCatalog: Current mean:   3.5586e+05   1.3001       0.71931     -1.3815       2.933
# # NcmMSetCatalog: Current msd:    28227        0.0043694    0.0025517    0.0031551    0.0079267
# # NcmMSetCatalog: Current sd:     2.3617e+06   0.36557      0.21349      0.26397      0.66319
# # NcmMSetCatalog: Current var:    5.5775e+12   0.13364      0.045578     0.069682     0.43982
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.99273      0.97833      0.97095      1.0442       0.97341
# # NcmMSetCatalog: Maximal Shrink factor = 1.14876
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `14':
# # NcmMSetCatalog: Constant break point at `6':
# # NcmFitESMCMC:acceptance ratio 40.8462% (last update  6.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):        11315.542977052 (2n = 6), min(-2ln(L)) =       129.183940056355.
# # Task:NcmFitESMCMC, completed: 7000 of 400000, elapsed time: 00:15:54.7112
# # Task:NcmFitESMCMC, mean time: 00:00:00.1364 +/- 00:00:00.0366
# # Task:NcmFitESMCMC, time left: 14:53:18.9112 +/- 03:59:31.4974
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 17:31:10
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 08:24:29 +/- 03:59:31.4974
# # NcmMSetCatalog: Current mean:   3.3216e+05   1.2914       0.72717     -1.3919       2.9103
# # NcmMSetCatalog: Current msd:    26365        0.0040973    0.0024107    0.0031569    0.0074665
# # NcmMSetCatalog: Current sd:     2.2833e+06   0.35483      0.20877      0.27339      0.64662
# # NcmMSetCatalog: Current var:    5.2135e+12   0.12591      0.043586     0.074744     0.41812
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.9932       0.98018      0.97418      1.059        0.97552
# # NcmMSetCatalog: Maximal Shrink factor = 1.16154
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `15':
# # NcmMSetCatalog: Constant break point at `6':
# # NcmFitESMCMC:acceptance ratio 38.5714% (last update  9.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       11002.3614194037 (2n = 6), min(-2ln(L)) =       129.183940056355.
# # Task:NcmFitESMCMC, completed: 7500 of 400000, elapsed time: 00:16:59.0500
# # Task:NcmFitESMCMC, mean time: 00:00:00.1359 +/- 00:00:00.0352
# # Task:NcmFitESMCMC, time left: 14:48:49.3672 +/- 03:50:12.2379
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 17:32:14
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 08:21:04 +/- 03:50:12.2379
# # NcmMSetCatalog: Current mean:   3.1142e+05   1.2837       0.73395     -1.4018       2.8903
# # NcmMSetCatalog: Current msd:    24734        0.003857     0.0022839    0.0031601    0.0070559
# # NcmMSetCatalog: Current sd:     2.2122e+06   0.34498      0.20428      0.28265      0.6311
# # NcmMSetCatalog: Current var:    4.894e+12    0.11901      0.041729     0.07989      0.39829
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.99362      0.98183      0.9772       1.0737       0.9774
# # NcmMSetCatalog: Maximal Shrink factor = 1.17545
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `16':
# # NcmMSetCatalog: Constant break point at `6':
# # NcmFitESMCMC:acceptance ratio 36.2933% (last update  4.4000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       10705.6803503071 (2n = 6), min(-2ln(L)) =       129.183940056355.
# # Task:NcmFitESMCMC, completed: 8000 of 400000, elapsed time: 00:18:06.3351
# # Task:NcmFitESMCMC, mean time: 00:00:00.1358 +/- 00:00:00.0340
# # Task:NcmFitESMCMC, time left: 14:47:09.4455 +/- 03:42:25.2744
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 17:33:22
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 08:20:31 +/- 03:42:25.2744
# # NcmMSetCatalog: Current mean:   2.9312e+05   1.2766       0.74008     -1.4104       2.8721
# # NcmMSetCatalog: Current msd:    23292        0.0036445    0.0021703    0.0031522    0.0066902
# # NcmMSetCatalog: Current sd:     2.1474e+06   0.33601      0.20009      0.29062      0.6168
# # NcmMSetCatalog: Current var:    4.6115e+12   0.1129       0.040036     0.08446      0.38045
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.99399      0.98322      0.97993      1.0875       0.97901
# # NcmMSetCatalog: Maximal Shrink factor = 1.18856
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `17':
# # NcmMSetCatalog: Constant break point at `6':
# # NcmFitESMCMC:acceptance ratio 35.0250% (last update 16.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       10131.2338537399 (2n = 6), min(-2ln(L)) =       129.183940056355.
# # Task:NcmFitESMCMC, completed: 8500 of 400000, elapsed time: 00:19:12.5152
# # Task:NcmFitESMCMC, mean time: 00:00:00.1356 +/- 00:00:00.0330
# # Task:NcmFitESMCMC, time left: 14:44:42.2381 +/- 03:35:08.4650
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 17:34:28
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 08:19:10 +/- 03:35:08.4650
# # NcmMSetCatalog: Current mean:   2.7685e+05   1.2702       0.74572     -1.4177       2.8557
# # NcmMSetCatalog: Current msd:    22009        0.0034547    0.0020682    0.0031275    0.0063611
# # NcmMSetCatalog: Current sd:     2.088e+06    0.32774      0.1962       0.2967       0.60346
# # NcmMSetCatalog: Current var:    4.3598e+12   0.10741      0.038496     0.088032     0.36417
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.99431      0.98447      0.98233      1.102        0.98045
# # NcmMSetCatalog: Maximal Shrink factor = 1.20394
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `18':
# # NcmMSetCatalog: Constant break point at `6':
# # NcmFitESMCMC:acceptance ratio 33.4941% (last update  9.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):        9309.8772145892 (2n = 6), min(-2ln(L)) =       129.183940056355.
# # Task:NcmFitESMCMC, completed: 9000 of 400000, elapsed time: 00:20:28.2541
# # Task:NcmFitESMCMC, mean time: 00:00:00.1365 +/- 00:00:00.0323
# # Task:NcmFitESMCMC, time left: 14:49:19.9553 +/- 03:30:11.7764
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 17:35:44
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 08:25:04 +/- 03:30:11.7764
# # NcmMSetCatalog: Current mean:   2.6229e+05   1.2641       0.75101     -1.4239       2.8403
# # NcmMSetCatalog: Current msd:    20861        0.003285     0.0019763    0.0030938    0.0060656
# # NcmMSetCatalog: Current sd:     2.0332e+06   0.32018      0.19262      0.30154      0.5912
# # NcmMSetCatalog: Current var:    4.1341e+12   0.10251      0.037104     0.090928     0.34952
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.99461      0.98557      0.98445      1.1169       0.98171
# # NcmMSetCatalog: Maximal Shrink factor = 1.22051
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `19':
# # NcmMSetCatalog: Constant break point at `6':
# # NcmFitESMCMC:acceptance ratio 32.2444% (last update 11.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       8726.45887433933 (2n = 6), min(-2ln(L)) =       129.183940056355.
# # Task:NcmFitESMCMC, completed: 9500 of 400000, elapsed time: 00:21:31.8569
# # Task:NcmFitESMCMC, mean time: 00:00:00.1360 +/- 00:00:00.0313
# # Task:NcmFitESMCMC, time left: 14:45:00.9405 +/- 03:23:35.1248
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 17:36:47
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 08:21:48 +/- 03:23:35.1248
# # NcmMSetCatalog: Current mean:   2.4919e+05   1.2578       0.75678     -1.4271       2.825
# # NcmMSetCatalog: Current msd:    19826        0.0031337    0.0018964    0.0030152    0.0058025
# # NcmMSetCatalog: Current sd:     1.9826e+06   0.31337      0.18964      0.30152      0.58025
# # NcmMSetCatalog: Current var:    3.9306e+12   0.0982       0.035962     0.090916     0.33669
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.99487      0.98636      0.98578      1.1228       0.9827
# # NcmMSetCatalog: Maximal Shrink factor = 1.22174
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `20':
# # NcmMSetCatalog: Constant break point at `6':
# # NcmFitESMCMC:acceptance ratio 33.0421% (last update 47.4000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       9602.70529093136 (2n = 6), min(-2ln(L)) =       128.651317327334.
# # Task:NcmFitESMCMC, completed: 10000 of 400000, elapsed time: 00:22:37.6492
# # Task:NcmFitESMCMC, mean time: 00:00:00.1358 +/- 00:00:00.0304
# # Task:NcmFitESMCMC, time left: 14:42:27.3622 +/- 03:17:49.6320
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 17:37:53
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 08:20:20 +/- 03:17:49.6320
# # NcmMSetCatalog: Current mean:   2.3733e+05   1.2522       0.76176     -1.4316       2.8113
# # NcmMSetCatalog: Current msd:    18889        0.0029952    0.0018215    0.0029626    0.0055597
# # NcmMSetCatalog: Current sd:     1.9355e+06   0.30691      0.18664      0.30358      0.5697
# # NcmMSetCatalog: Current var:    3.7462e+12   0.094196     0.034836     0.092158     0.32456
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.99511      0.98708      0.98709      1.1246       0.98362
# # NcmMSetCatalog: Maximal Shrink factor = 1.21657
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `21':
# # NcmMSetCatalog: Constant break point at `6':
# # NcmFitESMCMC:acceptance ratio 32.1100% (last update 14.4000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       7659.21888274305 (2n = 6), min(-2ln(L)) =       121.501110935325.
# # Task:NcmFitESMCMC, completed: 10500 of 400000, elapsed time: 00:23:49.3431
# # Task:NcmFitESMCMC, mean time: 00:00:00.1361 +/- 00:00:00.0298
# # Task:NcmFitESMCMC, time left: 14:43:40.8642 +/- 03:13:18.3129
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 17:39:05
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 08:22:46 +/- 03:13:18.3129
# # NcmMSetCatalog: Current mean:   2.2656e+05   1.2472       0.76616     -1.4365       2.799
# # NcmMSetCatalog: Current msd:    18036        0.002868     0.0017516    0.0029172    0.0053352
# # NcmMSetCatalog: Current sd:     1.8917e+06   0.3008       0.18371      0.30595      0.55957
# # NcmMSetCatalog: Current var:    3.5784e+12   0.090478     0.033749     0.093608     0.31311
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.99533      0.98775      0.98837      1.1262       0.98446
# # NcmMSetCatalog: Maximal Shrink factor = 1.21259
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `22':
# # NcmMSetCatalog: Constant break point at `6':
# # NcmFitESMCMC:acceptance ratio 31.1238% (last update 11.4000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       6353.01815364264 (2n = 6), min(-2ln(L)) =       121.501110935325.
# # Task:NcmFitESMCMC, completed: 11000 of 400000, elapsed time: 00:25:05.8970
# # Task:NcmFitESMCMC, mean time: 00:00:00.1369 +/- 00:00:00.0293
# # Task:NcmFitESMCMC, time left: 14:47:32.8935 +/- 03:09:42.8287
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 17:40:21
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 08:27:54 +/- 03:09:42.8287
# # NcmMSetCatalog: Current mean:   2.1671e+05   1.2427       0.7701      -1.4417       2.7879
# # NcmMSetCatalog: Current msd:    17257        0.002751     0.0016865    0.002873     0.0051277
# # NcmMSetCatalog: Current sd:     1.8507e+06   0.29501      0.18086      0.30809      0.54989
# # NcmMSetCatalog: Current var:    3.4249e+12   0.087034     0.03271      0.094921     0.30238
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.99553      0.98836      0.9896       1.1288       0.98524
# # NcmMSetCatalog: Maximal Shrink factor = 1.21167
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `23':
# # NcmMSetCatalog: Constant break point at `6':
# # NcmFitESMCMC:acceptance ratio 30.1091% (last update  8.8000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       5662.84815426976 (2n = 6), min(-2ln(L)) =       121.501110935325.
# # Task:NcmFitESMCMC, completed: 11500 of 400000, elapsed time: 00:26:14.3766
# # Task:NcmFitESMCMC, mean time: 00:00:00.1369 +/- 00:00:00.0286
# # Task:NcmFitESMCMC, time left: 14:46:25.9313 +/- 03:05:16.9011
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 17:41:30
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 08:27:56 +/- 03:05:16.9011
# # NcmMSetCatalog: Current mean:   2.0769e+05   1.2386       0.77382     -1.4454       2.7777
# # NcmMSetCatalog: Current msd:    16543        0.002643     0.0016261    0.0028195    0.0049349
# # NcmMSetCatalog: Current sd:     1.8122e+06   0.28953      0.17814      0.30887      0.54059
# # NcmMSetCatalog: Current var:    3.2841e+12   0.083826     0.031732     0.095398     0.29224
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.99571      0.98892      0.99068      1.1333       0.98595
# # NcmMSetCatalog: Maximal Shrink factor = 1.21396
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `24':
# # NcmMSetCatalog: Constant break point at `6':
# # NcmFitESMCMC:acceptance ratio 29.2696% (last update 10.8000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       4409.71527663228 (2n = 6), min(-2ln(L)) =       121.501110935325.
# # Task:NcmFitESMCMC, completed: 12000 of 400000, elapsed time: 00:27:24.0556
# # Task:NcmFitESMCMC, mean time: 00:00:00.1370 +/- 00:00:00.0280
# # Task:NcmFitESMCMC, time left: 14:45:57.1132 +/- 03:01:15.4079
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 17:42:39
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 08:28:37 +/- 03:01:15.4079
# # NcmMSetCatalog: Current mean:   1.9939e+05   1.2347       0.77752     -1.4479       2.7683
# # NcmMSetCatalog: Current msd:    15885        0.0025433    0.0015709    0.0027613    0.0047564
# # NcmMSetCatalog: Current sd:     1.7761e+06   0.28435      0.17563      0.30872      0.53178
# # NcmMSetCatalog: Current var:    3.1544e+12   0.080855     0.030847     0.095308     0.28279
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.99588      0.98943      0.99152      1.1384       0.98659
# # NcmMSetCatalog: Maximal Shrink factor = 1.21707
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `25':
# # NcmMSetCatalog: Constant break point at `6':
# # NcmFitESMCMC:acceptance ratio 28.6250% (last update 13.8000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       3595.11992084676 (2n = 6), min(-2ln(L)) =       121.501110935325.
# # Task:NcmFitESMCMC, completed: 12500 of 400000, elapsed time: 00:28:34.7294
# # Task:NcmFitESMCMC, mean time: 00:00:00.1372 +/- 00:00:00.0275
# # Task:NcmFitESMCMC, time left: 14:45:56.2318 +/- 02:57:34.2301
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 17:43:50
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 08:29:46 +/- 02:57:34.2301
# # NcmMSetCatalog: Current mean:   1.9173e+05   1.2311       0.78109     -1.4496       2.7594
# # NcmMSetCatalog: Current msd:    15278        0.0024509    0.0015197    0.0027013    0.0045904
# # NcmMSetCatalog: Current sd:     1.742e+06    0.27945      0.17327      0.30799      0.52338
# # NcmMSetCatalog: Current var:    3.0345e+12   0.07809      0.030023     0.094858     0.27393
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.99604      0.98989      0.99223      1.1437       0.98717
# # NcmMSetCatalog: Maximal Shrink factor = 1.22051
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `26':
# # NcmMSetCatalog: Constant break point at `6':
# # NcmFitESMCMC:acceptance ratio 27.8240% (last update  8.6000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):        3097.9768778599 (2n = 6), min(-2ln(L)) =       121.501110935325.
# # Task:NcmFitESMCMC, completed: 13000 of 400000, elapsed time: 00:29:35.0748
# # Task:NcmFitESMCMC, mean time: 00:00:00.1365 +/- 00:00:00.0268
# # Task:NcmFitESMCMC, time left: 14:40:41.9101 +/- 02:53:07.3807
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 17:44:50
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 08:25:32 +/- 02:53:07.3807
# # NcmMSetCatalog: Current mean:   1.8464e+05   1.2278       0.78449     -1.4507       2.7512
# # NcmMSetCatalog: Current msd:    14716        0.002365     0.0014719    0.0026421    0.0044354
# # NcmMSetCatalog: Current sd:     1.7098e+06   0.27478      0.17102      0.30698      0.51535
# # NcmMSetCatalog: Current var:    2.9234e+12   0.075507     0.029249     0.094236     0.26559
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.99618      0.99032      0.99284      1.149        0.9877
# # NcmMSetCatalog: Maximal Shrink factor = 1.22421
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `27':
# # NcmMSetCatalog: Constant break point at `5':
# # NcmFitESMCMC:acceptance ratio 27.1000% (last update  9.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       2596.09112352292 (2n = 6), min(-2ln(L)) =       121.501110935325.
# # Task:NcmFitESMCMC, completed: 13500 of 400000, elapsed time: 00:30:35.5605
# # Task:NcmFitESMCMC, mean time: 00:00:00.1360 +/- 00:00:00.0262
# # Task:NcmFitESMCMC, time left: 14:35:50.7863 +/- 02:48:58.4311
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 17:45:51
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 08:21:42 +/- 02:48:58.4311
# # NcmMSetCatalog: Current mean:   1.7805e+05   1.2246       0.78775     -1.4518       2.7434
# # NcmMSetCatalog: Current msd:    14193        0.002285     0.0014272    0.0025804    0.0042909
# # NcmMSetCatalog: Current sd:     1.6793e+06   0.27036      0.16887      0.30531      0.50771
# # NcmMSetCatalog: Current var:    2.8202e+12   0.073097     0.028517     0.093215     0.25777
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.99632      0.99072      0.99323      1.1496       0.98819
# # NcmMSetCatalog: Maximal Shrink factor = 1.22112
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `28':
# # NcmMSetCatalog: Constant break point at `5':
# # NcmFitESMCMC:acceptance ratio 26.5926% (last update 13.4000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):        1932.5811267385 (2n = 6), min(-2ln(L)) =       121.501110935325.
# # Task:NcmFitESMCMC, completed: 14000 of 400000, elapsed time: 00:31:41.8951
# # Task:NcmFitESMCMC, mean time: 00:00:00.1358 +/- 00:00:00.0257
# # Task:NcmFitESMCMC, time left: 14:33:57.3133 +/- 02:45:33.1727
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 17:46:57
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 08:20:55 +/- 02:45:33.1727
# ...
# # NcmMSetCatalog: Current sd:     1.4252e+06   0.23268      0.14919      0.31333      0.44117
# # NcmMSetCatalog: Current var:    2.0311e+12   0.054138     0.022257     0.098176     0.19463
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.99735      0.99356      0.99657      1.145        0.9917
# # NcmMSetCatalog: Maximal Shrink factor = 1.18418
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `39':
# # NcmMSetCatalog: Constant break point at `5':
# # NcmFitESMCMC:acceptance ratio 21.0632% (last update  8.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       291.309129330376 (2n = 6), min(-2ln(L)) =       94.9254760370414.
# # Task:NcmFitESMCMC, completed: 19500 of 400000, elapsed time: 00:43:10.9602
# # Task:NcmFitESMCMC, mean time: 00:00:00.1329 +/- 00:00:00.0213
# # Task:NcmFitESMCMC, time left: 14:02:36.3933 +/- 02:15:16.8736
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 17:58:26
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 08:01:03 +/- 02:15:16.8736
# # NcmMSetCatalog: Current mean:   1.2164e+05   1.1963       0.81561     -1.4699       2.6749
# # NcmMSetCatalog: Current msd:    9709.9       0.0015882    0.0010217    0.0022934    0.003015
# # NcmMSetCatalog: Current sd:     1.3902e+06   0.22739      0.14629      0.32837      0.43169
# # NcmMSetCatalog: Current var:    1.9328e+12   0.051706     0.021401     0.10783      0.18636
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.99747      0.99389      0.99717      1.1386       0.99212
# # NcmMSetCatalog: Maximal Shrink factor = 1.17088
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `41':
# # NcmMSetCatalog: Constant break point at `5':
# # NcmFitESMCMC:acceptance ratio 20.5550% (last update  9.8000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       208.220412098386 (2n = 6), min(-2ln(L)) =       94.9254760370414.
# # Task:NcmFitESMCMC, completed: 20500 of 400000, elapsed time: 00:45:09.7924
# # Task:NcmFitESMCMC, mean time: 00:00:00.1322 +/- 00:00:00.0207
# # Task:NcmFitESMCMC, time left: 13:56:03.7895 +/- 02:10:55.8823
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 18:00:25
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 07:56:29 +/- 02:10:55.8823
# # NcmMSetCatalog: Current mean:   1.1875e+05   1.1949       0.81676     -1.4755       2.6712
# # NcmMSetCatalog: Current msd:    9479.5       0.0015518    0.0010001    0.0023655    0.0029479
# # NcmMSetCatalog: Current sd:     1.3737e+06   0.22487      0.14492      0.34279      0.42719
# # NcmMSetCatalog: Current var:    1.8871e+12   0.050569     0.021002     0.1175       0.1825
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.99753      0.99405      0.9975       1.1299       0.99231
# # NcmMSetCatalog: Maximal Shrink factor = 1.15743
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `42':
# # NcmMSetCatalog: Constant break point at `5':
# # NcmFitESMCMC:acceptance ratio 20.3805% (last update 13.4000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       166.207166331025 (2n = 6), min(-2ln(L)) =       94.9254760370414.
# # Task:NcmFitESMCMC, completed: 21000 of 400000, elapsed time: 00:46:18.4282
# # Task:NcmFitESMCMC, mean time: 00:00:00.1323 +/- 00:00:00.0205
# # Task:NcmFitESMCMC, time left: 13:55:43.6147 +/- 02:09:18.0640
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 18:01:34
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 07:57:17 +/- 02:09:18.0640
# # NcmMSetCatalog: Current mean:   1.1599e+05   1.1935       0.81789     -1.4807       2.6676
# # NcmMSetCatalog: Current msd:    9259.9       0.0015171    0.00097935   0.0024255    0.0028838
# # NcmMSetCatalog: Current sd:     1.3578e+06   0.22245      0.1436       0.35564      0.42285
# # NcmMSetCatalog: Current var:    1.8435e+12   0.049483     0.020621     0.12648      0.1788
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.99759      0.9942       0.99787      1.1258       0.9925
# # NcmMSetCatalog: Maximal Shrink factor = 1.15027
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `43':
# # NcmMSetCatalog: Constant break point at `5':
# # NcmFitESMCMC:acceptance ratio 20.1857% (last update 12.2000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):        128.89666314998 (2n = 6), min(-2ln(L)) =       94.9254760370414.
# # Task:NcmFitESMCMC, completed: 21500 of 400000, elapsed time: 00:47:24.1093
# # Task:NcmFitESMCMC, mean time: 00:00:00.1323 +/- 00:00:00.0202
# # Task:NcmFitESMCMC, time left: 13:54:29.0719 +/- 02:07:35.2856
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 18:02:39
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 07:57:09 +/- 02:07:35.2856
# # NcmMSetCatalog: Current mean:   1.1336e+05   1.1921       0.81889     -1.4871       2.6641
# # NcmMSetCatalog: Current msd:    9050.2       0.0014839    0.0009596    0.0025033    0.0028225
# # NcmMSetCatalog: Current sd:     1.3424e+06   0.2201       0.14233      0.3713       0.41865
# # NcmMSetCatalog: Current var:    1.8019e+12   0.048444     0.020258     0.13786      0.17526
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.99765      0.99435      0.99834      1.1211       0.99268
# # NcmMSetCatalog: Maximal Shrink factor = 1.14293
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `44':
# # NcmMSetCatalog: Constant break point at `5':
# # NcmFitESMCMC:acceptance ratio 20.0791% (last update 15.6000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       106.584892667211 (2n = 6), min(-2ln(L)) =       94.9254760370414.
# # Task:NcmFitESMCMC, completed: 22000 of 400000, elapsed time: 00:48:31.4132
# # Task:NcmFitESMCMC, mean time: 00:00:00.1323 +/- 00:00:00.0200
# # Task:NcmFitESMCMC, time left: 13:53:42.9191 +/- 02:06:00.2066
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 18:03:47
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 07:57:30 +/- 02:06:00.2066
# # NcmMSetCatalog: Current mean:   1.1084e+05   1.1908       0.81971     -1.4955       2.6608
# # NcmMSetCatalog: Current msd:    8849.8       0.0014521    0.00094077   0.0026082    0.0027638
# # NcmMSetCatalog: Current sd:     1.3275e+06   0.21782      0.14112      0.39123      0.41458
# # NcmMSetCatalog: Current var:    1.7622e+12   0.047446     0.019914     0.15306      0.17187
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.9977       0.9945       0.99882      1.1149       0.99285
# # NcmMSetCatalog: Maximal Shrink factor = 1.13383
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `45':
# # NcmMSetCatalog: Constant break point at `5':
# # NcmFitESMCMC:acceptance ratio 20.1500% (last update 23.2000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       98.3713281795472 (2n = 6), min(-2ln(L)) =       92.6372925798577.
# # Task:NcmFitESMCMC, completed: 22500 of 400000, elapsed time: 00:49:38.4860
# # Task:NcmFitESMCMC, mean time: 00:00:00.1324 +/- 00:00:00.0198
# # Task:NcmFitESMCMC, time left: 13:52:51.9891 +/- 02:04:27.5391
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 18:04:54
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 07:57:46 +/- 02:04:27.5391
# # NcmMSetCatalog: Current mean:   1.0844e+05   1.1897       0.82029     -1.5069       2.6575
# # NcmMSetCatalog: Current msd:    8658         0.0014217    0.00092309   0.0027517    0.0027077
# # NcmMSetCatalog: Current sd:     1.3131e+06   0.2156       0.13999      0.41732      0.41064
# # NcmMSetCatalog: Current var:    1.7241e+12   0.046485     0.019598     0.17415      0.16862
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.99775      0.99465      0.99926      1.1031       0.99301
# # NcmMSetCatalog: Maximal Shrink factor = 1.11871
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `46':
# # NcmMSetCatalog: Constant break point at `5':
# # NcmFitESMCMC:acceptance ratio 20.2222% (last update 23.4000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):        84.445180618114 (2n = 6), min(-2ln(L)) =       92.6372925798577.
# # Task:NcmFitESMCMC, completed: 23000 of 400000, elapsed time: 00:50:46.1595
# # Task:NcmFitESMCMC, mean time: 00:00:00.1324 +/- 00:00:00.0196
# # Task:NcmFitESMCMC, time left: 13:52:10.1294 +/- 02:02:59.2027
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 18:06:02
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 07:58:12 +/- 02:02:59.2027
# # NcmMSetCatalog: Current mean:   1.0613e+05   1.1886       0.82065     -1.5214       2.6543
# # NcmMSetCatalog: Current msd:    8474.4       0.0013924    0.00090606   0.0029072    0.0026538
# # NcmMSetCatalog: Current sd:     1.2991e+06   0.21345      0.1389       0.44567      0.40682
# # NcmMSetCatalog: Current var:    1.6877e+12   0.04556      0.019292     0.19862      0.1655
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.99779      0.99479      0.99963      1.0912       0.99315
# # NcmMSetCatalog: Maximal Shrink factor = 1.10418
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `47':
# # NcmMSetCatalog: Constant break point at `5':
# # NcmFitESMCMC:acceptance ratio 20.9043% (last update 51.6000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       68.6185156213451 (2n = 6), min(-2ln(L)) =       92.6372925798577.
# # Task:NcmFitESMCMC, completed: 23500 of 400000, elapsed time: 00:51:46.1934
# # Task:NcmFitESMCMC, mean time: 00:00:00.1322 +/- 00:00:00.0193
# # Task:NcmFitESMCMC, time left: 13:49:24.7875 +/- 02:01:16.3400
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 18:07:02
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 07:56:26 +/- 02:01:16.3400
# # NcmMSetCatalog: Current mean:   1.0392e+05   1.1876       0.82102     -1.5367       2.6512
# # NcmMSetCatalog: Current msd:    8298.4       0.0013643    0.00088955   0.0030376    0.0026022
# # NcmMSetCatalog: Current sd:     1.2856e+06   0.21136      0.13781      0.47058      0.40313
# # NcmMSetCatalog: Current var:    1.6527e+12   0.044673     0.018991     0.22145      0.16252
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.99784      0.99491      1            1.0841       0.99329
# # NcmMSetCatalog: Maximal Shrink factor = 1.09563
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `48':
# # NcmMSetCatalog: Constant break point at `5':
# # NcmFitESMCMC:acceptance ratio 21.5106% (last update 49.4000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       55.7346806505866 (2n = 6), min(-2ln(L)) =       92.6372925798577.
# # Task:NcmFitESMCMC, completed: 24000 of 400000, elapsed time: 00:52:46.9309
# # Task:NcmFitESMCMC, mean time: 00:00:00.1320 +/- 00:00:00.0191
# # Task:NcmFitESMCMC, time left: 13:46:54.8735 +/- 01:59:38.5084
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 18:08:02
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 07:54:57 +/- 01:59:38.5084
# # NcmMSetCatalog: Current mean:   1.018e+05    1.1866       0.82113     -1.559        2.6481
# # NcmMSetCatalog: Current msd:    8129.6       0.0013374    0.00087317   0.0032323    0.0025531
# # NcmMSetCatalog: Current sd:     1.2725e+06   0.20933      0.13667      0.50593      0.39962
# # NcmMSetCatalog: Current var:    1.6192e+12   0.043818     0.01868      0.25597      0.15969
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.99788      0.99503      1.0003       1.0716       0.99343
# # NcmMSetCatalog: Maximal Shrink factor = 1.08173
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `49':
# # NcmMSetCatalog: Constant break point at `5':
# # NcmFitESMCMC:acceptance ratio 22.1542% (last update 52.4000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       79.6139370724714 (2n = 6), min(-2ln(L)) =       92.6372925798577.
# # Task:NcmFitESMCMC, completed: 24500 of 400000, elapsed time: 00:53:55.7521
# # Task:NcmFitESMCMC, mean time: 00:00:00.1321 +/- 00:00:00.0189
# # Task:NcmFitESMCMC, time left: 13:46:32.5063 +/- 01:58:21.2757
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 18:09:11
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 07:55:44 +/- 01:58:21.2757
# # NcmMSetCatalog: Current mean:   99770        1.1856       0.82099     -1.5889       2.6448
# # NcmMSetCatalog: Current msd:    7967.5       0.0013114    0.00085718   0.003487     0.0025063
# # NcmMSetCatalog: Current sd:     1.2598e+06   0.20736      0.13553      0.55134      0.39629
# # NcmMSetCatalog: Current var:    1.587e+12    0.042997     0.018369     0.30397      0.15704
# # NcmMSetCatalog: Current tau:    1            1            1            1            1
# # NcmMSetCatalog: Current skfac:  0.99793      0.99515      1.0006       1.0577       0.99356
# # NcmMSetCatalog: Maximal Shrink factor = 1.0668
# #----------------------------------------------------------------------------------
# # NcmMSetCatalog: Computing the constant break point for parameter `0', sample size `50':
# # NcmMSetCatalog: Constant break point at `5':
# # NcmFitESMCMC:acceptance ratio 22.6612% (last update 47.0000%), offboard ratio  0.0000% (last update  0.0000%).
# # NcmFitESMCMC:last ensemble variance of -2ln(L):       58.5556944369227 (2n = 6), min(-2ln(L)) =       92.6372925798577.
# # Task:NcmFitESMCMC, completed: 25000 of 400000, elapsed time: 00:54:57.1102
# # Task:NcmFitESMCMC, mean time: 00:00:00.1319 +/- 00:00:00.0187
# # Task:NcmFitESMCMC, time left: 13:44:16.4080 +/- 01:56:50.5516
# # Task:NcmFitESMCMC, current time:        Tue Nov 07 2023, 18:10:12
# # Task:NcmFitESMCMC, estimated to end at: Wed Nov 08 2023, 07:54:29 +/- 01:56:50.5516
