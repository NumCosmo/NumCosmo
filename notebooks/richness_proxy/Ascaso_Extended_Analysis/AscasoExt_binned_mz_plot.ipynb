# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.insert(0, "/global/homes/c/cinlima/NumCosmo/notebooks/richness_proxy/")

from numcosmo_py import Ncm, Nc, GObject

from richness_mass_calib import create_richness_mass_calib
import numpy as np
import math
import sys
import os.path

from astropy.io import fits
from astropy.table import Table
from scipy import stats

import matplotlib.pyplot as plt

# %%
#Settings
Ncm.cfg_init()

# %matplotlib inline
sys.path.insert(0, "/global/homes/c/cinlima/gcr-catalogs")
sys.path.insert(0, "/global/homes/c/cinlima/NumCosmo/notebooks/richness_proxy")


# DC2 data
DC2_halos_m200c = fits.open(
    "/global/cfs/projectdirs/lsst/groups/CL/cosmoDC2_v1.1.4/extragal/full/halos/halos_m200c_13.0.fits")

dt_halos = Table(DC2_halos_m200c[1].data)

lnM = np.log(dt_halos["m200c"])  # ln(mass)
z = dt_halos["redshift_true"]  # redshift
lnR = np.log(dt_halos["richness"])  # ln(richness)



def compute_res(rich_model):

    lnR_mean = np.array(
        [rich_model.get_mean_richness(lnM[i], z[i]) for i in range(len(dt_halos))]
    )
    lnR_std = np.array(
        [rich_model.get_std_richness(lnM[i], z[i]) for i in range(len(dt_halos))]
    )
    
    lnr_cut = np.array(
        [rich_model.get_cut(lnM[i], z[i]) for i in range(len(dt_halos))])

    abs_err = (lnR - lnR_mean) / lnR_std
    # Data cut
    sigma_cut = 5.0

    sigma_cut_array = np.abs(abs_err) < sigma_cut
    print(f"Cutting {sigma_cut}-sigma, {np.sum(np.logical_not(sigma_cut_array))}")

    lnR_mean = lnR_mean[sigma_cut_array]
    z_sigma_cut = z[sigma_cut_array]
    lnM_sigma_cut = lnM[sigma_cut_array]
    abs_err = abs_err[sigma_cut_array]
    lnR_ext = lnR[sigma_cut_array]
    lnr_cut = lnr_cut[sigma_cut_array] 
    
    return abs_err, lnR_mean, z_sigma_cut, lnM_sigma_cut, lnr_cut, lnR_ext

# %%
# redshift bins
z_0 = 0.0
z_1 = 0.1
halos_bin_z =[]

for i in range(31):
    cut_z = np.logical_and (dt_halos['redshift_true'] > z_0, dt_halos['redshift_true'] < z_1)
    halos_bin_z.append(dt_halos[cut_z])
    z_0 = z_0 + 0.1
    z_1 = z_1 + 0.1

# mass bins
label = []
halos_bin_mz =[]
for i in range(30):
    lnM_0 = min(lnM)
    lnM_1 = min(lnM) + 0.5

    for j in range(9):
        cut = np.logical_and (np.log(halos_bin_z[i]["m200c"]) > lnM_0, np.log(halos_bin_z[i]["m200c"]) < lnM_1)
        halos_bin_mz.append(halos_bin_z[i][cut])
        label.append(f"{min(halos_bin_z[i]['redshift_true']):.3f} < z < {max(halos_bin_z[i]['redshift_true']):.3f}\n{lnM_0:.3f} < lnM < {lnM_1:.3f}")
        lnM_0 = lnM_0 + 0.5
        lnM_1 = lnM_1 + 0.5

# %%
fit_results_ascaso = []
fit_results_ext = []

mean_ext_list=[]

for i in range(len(halos_bin_mz)):
    
    if len(halos_bin_mz[i]) == 0:
        fit_results_ascaso.append(([], [], [], [], [] ,[]))
        fit_results_ext.append(([], [], [], [], [] ,[]))

    
    else:
        rmdata = create_richness_mass_calib(halos_bin_mz[i])

        use_ascaso = False

        ascaso = Nc.ClusterMassAscaso()

        ascaso.param_set_by_name("mup0", 4.45393539397061)
        ascaso.param_set_by_name("cut", 1e15)
        ascaso.param_set_by_name("mup1", 0.0)
        ascaso.param_set_by_name("mup2", 0.0)
        ascaso.param_set_by_name("sigmap0", 0.227197277810533)
        ascaso.param_set_by_name("sigmap1", 0.0)
        ascaso.param_set_by_name("sigmap2", 0.0)


        ascaso.param_set_ftype(0, Ncm.ParamType.FREE)
        ascaso.param_set_ftype(1, Ncm.ParamType.FIXED)
        ascaso.param_set_ftype(2, Ncm.ParamType.FIXED)
        ascaso.param_set_ftype(3, Ncm.ParamType.FREE)
        ascaso.param_set_ftype(4, Ncm.ParamType.FIXED)
        ascaso.param_set_ftype(5, Ncm.ParamType.FIXED)
        ascaso.param_set_ftype(6, Ncm.ParamType.FIXED)

        lnrich_ext = Nc.ClusterMassLnrichExt()
        lnrich_ext.param_set_by_name("mu", 4.60456407051582)
        lnrich_ext.param_set_by_name("muM1", 0.0)
        lnrich_ext.param_set_by_name("muZ1", 0.0)
        lnrich_ext.param_set_by_name("muM2", 0.0)
        lnrich_ext.param_set_by_name("muZ2", 0.0)
        lnrich_ext.param_set_by_name("muMZ", 0.0)
        
        lnrich_ext.param_set_by_name("sigma0", 0.288099083637692)
        lnrich_ext.param_set_by_name("sigmaM1", 0.0)
        lnrich_ext.param_set_by_name("sigmaZ1", 0.0)
        lnrich_ext.param_set_by_name("sigmaM2", 0.0)
        lnrich_ext.param_set_by_name("sigmaZ2", 0.0)
        lnrich_ext.param_set_by_name("sigmaMZ", 0.0)


        lnrich_ext.param_set_by_name("cut", 1e15)
        lnrich_ext.param_set_by_name("cutM1", 0)
        lnrich_ext.param_set_by_name("cutZ1", 0)


        lnrich_ext.param_set_ftype(0, Ncm.ParamType.FREE)
        lnrich_ext.param_set_ftype(1, Ncm.ParamType.FIXED)
        lnrich_ext.param_set_ftype(2, Ncm.ParamType.FIXED)
        lnrich_ext.param_set_ftype(3, Ncm.ParamType.FIXED)
        lnrich_ext.param_set_ftype(4, Ncm.ParamType.FIXED)
        lnrich_ext.param_set_ftype(5, Ncm.ParamType.FIXED)
        lnrich_ext.param_set_ftype(6, Ncm.ParamType.FIXED)

        lnrich_ext.param_set_ftype(7, Ncm.ParamType.FREE)
        lnrich_ext.param_set_ftype(8, Ncm.ParamType.FIXED)
        lnrich_ext.param_set_ftype(9, Ncm.ParamType.FIXED)
        lnrich_ext.param_set_ftype(10, Ncm.ParamType.FIXED)
        lnrich_ext.param_set_ftype(11, Ncm.ParamType.FIXED)

        lnrich_ext.param_set_ftype(12, Ncm.ParamType.FIXED)
        lnrich_ext.param_set_ftype(13, Ncm.ParamType.FIXED)
        lnrich_ext.param_set_ftype(14, Ncm.ParamType.FIXED)

        mset_ascaso = Ncm.MSet()
        mset_ascaso.set(ascaso)

        mset_ext = Ncm.MSet()
        mset_ext.set(lnrich_ext)

        dset = Ncm.Dataset.new()
        dset.append_data(rmdata)

        lh = Ncm.Likelihood.new(dset)

        fit_ascaso = Ncm.Fit.new( Ncm.FitType.NLOPT, "ln-neldermead", lh, mset_ascaso, Ncm.FitGradType.NUMDIFF_CENTRAL )
        fit_ext = Ncm.Fit.new( Ncm.FitType.NLOPT, "ln-neldermead", lh, mset_ext, Ncm.FitGradType.NUMDIFF_CENTRAL )

        fit_ascaso.run_restart(Ncm.FitRunMsgs.SIMPLE, 1.0e-3, 0.0, None, None)
        fit_ext.run_restart(Ncm.FitRunMsgs.SIMPLE, 1.0e-3, 0.0, None, None)
        
        res_ascaso, lnR_mean_ascaso, z_sigma_cut_ascaso, lnM_sigma_cut_ascaso, lnr_cut_ascaso, lnR_ascaso  = compute_res(ascaso)

        res_ext, lnR_mean_ext, z_sigma_cut_ext, lnM_sigma_cut_ext, lnr_cut_ext, lnR_ext  = compute_res(lnrich_ext)

        fit_results_ascaso.append((res_ascaso, lnR_mean_ascaso, z_sigma_cut_ascaso, lnM_sigma_cut_ascaso, lnr_cut_ascaso, lnR_ascaso))
        fit_results_ext.append((res_ext, lnR_mean_ext, z_sigma_cut_ext, lnM_sigma_cut_ext, lnr_cut_ext, lnR_ext))
        mean_ext_list.append(lnR_mean_ext)
# Out:
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0006570
# #  iteration            [000081]
# #  function evaluations [000083]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000167]
# #  m2lnL     =     134.276741619888 (     134.27674 )
# #  Fit parameters:
# #     1.57814408555312     0.451187951631736
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 27341.940837573
# #  - relative improvement: 0.995112983028582
# #  - m2lnL_0  :            27476.2175791929
# #  - m2lnL_1  :            134.276741619888
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0003850
# #  iteration            [000046]
# #  function evaluations [000048]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000167]
# #  m2lnL     =     134.276741619888 (     134.27674 )
# #  Fit parameters:
# #     1.57814408555312     0.451187951631736
# #----------------------------------------------------------------------------------
# # Restarting:              no
# #  - absolute improvement: 0
# #  - relative improvement: 0
# #  - m2lnL_1  :            134.276741619888
# #  - m2lnL_2  :            134.276741619888
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #..............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0005260
# #  iteration            [000053]
# #  function evaluations [000055]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000167]
# #  m2lnL     =      907.53603990463 (     907.53604 )
# #  Fit parameters:
# #     6                   -1.18062413871288
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 17969.6498030042
# #  - relative improvement: 0.951924187881768
# #  - m2lnL_0  :            18877.1858429088
# #  - m2lnL_1  :            907.53603990463
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #..................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0007790
# #  iteration            [000098]
# #  function evaluations [000100]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000167]
# #  m2lnL     =     333.784743061531 (     333.78474 )
# #  Fit parameters:
# #     0.957031250000013   -0.199618279337866
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 573.751296843098
# #  - relative improvement: 0.632207726872634
# #  - m2lnL_1  :            907.53603990463
# #  - m2lnL_2  :            333.784743061531
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0006220
# #  iteration            [000071]
# #  function evaluations [000073]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000167]
# #  m2lnL     =     133.944105257721 (     133.94411 )
# #  Fit parameters:
# #     1.58070916446747    -0.0462527715035659
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 199.84063780381
# #  - relative improvement: 0.598711121337773
# #  - m2lnL_2  :            333.784743061531
# #  - m2lnL_3  :            133.944105257721
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0004200
# #  iteration            [000047]
# #  function evaluations [000049]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000167]
# #  m2lnL     =     133.944105118627 (     133.94411 )
# #  Fit parameters:
# #     1.58077012291926    -0.0462447412093112
# #----------------------------------------------------------------------------------
# # Restarting:              no
# #  - absolute improvement: 1.39094339601797e-07
# #  - relative improvement: 1.03845062337134e-09
# #  - m2lnL_3  :            133.944105257721
# #  - m2lnL_4  :            133.944105118627
# Cutting 5.0-sigma, 10940
# Cutting 5.0-sigma, 25007
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0003890
# #  iteration            [000073]
# #  function evaluations [000075]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000103]
# #  m2lnL     =      69.063360373706 (      69.06336 )
# #  Fit parameters:
# #     1.89062861743216     0.421358439349756
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 13492.2254741064
# #  - relative improvement: 0.994907315874129
# #  - m2lnL_0  :            13561.2888344801
# #  - m2lnL_1  :            69.063360373706
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0002520
# #  iteration            [000045]
# #  function evaluations [000047]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000103]
# #  m2lnL     =     69.0633600079285 (      69.06336 )
# #  Fit parameters:
# #     1.8905866545406      0.421347814479236
# #----------------------------------------------------------------------------------
# # Restarting:              no
# #  - absolute improvement: 3.65777481192708e-07
# #  - relative improvement: 5.29625953926169e-09
# #  - m2lnL_1  :            69.063360373706
# #  - m2lnL_2  :            69.0633600079285
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #..............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0002890
# #  iteration            [000050]
# #  function evaluations [000052]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000103]
# #  m2lnL     =      548.53799112669 (     548.53799 )
# #  Fit parameters:
# #     6                   -1.27427417755127
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 8878.10690967525
# #  - relative improvement: 0.941809838293577
# #  - m2lnL_0  :            9426.64490080194
# #  - m2lnL_1  :            548.53799112669
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #...................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0005820
# #  iteration            [000106]
# #  function evaluations [000108]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000103]
# #  m2lnL     =     68.8151125666116 (     68.815113 )
# #  Fit parameters:
# #     1.89280937609016    -0.0441314927452859
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 479.722878560078
# #  - relative improvement: 0.874548137631696
# #  - m2lnL_1  :            548.53799112669
# #  - m2lnL_2  :            68.8151125666116
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0002680
# #  iteration            [000047]
# #  function evaluations [000049]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000103]
# #  m2lnL     =     68.8151125666116 (     68.815113 )
# #  Fit parameters:
# #     1.89280937609016    -0.0441314927452859
# #----------------------------------------------------------------------------------
# # Restarting:              no
# #  - absolute improvement: 0
# #  - relative improvement: 0
# #  - m2lnL_2  :            68.8151125666116
# #  - m2lnL_3  :            68.8151125666116
# Cutting 5.0-sigma, 6245
# Cutting 5.0-sigma, 13096
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0002670
# #  iteration            [000080]
# #  function evaluations [000082]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000059]
# #  m2lnL     =     30.6881598753509 (      30.68816 )
# #  Fit parameters:
# #     2.11097146460893     0.390000481306419
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 6539.90160748114
# #  - relative improvement: 0.995329466461624
# #  - m2lnL_0  :            6570.58976735649
# #  - m2lnL_1  :            30.6881598753509
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0001570
# #  iteration            [000048]
# #  function evaluations [000050]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000059]
# #  m2lnL     =     30.6881598753509 (      30.68816 )
# #  Fit parameters:
# #     2.11097146460893     0.390000481306419
# #----------------------------------------------------------------------------------
# # Restarting:              no
# #  - absolute improvement: 0
# #  - relative improvement: 0
# #  - m2lnL_1  :            30.6881598753509
# #  - m2lnL_2  :            30.6881598753509
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #..............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0001920
# #  iteration            [000054]
# #  function evaluations [000056]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000059]
# #  m2lnL     =     312.179855341373 (     312.17986 )
# #  Fit parameters:
# #     6                   -1.44596059244126
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 4302.08717761292
# #  - relative improvement: 0.932344649082544
# #  - m2lnL_0  :            4614.2670329543
# #  - m2lnL_1  :            312.179855341373
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.....................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0004050
# #  iteration            [000120]
# #  function evaluations [000122]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000059]
# #  m2lnL     =     30.7796960068956 (     30.779696 )
# #  Fit parameters:
# #     2.11108041393403    -0.0404535650111937
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 281.400159334478
# #  - relative improvement: 0.901403964797032
# #  - m2lnL_1  :            312.179855341373
# #  - m2lnL_2  :            30.7796960068956
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #..............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0001770
# #  iteration            [000050]
# #  function evaluations [000052]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000059]
# #  m2lnL     =     30.7796956107356 (     30.779696 )
# #  Fit parameters:
# #     2.11112178795241    -0.040444600087444
# #----------------------------------------------------------------------------------
# # Restarting:              no
# #  - absolute improvement: 3.9616004698928e-07
# #  - relative improvement: 1.28708238996424e-08
# #  - m2lnL_2  :            30.7796960068956
# #  - m2lnL_3  :            30.7796956107356
# Cutting 5.0-sigma, 5023
# Cutting 5.0-sigma, 8409
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0002610
# #  iteration            [000080]
# #  function evaluations [000082]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000044]
# #  m2lnL     =     41.9038523088631 (     41.903852 )
# #  Fit parameters:
# #     2.57398722725631     0.478231236834914
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 3239.04774988265
# #  - relative improvement: 0.987228140676969
# #  - m2lnL_0  :            3280.95160219151
# #  - m2lnL_1  :            41.9038523088631
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0001190
# #  iteration            [000046]
# #  function evaluations [000048]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000044]
# #  m2lnL     =     41.9038516080989 (     41.903852 )
# #  Fit parameters:
# #     2.57393938950047     0.478225738438237
# #----------------------------------------------------------------------------------
# # Restarting:              no
# #  - absolute improvement: 7.00764168470869e-07
# #  - relative improvement: 1.67231442900693e-08
# #  - m2lnL_1  :            41.9038523088631
# #  - m2lnL_2  :            41.9038516080989
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #..............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0001640
# #  iteration            [000058]
# #  function evaluations [000060]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000044]
# #  m2lnL     =     223.738989860634 (     223.73899 )
# #  Fit parameters:
# #     6                   -1.5826585750957
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 2137.5647054818
# #  - relative improvement: 0.905247685716179
# #  - m2lnL_0  :            2361.30369534244
# #  - m2lnL_1  :            223.738989860634
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #...................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0002720
# #  iteration            [000101]
# #  function evaluations [000103]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000044]
# #  m2lnL     =     41.3277325645437 (     41.327733 )
# #  Fit parameters:
# #     2.58360630241393    -0.0945191220561307
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 182.41125729609
# #  - relative improvement: 0.815285960706775
# #  - m2lnL_1  :            223.738989860634
# #  - m2lnL_2  :            41.3277325645437
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0001290
# #  iteration            [000045]
# #  function evaluations [000047]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000044]
# #  m2lnL     =     41.3277322623284 (     41.327732 )
# #  Fit parameters:
# #     2.58358344143696    -0.0945395756696186
# #----------------------------------------------------------------------------------
# # Restarting:              no
# #  - absolute improvement: 3.02215255487681e-07
# #  - relative improvement: 7.3126502891417e-09
# #  - m2lnL_2  :            41.3277325645437
# #  - m2lnL_3  :            41.3277322623284
# Cutting 5.0-sigma, 125
# Cutting 5.0-sigma, 953
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0000750
# #  iteration            [000078]
# #  function evaluations [000080]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000006]
# #  m2lnL     =     1.21932122920829 (     1.2193212 )
# #  Fit parameters:
# #     2.83312536742358     0.327270227316565
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 409.905045732446
# #  - relative improvement: 0.997034179126332
# #  - m2lnL_0  :            411.124366961654
# #  - m2lnL_1  :            1.21932122920829
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0000410
# #  iteration            [000048]
# #  function evaluations [000050]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000006]
# #  m2lnL     =     1.21932122185962 (     1.2193212 )
# #  Fit parameters:
# #     2.83311711101025     0.327284137311508
# #----------------------------------------------------------------------------------
# # Restarting:              no
# #  - absolute improvement: 7.34866523188771e-09
# #  - relative improvement: 6.02684924682171e-09
# #  - m2lnL_1  :            1.21932122920829
# #  - m2lnL_2  :            1.21932122185962
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0000640
# #  iteration            [000077]
# #  function evaluations [000079]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000006]
# #  m2lnL     =     1.19794023555238 (     1.1979402 )
# #  Fit parameters:
# #     2.83583197167835    -0.0262463344702828
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 302.758892687806
# #  - relative improvement: 0.996058847488207
# #  - m2lnL_0  :            303.956832923359
# #  - m2lnL_1  :            1.19794023555238
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0000430
# #  iteration            [000048]
# #  function evaluations [000050]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000006]
# #  m2lnL     =     1.19794023555238 (     1.1979402 )
# #  Fit parameters:
# #     2.83583197167835    -0.0262463344702828
# #----------------------------------------------------------------------------------
# # Restarting:              no
# #  - absolute improvement: 0
# #  - relative improvement: 0
# #  - m2lnL_1  :            1.19794023555238
# #  - m2lnL_2  :            1.19794023555238
# Cutting 5.0-sigma, 4497
# Cutting 5.0-sigma, 2535
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0000780
# #  iteration            [000084]
# #  function evaluations [000086]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000005]
# #  m2lnL     =    -4.63592504103009 (     -4.635925 )
# #  Fit parameters:
# #     3.19219450345441     0.217782716602718
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 215.911096158819
# #  - relative improvement: 1.02194259276423
# #  - m2lnL_0  :            211.275171117789
# #  - m2lnL_1  :            -4.63592504103009
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0000390
# #  iteration            [000049]
# #  function evaluations [000051]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000005]
# #  m2lnL     =    -4.63592504103009 (     -4.635925 )
# #  Fit parameters:
# #     3.19219450345441     0.217782716602718
# #----------------------------------------------------------------------------------
# # Restarting:              no
# #  - absolute improvement: 0
# #  - relative improvement: -0
# #  - m2lnL_1  :            -4.63592504103009
# #  - m2lnL_2  :            -4.63592504103009
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #..................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0000750
# #  iteration            [000099]
# #  function evaluations [000101]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000005]
# #  m2lnL     =    -4.50370143679248 (    -4.5037014 )
# #  Fit parameters:
# #     3.18519715530728     0.0604643409799939
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 169.015986447085
# #  - relative improvement: 1.02737607976517
# #  - m2lnL_0  :            164.512285010293
# #  - m2lnL_1  :            -4.50370143679248
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0000410
# #  iteration            [000048]
# #  function evaluations [000050]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000005]
# #  m2lnL     =    -4.50370143679248 (    -4.5037014 )
# #  Fit parameters:
# #     3.18519715530728     0.0604643409799939
# #----------------------------------------------------------------------------------
# # Restarting:              no
# #  - absolute improvement: 0
# #  - relative improvement: -0
# #  - m2lnL_1  :            -4.50370143679248
# #  - m2lnL_2  :            -4.50370143679248
# Cutting 5.0-sigma, 68809
# Cutting 5.0-sigma, 249226
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0000590
# #  iteration            [000078]
# #  function evaluations [000080]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000001]
# #  m2lnL     =   -0.781987657874931 (   -0.78198766 )
# #  Fit parameters:
# #     3.72507109406852     0.266212439543211
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 31.0436947262355
# #  - relative improvement: 1.02584083099174
# #  - m2lnL_0  :            30.2617070683606
# #  - m2lnL_1  :            -0.781987657874931
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0000310
# #  iteration            [000049]
# #  function evaluations [000051]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000001]
# #  m2lnL     =   -0.781987657874931 (   -0.78198766 )
# #  Fit parameters:
# #     3.72507109406852     0.266212439543211
# #----------------------------------------------------------------------------------
# # Restarting:              no
# #  - absolute improvement: 0
# #  - relative improvement: -0
# #  - m2lnL_1  :            -0.781987657874931
# #  - m2lnL_2  :            -0.781987657874931
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #...............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0000420
# #  iteration            [000067]
# #  function evaluations [000069]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000001]
# #  m2lnL     =   -0.784709107751717 (   -0.78470911 )
# #  Fit parameters:
# #     3.72556604601193     0.0326317554680096
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 27.9965585308043
# #  - relative improvement: 1.02883703696695
# #  - m2lnL_0  :            27.2118494230526
# #  - m2lnL_1  :            -0.784709107751717
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0000310
# #  iteration            [000048]
# #  function evaluations [000050]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000001]
# #  m2lnL     =   -0.784709108898676 (   -0.78470911 )
# #  Fit parameters:
# #     3.72555377265132     0.0326469003398912
# #----------------------------------------------------------------------------------
# # Restarting:              no
# #  - absolute improvement: 1.14695897224237e-09
# #  - relative improvement: -1.46163586087148e-09
# #  - m2lnL_1  :            -0.784709107751717
# #  - m2lnL_2  :            -0.784709108898676
# Cutting 5.0-sigma, 134440
# Cutting 5.0-sigma, 270808
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #....................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0000660
# #  iteration            [000115]
# #  function evaluations [000117]
# #  gradient evaluations [000000]
# #  degrees of freedom   [-00001]
# #  m2lnL     =    -17.0320341561396 (    -17.032034 )
# #  Fit parameters:
# #     4.18929440287526     0.0001
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 16.8111811055168
# #  - relative improvement: -76.1193067431452
# #  - m2lnL_0  :            -0.220853050622807
# #  - m2lnL_1  :            -17.0320341561396
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0000210
# #  iteration            [000036]
# #  function evaluations [000038]
# #  gradient evaluations [000000]
# #  degrees of freedom   [-00001]
# #  m2lnL     =    -17.0320341561396 (    -17.032034 )
# #  Fit parameters:
# #     4.18929440287526     0.0001
# #----------------------------------------------------------------------------------
# # Restarting:              no
# #  - absolute improvement: 0
# #  - relative improvement: -0
# #  - m2lnL_1  :            -17.0320341561396
# #  - m2lnL_2  :            -17.0320341561396
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0000440
# #  iteration            [000089]
# #  function evaluations [000091]
# #  gradient evaluations [000000]
# #  degrees of freedom   [-00001]
# #  m2lnL     =    -8.26673740274799 (    -8.2667374 )
# #  Fit parameters:
# #     4.19385240059393    -0.552019348144531
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 9.24175206622078
# #  - relative improvement: 9.47857751523824
# #  - m2lnL_0  :            0.975014663472791
# #  - m2lnL_1  :            -8.26673740274799
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0000380
# #  iteration            [000076]
# #  function evaluations [000078]
# #  gradient evaluations [000000]
# #  degrees of freedom   [-00001]
# #  m2lnL     =     -21.372508485299 (    -21.372508 )
# #  Fit parameters:
# #     4.18929364662665    -0.563796567916871
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 13.1057710825511
# #  - relative improvement: -1.58536196857959
# #  - m2lnL_1  :            -8.26673740274799
# #  - m2lnL_2  :            -21.372508485299
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0000350
# #  iteration            [000047]
# #  function evaluations [000049]
# #  gradient evaluations [000000]
# #  degrees of freedom   [-00001]
# #  m2lnL     =     -21.372508485299 (    -21.372508 )
# #  Fit parameters:
# #     4.18929364662665    -0.563796567916871
# #----------------------------------------------------------------------------------
# # Restarting:              no
# #  - absolute improvement: 0
# #  - relative improvement: -0
# #  - m2lnL_2  :            -21.372508485299
# #  - m2lnL_3  :            -21.372508485299
# Cutting 5.0-sigma, 454460
# Cutting 5.0-sigma, 38
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0041200
# #  iteration            [000081]
# #  function evaluations [000083]
# #  gradient evaluations [000000]
# #  degrees of freedom   [001135]
# #  m2lnL     =     815.711450378432 (     815.71145 )
# #  Fit parameters:
# #     1.71388864493599     0.434117416348117
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 166919.579408466
# #  - relative improvement: 0.995136912177504
# #  - m2lnL_0  :            167735.290858844
# #  - m2lnL_1  :            815.711450378432
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0023280
# #  iteration            [000045]
# #  function evaluations [000047]
# #  gradient evaluations [000000]
# #  degrees of freedom   [001135]
# #  m2lnL     =     815.711450378432 (     815.71145 )
# #  Fit parameters:
# #     1.71388864493599     0.434117416348117
# #----------------------------------------------------------------------------------
# # Restarting:              no
# #  - absolute improvement: 0
# #  - relative improvement: 0
# #  - m2lnL_1  :            815.711450378432
# #  - m2lnL_2  :            815.711450378432
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0027160
# #  iteration            [000048]
# #  function evaluations [000050]
# #  gradient evaluations [000000]
# #  degrees of freedom   [001135]
# #  m2lnL     =     6035.04672401658 (     6035.0467 )
# #  Fit parameters:
# #     6                   -1.14631149560213
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 109760.391962505
# #  - relative improvement: 0.947881826845058
# #  - m2lnL_0  :            115795.438686521
# #  - m2lnL_1  :            6035.04672401658
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.....................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0068790
# #  iteration            [000125]
# #  function evaluations [000127]
# #  gradient evaluations [000000]
# #  degrees of freedom   [001135]
# #  m2lnL     =     812.830297458663 (      812.8303 )
# #  Fit parameters:
# #     1.71558929197477    -0.0415699745881484
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 5222.21642655791
# #  - relative improvement: 0.86531499512274
# #  - m2lnL_1  :            6035.04672401658
# #  - m2lnL_2  :            812.830297458663
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0027570
# #  iteration            [000049]
# #  function evaluations [000051]
# #  gradient evaluations [000000]
# #  degrees of freedom   [001135]
# #  m2lnL     =     812.830297458663 (      812.8303 )
# #  Fit parameters:
# #     1.71558929197477    -0.0415699745881484
# #----------------------------------------------------------------------------------
# # Restarting:              no
# #  - absolute improvement: 0
# #  - relative improvement: 0
# #  - m2lnL_2  :            812.830297458663
# #  - m2lnL_3  :            812.830297458663
# Cutting 5.0-sigma, 9212
# Cutting 5.0-sigma, 20795
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0023430
# #  iteration            [000073]
# #  function evaluations [000075]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000707]
# #  m2lnL     =     483.744943085523 (     483.74494 )
# #  Fit parameters:
# #     1.95627948952837     0.426547016033822
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 86582.5722616099
# #  - relative improvement: 0.994443948491031
# #  - m2lnL_0  :            87066.3172046954
# #  - m2lnL_1  :            483.744943085523
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0014300
# #  iteration            [000044]
# #  function evaluations [000046]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000707]
# #  m2lnL     =     483.744943085523 (     483.74494 )
# #  Fit parameters:
# #     1.95627948952837     0.426547016033822
# #----------------------------------------------------------------------------------
# # Restarting:              no
# #  - absolute improvement: 0
# #  - relative improvement: 0
# #  - m2lnL_1  :            483.744943085523
# #  - m2lnL_2  :            483.744943085523
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #..............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0019140
# #  iteration            [000054]
# #  function evaluations [000056]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000707]
# #  m2lnL     =     3680.48307344055 (     3680.4831 )
# #  Fit parameters:
# #     6                   -1.25167793672532
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 57001.3455696304
# #  - relative improvement: 0.939347854938765
# #  - m2lnL_0  :            60681.828643071
# #  - m2lnL_1  :            3680.48307344055
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #...................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0036320
# #  iteration            [000105]
# #  function evaluations [000107]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000707]
# #  m2lnL     =     481.996985582121 (     481.99699 )
# #  Fit parameters:
# #     1.9593956875        -0.0458318823370411
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 3198.48608785843
# #  - relative improvement: 0.869039749412148
# #  - m2lnL_1  :            3680.48307344055
# #  - m2lnL_2  :            481.996985582121
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0017350
# #  iteration            [000048]
# #  function evaluations [000050]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000707]
# #  m2lnL     =     481.996985582121 (     481.99699 )
# #  Fit parameters:
# #     1.9593956875        -0.0458318823370411
# #----------------------------------------------------------------------------------
# # Restarting:              no
# #  - absolute improvement: 0
# #  - relative improvement: 0
# #  - m2lnL_2  :            481.996985582121
# #  - m2lnL_3  :            481.996985582121
# Cutting 5.0-sigma, 4491
# Cutting 5.0-sigma, 10885
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0014670
# #  iteration            [000078]
# #  function evaluations [000080]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000399]
# #  m2lnL     =     187.535847181162 (     187.53585 )
# #  Fit parameters:
# #     2.24743596411229     0.383163068732313
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 38142.7984660542
# #  - relative improvement: 0.995107377732513
# #  - m2lnL_0  :            38330.3343132353
# #  - m2lnL_1  :            187.535847181162
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0008700
# #  iteration            [000047]
# #  function evaluations [000049]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000399]
# #  m2lnL     =     187.535847181162 (     187.53585 )
# #  Fit parameters:
# #     2.24743596411229     0.383163068732313
# #----------------------------------------------------------------------------------
# # Restarting:              no
# #  - absolute improvement: 0
# #  - relative improvement: 0
# #  - m2lnL_1  :            187.535847181162
# #  - m2lnL_2  :            187.535847181162
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #..............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0010560
# #  iteration            [000052]
# #  function evaluations [000054]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000399]
# #  m2lnL     =     2021.80407649603 (     2021.8041 )
# #  Fit parameters:
# #     6                   -1.38804720079526
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 25088.3009913853
# #  - relative improvement: 0.925422492040012
# #  - m2lnL_0  :            27110.1050678813
# #  - m2lnL_1  :            2021.80407649603
# ...
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0019580
# #  iteration            [000088]
# #  function evaluations [000090]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000347]
# #  m2lnL     =     244.555134329763 (     244.55513 )
# #  Fit parameters:
# #     3.10690782051585    -0.0278125
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 5579.51458515435
# #  - relative improvement: 0.958009579879922
# #  - m2lnL_0  :            5824.06971948411
# #  - m2lnL_1  :            244.555134329763
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #..............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0013450
# #  iteration            [000059]
# #  function evaluations [000061]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000347]
# #  m2lnL     =    -55.3546548448259 (    -55.354655 )
# #  Fit parameters:
# #     3.42189324365614     0.00258828179903044
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 299.909789174589
# #  - relative improvement: 1.226348365151
# #  - m2lnL_1  :            244.555134329763
# #  - m2lnL_2  :            -55.3546548448259
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0011080
# #  iteration            [000048]
# #  function evaluations [000050]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000347]
# #  m2lnL     =    -55.3546560269594 (    -55.354656 )
# #  Fit parameters:
# #     3.42191800022118     0.00258641043932922
# #----------------------------------------------------------------------------------
# # Restarting:              no
# #  - absolute improvement: 1.18213358035746e-06
# #  - relative improvement: -2.13556309522894e-08
# #  - m2lnL_2  :            -55.3546548448259
# #  - m2lnL_3  :            -55.3546560269594
# Cutting 5.0-sigma, 53280
# Cutting 5.0-sigma, 53880
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0004510
# #  iteration            [000079]
# #  function evaluations [000081]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000088]
# #  m2lnL     =    -47.7747135214649 (    -47.774714 )
# #  Fit parameters:
# #     3.72555697018629     0.232574982739122
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 925.135981394346
# #  - relative improvement: 1.05445272691065
# #  - m2lnL_0  :            877.361267872881
# #  - m2lnL_1  :            -47.7747135214649
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0002750
# #  iteration            [000049]
# #  function evaluations [000051]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000088]
# #  m2lnL     =    -47.7747135214649 (    -47.774714 )
# #  Fit parameters:
# #     3.72555697018629     0.232574982739122
# #----------------------------------------------------------------------------------
# # Restarting:              no
# #  - absolute improvement: 0
# #  - relative improvement: -0
# #  - m2lnL_1  :            -47.7747135214649
# #  - m2lnL_2  :            -47.7747135214649
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #...............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0004280
# #  iteration            [000069]
# #  function evaluations [000071]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000088]
# #  m2lnL     =    -48.3169139972013 (    -48.316914 )
# #  Fit parameters:
# #     3.72337070424482     0.0225969176095307
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 845.551537412294
# #  - relative improvement: 1.06060563926618
# #  - m2lnL_0  :            797.234623415093
# #  - m2lnL_1  :            -48.3169139972013
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0002970
# #  iteration            [000047]
# #  function evaluations [000049]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000088]
# #  m2lnL     =    -48.3169139972013 (    -48.316914 )
# #  Fit parameters:
# #     3.72337070424482     0.0225969176095307
# #----------------------------------------------------------------------------------
# # Restarting:              no
# #  - absolute improvement: 0
# #  - relative improvement: -0
# #  - m2lnL_1  :            -48.3169139972013
# #  - m2lnL_2  :            -48.3169139972013
# Cutting 5.0-sigma, 186895
# Cutting 5.0-sigma, 217171
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0000830
# #  iteration            [000072]
# #  function evaluations [000074]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000007]
# #  m2lnL     =    -7.39086831482467 (    -7.3908683 )
# #  Fit parameters:
# #     4.03799624258684     0.201139844791142
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 30.4104222038519
# #  - relative improvement: 1.32106913758862
# #  - m2lnL_0  :            23.0195538890272
# #  - m2lnL_1  :            -7.39086831482467
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0000480
# #  iteration            [000048]
# #  function evaluations [000050]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000007]
# #  m2lnL     =    -7.39086831482467 (    -7.3908683 )
# #  Fit parameters:
# #     4.03799624258684     0.201139844791142
# #----------------------------------------------------------------------------------
# # Restarting:              no
# #  - absolute improvement: 0
# #  - relative improvement: -0
# #  - m2lnL_1  :            -7.39086831482467
# #  - m2lnL_2  :            -7.39086831482467
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0000740
# #  iteration            [000071]
# #  function evaluations [000073]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000007]
# #  m2lnL     =    -7.41975729020907 (    -7.4197573 )
# #  Fit parameters:
# #     4.03265685338462     0.043477317828675
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 36.6892617442363
# #  - relative improvement: 1.25349787871753
# #  - m2lnL_0  :            29.2695044540272
# #  - m2lnL_1  :            -7.41975729020907
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #..............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0000570
# #  iteration            [000053]
# #  function evaluations [000055]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000007]
# #  m2lnL     =     -7.4197573139322 (    -7.4197573 )
# #  Fit parameters:
# #     4.03263536718486     0.0434806360489481
# #----------------------------------------------------------------------------------
# # Restarting:              no
# #  - absolute improvement: 2.37231247979253e-08
# #  - relative improvement: -3.19729121452931e-09
# #  - m2lnL_1  :            -7.41975729020907
# #  - m2lnL_2  :            -7.4197573139322
# Cutting 5.0-sigma, 340754
# Cutting 5.0-sigma, 384049
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #...................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0000630
# #  iteration            [000104]
# #  function evaluations [000106]
# #  gradient evaluations [000000]
# #  degrees of freedom   [-00001]
# #  m2lnL     =    -17.0322534673143 (    -17.032253 )
# #  Fit parameters:
# #     3.92842608030083     0.0001
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 20.8045905741041
# #  - relative improvement: 5.51504014226563
# #  - m2lnL_0  :            3.77233710678983
# #  - m2lnL_1  :            -17.0322534673143
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0000220
# #  iteration            [000036]
# #  function evaluations [000038]
# #  gradient evaluations [000000]
# #  degrees of freedom   [-00001]
# #  m2lnL     =    -17.0322534673143 (    -17.032253 )
# #  Fit parameters:
# #     3.92842608030083     0.0001
# #----------------------------------------------------------------------------------
# # Restarting:              no
# #  - absolute improvement: 0
# #  - relative improvement: -0
# #  - m2lnL_1  :            -17.0322534673143
# #  - m2lnL_2  :            -17.0322534673143
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #...................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0000510
# #  iteration            [000104]
# #  function evaluations [000106]
# #  gradient evaluations [000000]
# #  degrees of freedom   [-00001]
# #  m2lnL     =     -8.6244110944096 (    -8.6244111 )
# #  Fit parameters:
# #     3.93244492989082     0.17197998046875
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 13.0296396891197
# #  - relative improvement: 2.95776698279993
# #  - m2lnL_0  :            4.40522859471011
# #  - m2lnL_1  :            -8.6244110944096
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #..............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0000310
# #  iteration            [000056]
# #  function evaluations [000058]
# #  gradient evaluations [000000]
# #  degrees of freedom   [-00001]
# #  m2lnL     =    -13.4819983114594 (    -13.481998 )
# #  Fit parameters:
# #     3.92853867989082     0.17436279296875
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 4.85758721704975
# #  - relative improvement: -0.563236975124999
# #  - m2lnL_1  :            -8.6244110944096
# #  - m2lnL_2  :            -13.4819983114594
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #...............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0000340
# #  iteration            [000064]
# #  function evaluations [000066]
# #  gradient evaluations [000000]
# #  degrees of freedom   [-00001]
# #  m2lnL     =    -18.0004084362317 (    -18.000408 )
# #  Fit parameters:
# #     3.9284681079914      0.174692554473877
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 4.51841012477239
# #  - relative improvement: -0.335143946793989
# #  - m2lnL_2  :            -13.4819983114594
# #  - m2lnL_3  :            -18.0004084362317
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.............
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0000260
# #  iteration            [000045]
# #  function evaluations [000047]
# #  gradient evaluations [000000]
# #  degrees of freedom   [-00001]
# #  m2lnL     =    -18.0004084362317 (    -18.000408 )
# #  Fit parameters:
# #     3.9284681079914      0.174692554473877
# #----------------------------------------------------------------------------------
# # Restarting:              no
# #  - absolute improvement: 0
# #  - relative improvement: -0
# #  - m2lnL_3  :            -18.0004084362317
# #  - m2lnL_4  :            -18.0004084362317
# Cutting 5.0-sigma, 454450
# Cutting 5.0-sigma, 195435

# %%
mean_tot_ascaso = [np.mean(err ** 2) for err, lnR_mean, z_sigma_cut, lnM_sigma_cut, cut, lnR in fit_results_ascaso if len(err)>0]

mean_z_ascaso = [np.mean(z_sigma_cut) for err, lnR_mean, z_sigma_cut, lnM_sigma_cut, cut, lnR  in fit_results_ascaso if len(z_sigma_cut) > 0]

mean_lnM_ascaso = [np.mean(lnM_sigma_cut) for err, lnR_mean, z_sigma_cut, lnM_sigma_cut, cut, lnR in fit_results_ascaso if len(lnM_sigma_cut) > 0]


#plt.scatter(mean_lnM_ascaso, mean_tot_ascaso)

plt.scatter(mean_lnM_ascaso, mean_tot_ascaso , c=mean_z_ascaso, cmap='RdYlBu')
plt.colorbar(label='z')

plt.xlabel('lnM')
plt.ylabel('mean_err²')
# Out:
# Text(0, 0.5, 'mean_err²')

# %%
plt.scatter(mean_z_ascaso, mean_tot_ascaso , c=mean_lnM_ascaso, cmap='RdYlBu')
plt.colorbar(label='lnM')

plt.xlabel('z')
plt.ylabel('mean_err²')
# Out:
# Text(0, 0.5, 'mean_err²')
