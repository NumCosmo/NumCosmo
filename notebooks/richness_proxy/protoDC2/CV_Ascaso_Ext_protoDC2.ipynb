# %% [markdown]
# ## Settings

# %%
import sys
sys.path.insert(0, "/global/homes/c/cinlima/NumCosmo/notebooks/richness_proxy/")

#NumCosmo
from numcosmo_py import Ncm, Nc, GObject
from richness_mass_calib import create_richness_mass_calib

#Functions
#from Configs_Ascaso_Ext_Analysis import Binningf

#Useful packages
import numpy as np
import math
from scipy import stats

from astropy.io import fits
from astropy.table import Table
import pandas as pd
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
import matplotlib.pyplot as gridspec
from matplotlib.gridspec import GridSpec

sys.path.insert(0, "/global/homes/c/cinlima/gcr-catalogs")
import GCRCatalogs

# %matplotlib inline

Ncm.cfg_init()
Ncm.cfg_set_log_handler(lambda msg: sys.stdout.write(msg) and sys.stdout.flush())

# %% [markdown]
# ## Data

# %%
protodc2 = GCRCatalogs.load_catalog('proto-dc2_v3.0_redmapper')
protoDC2_v3_redmapper=Table(protodc2.get_quantities(['cluster_id','redshift_true_cluster','halo_mass','richness']))

protoDC2_v3_redmapper.rename_column('redshift_true_cluster', 'redshift_true')
protoDC2_v3_redmapper.rename_column('halo_mass', 'm200c')

dt_halos = protoDC2_v3_redmapper

cut=dt_halos['richness'] > 0
dt_halos = dt_halos[cut]

print(protodc2.get_catalog_info('description'))
print(protodc2.cosmology)


GCRCatalogs.get_available_catalogs()
# Out:
# cluster catalog and member catalog from the redMaPPer cluster finder run on proto-dc2. Red
# sequence was fit in the standard way, but centers are on halo centers, i.e. a real halo finding
# run was not done.
#
# FlatLambdaCDM(H0=71.0 km / (Mpc s), Om0=0.265, Tcmb0=0.0 K, Neff=3.04, m_nu=None, Ob0=0.0448)
# {'buzzard': {'subclass_name': 'buzzard.BuzzardGalaxyCatalog',
#   'catalog_root_dir': '/global/cfs/cdirs/lsst/shared/external/buzzard/Buzzard-3/v2.0.0/',
#   'catalog_path_template': {'truth': 'truth/Chinchilla-3_lensed_rs_shift_rs_scat_cam.{}.fits',
#    'auxmag': 'auxmags/Chinchilla-3-v1.9.7-auxmag.{}.fits'},
#   'cosmology': {'H0': 70.0,
#    'Om0': 0.286,
#    'Ob0': 0.047,
#    'sigma8': 0.82,
#    'n_s': 0.96},
#   'halo_mass_def': 'vir',
#   'lightcone': True,
#   'sky_area': 10313.24,
#   'version': '2.0.0_3',
#   'creators': ['Joe DeRose', 'Risa Wechsler', 'Eli Rykoff', 'Matt Becker'],
#   'description': 'Buzzard galaxy catalog v2.0.0 (realization 3).\nThis is a 10,000-square-degree catalog created with the ADDGALS algorithm.\nIt has galaxies down to r~26.5 magnitudes fainter than projected DES Y5 magnitude limits.\nRead more at https://confluence.slac.stanford.edu/x/4o2bDQ\n'},
#  'buzzard_high-res': {'subclass_name': 'buzzard.BuzzardGalaxyCatalog',
#   'high_res': True,
#   'catalog_root_dir': '/global/cfs/cdirs/lsst/shared/external/buzzard/Buzzard-highres',
#   'catalog_path_template': {'truth': 'truth/Buzzard-highres_galaxies_shmatch.{}.fit',
#    'lsst': 'lsst/Buzzard-highres_lsst.{}.fit',
#    'halos': 'halos/Buzzard-highres_halos.{}.fit',
#    'des': 'des/Buzzard-highres_decam.{}.fit',
#    'stripe82': 'stripe82/Buzzard-highres_Stripe82_Mock_mag.{}.fit',
#    'cfhtls': 'cfhtls/Buzzard-highres_cfhtls.{}.fit',
#    'candels': 'candels/Buzzard-highres_candels.{}.fit',
#    'deep': 'deep/Buzzard-highres_deep.{}.fit',
#    'euclid': 'euclid/Buzzard-highres_euclid.{}.fit',
#    'flamex': 'flamex/Buzzard-highres_flamex.{}.fit',
#    'hsc': 'hsc/Buzzard-highres_hsc.{}.fit',
#    'irac': 'irac/Buzzard-highres_irac.{}.fit',
#    'johnson': 'johnson/Buzzard-highres_johnson.{}.fit',
#    'sdss25': 'sdss25/Buzzard-highres_sdss25.{}.fit',
#    'twomass': 'twomass/Buzzard-highres_twomass.{}.fit',
#    'vista': 'vista/Buzzard-highres_vista.{}.fit',
#    'wise': 'wise/Buzzard-highres_wise.{}.fit',
#    'desy5': 'desy5/Buzzard-highres_DES_Mock_mag.{}.fit'},
#   'cosmology': {'H0': 70.0,
#    'Om0': 0.286,
#    'Ob0': 0.047,
#    'sigma8': 0.82,
#    'n_s': 0.96},
#   'halo_mass_def': 'vir',
#   'lightcone': True,
#   'sky_area': 400.0,
#   'version': '1.1',
#   'creators': ['Joe DeRose', 'Risa Wechsler', 'Eli Rykoff', 'Matt Becker'],
#   'description': 'Buzzard "high-res" galaxy catalog v1.1.\nThis is a 400-square-degree mock galaxy catalog with 238 million galaxies\ndown to r=29 for 0 < z <= 8.7, constructed with SHAM and ADDSEDs.\nRead more at https://confluence.slac.stanford.edu/x/ko6bDQ\n'},
#  'cosmoDC2_v1.1.4_image': {'subclass_name': 'cosmodc2.CosmoDC2GalaxyCatalog',
#   'catalog_root_dir': '/global/cfs/cdirs/lsst/shared/xgal/cosmoDC2/cosmoDC2_v1.1.4_rs_scatter_query_tree_double',
#   'catalog_filename_template': 'z_{}_{}.step_all.healpix_{}.hdf5',
#   'cosmology': {'H0': 71.0,
#    'Om0': 0.2648,
#    'Ob0': 0.0448,
#    'sigma8': 0.8,
#    'n_s': 0.963},
#   'lightcone': True,
#   'version': '1.1.4',
#   'check_md5': False,
#   'check_size': False,
#   'check_cosmology': False,
#   'ensure_meta_consistent': False,
#   'sky_area': 439.78987,
#   'creators': ['Andrew Hearin',
#    'Danila Korytov',
#    'Eve Kovacs',
#    'Esteban Rangel',
#    'Patricia Larsen',
#    'Joe Hollowed',
#    'Andrew Benson',
#    'Katrin Heitmann'],
#   'description': 'This is the extra-galactic catalog for the LSST-DESC data challenge DC2.\n',
#   'healpix_pixels': [8786,
#    8787,
#    8788,
#    8789,
#    8790,
#    8791,
#    8792,
#    8793,
#    8794,
#    8913,
#    8914,
#    8915,
#    8916,
#    8917,
#    8918,
#    8919,
#    8920,
#    8921,
#    9042,
#    9043,
#    9044,
#    9045,
#    9046,
#    9047,
#    9048,
#    9049,
#    9050,
#    9169,
#    9170,
#    9171,
#    9172,
#    9173,
#    9174,
#    9175,
#    9176,
#    9177,
#    9178,
#    9298,
#    9299,
#    9300,
#    9301,
#    9302,
#    9303,
#    9304,
#    9305,
#    9306,
#    9425,
#    9426,
#    9427,
#    9428,
#    9429,
#    9430,
#    9431,
#    9432,
#    9433,
#    9434,
#    9554,
#    9555,
#    9556,
#    9557,
#    9558,
#    9559,
#    9560,
#    9561,
#    9562,
#    9681,
#    9682,
#    9683,
#    9684,
#    9685,
#    9686,
#    9687,
#    9688,
#    9689,
#    9690,
#    9810,
#    9811,
#    9812,
#    9813,
#    9814,
#    9815,
#    9816,
#    9817,
#    9818,
#    9937,
#    9938,
#    9939,
#    9940,
#    9941,
#    9942,
#    9943,
#    9944,
#    9945,
#    9946,
#    10066,
#    10067,
#    10068,
#    10069,
#    10070,
#    10071,
#    10072,
#    10073,
#    10074,
#    10193,
#    10194,
#    10195,
#    10196,
#    10197,
#    10198,
#    10199,
#    10200,
#    10201,
#    10202,
#    10321,
#    10322,
#    10323,
#    10324,
#    10325,
#    10326,
#    10327,
#    10328,
#    10329,
#    10444,
#    10445,
#    10446,
#    10447,
#    10448,
#    10449,
#    10450,
#    10451,
#    10452],
#   'include_in_default_catalog_list': True},
#  'cosmoDC2_v1.1.4_redmagic_v0.8.1_highdens': {'subclass_name': 'redmagic.RedmagicCatalog',
#   'catalog_root_dir': '/global/cfs/cdirs/lsst/shared/xgal/cosmoDC2/addons/redmagic_v1.1.4',
#   'catalog_path_template': {'redmagic': 'cosmoDC2_v1.1.4_mag_run_redmapper_v0.8.1_redmagic_highdens-chi.fit'},
#   'sky_area': 439.78987,
#   'cosmology': {'H0': 71.0,
#    'Om0': 0.2648,
#    'Ob0': 0.0448,
#    'sigma8': 0.8,
#    'n_s': 0.963},
#   'creators': ['Eli Rykoff'],
#   'description': 'RedMaGiC high density red galaxy catalog computed from the redMaPPer\ncluster finder (v0.8.1) run on cosmoDC2 v1.1.4.\n',
#   'include_in_default_catalog_list': True},
#  'cosmoDC2_v1.1.4_redmagic_v0.8.1_highlum': {'subclass_name': 'redmagic.RedmagicCatalog',
#   'catalog_root_dir': '/global/cfs/cdirs/lsst/shared/xgal/cosmoDC2/addons/redmagic_v1.1.4',
#   'catalog_path_template': {'redmagic': 'cosmoDC2_v1.1.4_mag_run_redmapper_v0.8.1_redmagic_highlum-chi.fit'},
#   'sky_area': 439.78987,
#   'cosmology': {'H0': 71.0,
#    'Om0': 0.2648,
#    'Ob0': 0.0448,
#    'sigma8': 0.8,
#    'n_s': 0.963},
#   'creators': ['Eli Rykoff'],
#   'description': 'RedMaGiC high luminosity red galaxy catalog computed from the redMaPPer\ncluster finder (v0.8.1) run on cosmoDC2 v1.1.4.\n',
#   'include_in_default_catalog_list': True},
#  'cosmoDC2_v1.1.4_redmapper_v0.8.1': {'subclass_name': 'redmapper.RedmapperCatalog',
#   'catalog_root_dir': '/global/cfs/cdirs/lsst/shared/xgal/cosmoDC2/addons/redmapper_v1.1.4',
#   'catalog_path_template': {'clusters': 'cosmoDC2_v1.1.4_mag_run_redmapper_v0.8.1_lgt05_catalog.fit',
#    'members': 'cosmoDC2_v1.1.4_mag_run_redmapper_v0.8.1_lgt05_catalog_members.fit'},
#   'sky_area': 439.78987,
#   'cosmology': {'H0': 71.0,
#    'Om0': 0.2648,
#    'Ob0': 0.0448,
#    'sigma8': 0.8,
#    'n_s': 0.963},
#   'creators': ['Eli Rykoff'],
#   'description': 'Cluster and member catalogs computed from the redMaPPer cluster finder\n(v0.8.1) run on cosmoDC2 v1.1.4.  Richness selection is lambda > 5 to\nfacilitate matching with catalogs run on run2.2i DR6.\n',
#   'include_in_default_catalog_list': True},
#  'cosmoDC2_v1.1.4_small': {'subclass_name': 'cosmodc2.CosmoDC2GalaxyCatalog',
#   'catalog_root_dir': '/global/cfs/cdirs/lsst/shared/xgal/cosmoDC2/cosmoDC2_v1.1.4_rs_scatter_query_tree_double',
#   'catalog_filename_template': 'z_{}_{}.step_all.healpix_{}.hdf5',
#   'cosmology': {'H0': 71.0,
#    'Om0': 0.2648,
#    'Ob0': 0.0448,
#    'sigma8': 0.8,
#    'n_s': 0.963},
#   'lightcone': True,
#   'version': '1.1.4',
#   'check_md5': False,
#   'check_size': False,
#   'check_cosmology': False,
#   'ensure_meta_consistent': False,
#   'sky_area': 57.071968,
#   'creators': ['Andrew Hearin',
#    'Danila Korytov',
#    'Eve Kovacs',
#    'Esteban Rangel',
#    'Patricia Larsen',
#    'Joe Hollowed',
#    'Andrew Benson',
#    'Katrin Heitmann'],
#   'description': 'This is the extra-galactic catalog for the LSST-DESC data challenge DC2.\n',
#   'healpix_pixels': [9559,
#    9686,
#    9687,
#    9814,
#    9815,
#    9816,
#    9942,
#    9943,
#    10070,
#    10071,
#    10072,
#    10198,
#    10199,
#    10200,
#    10326,
#    10327,
#    10450],
#   'include_in_default_catalog_list': True},
#  'cosmoDC2_v1.1.4_wazp_v1.0_flexzboost_v1': {'subclass_name': 'wazp.WazpCatalog',
#   'catalog_root_dir': '/global/cfs/cdirs/lsst/shared/xgal/cosmoDC2/addons/wazp_v1.1.4/flexzboost',
#   'catalog_path_template': {'clusters': 'cosmoDC2_v1.1.4_wazp_cluster_v1.0.fits',
#    'members': 'cosmoDC2_v1.1.4_wazp_membership_v1.0.fits'},
#   'sky_area': 439.78987,
#   'cosmology': {'H0': 71.0,
#    'Om0': 0.2648,
#    'Ob0': 0.0448,
#    'sigma8': 0.8,
#    'n_s': 0.963},
#   'creators': ['Michel Aguena',
#    'Cristophe Benoist',
#    'Julia Gschwend',
#    'Luiz da Costa'],
#   'description': 'Cluster and member catalogs computed from the WaZP cluster finder\n(v5.1.0) run on cosmoDC2 v1.1.4 using FlexZBoost. Richness selection\nis NGALS > 5 to filter for more significant detections.\n',
#   'include_in_default_catalog_list': True},
#  'cosmoDC2_v1.1.4_wazp_v1.0_truez': {'subclass_name': 'wazp.WazpCatalog',
#   'catalog_root_dir': '/global/cfs/cdirs/lsst/shared/xgal/cosmoDC2/addons/wazp_v1.1.4/true',
#   'catalog_path_template': {'clusters': 'cosmoDC2_v1.1.4_wazp_cluster_v1.0.fits',
#    'members': 'cosmoDC2_v1.1.4_wazp_membership_v1.0.fits'},
#   'sky_area': 439.78987,
#   'cosmology': {'H0': 71.0,
#    'Om0': 0.2648,
#    'Ob0': 0.0448,
#    'sigma8': 0.8,
#    'n_s': 0.963},
#   'creators': ['Michel Aguena',
#    'Cristophe Benoist',
#    'Julia Gschwend',
#    'Luiz da Costa'],
#   'description': 'Cluster and member catalogs computed from the WaZP cluster finder\n(v5.1.0) run on cosmoDC2 v1.1.4 using true redshifts. Richness selection\nis NGALS > 5 to filter for more significant detections.\n',
#   'include_in_default_catalog_list': True},
#  'dc2_object_run1.2i': {'subclass_name': 'dc2_object.DC2ObjectCatalog',
#   'base_dir': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run1.2i/dpdd/object_catalog',
#   'schema_filename': 'trim_schema.yaml',
#   'filename_pattern': 'trim_object_tract_\\d+\\.hdf5$',
#   'description': 'DC2 Run 1.2i Object Catalog',
#   'creators': ['Michael Wood-Vasey'],
#   'pixel_scale': 0.2,
#   'include_in_default_catalog_list': True},
#  'dc2_object_run1.2i_all_columns': {'subclass_name': 'dc2_object.DC2ObjectCatalog',
#   'base_dir': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run1.2i/dpdd/object_catalog',
#   'schema_filename': 'schema.yaml',
#   'filename_pattern': 'object_tract_\\d+\\.hdf5$',
#   'description': 'DC2 Run 1.2i Object Catalog',
#   'creators': ['Michael Wood-Vasey'],
#   'pixel_scale': 0.2,
#   'include_in_default_catalog_list': True},
#  'dc2_object_run1.2i_tract4850': {'subclass_name': 'dc2_object.DC2ObjectCatalog',
#   'base_dir': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run1.2i/dpdd/object_catalog',
#   'filename_pattern': 'object_tract_4850\\.hdf5$',
#   'description': 'DC2 Run 1.2i Object Catalog Tract 4850',
#   'creators': ['Michael Wood-Vasey'],
#   'pixel_scale': 0.2,
#   'include_in_default_catalog_list': True},
#  'dc2_object_run1.2i_with_photoz': {'subclass_name': 'composite.CompositeReader',
#   'description': 'DC2 Run 1.2i Object Catalog with photo-z',
#   'catalogs': [{'catalog_name': 'dc2_object_run1.2i',
#     'matching_method': 'MATCHING_FORMAT'},
#    {'catalog_name': 'photoz_dc2_object_run1.2i',
#     'matching_method': 'MATCHING_FORMAT'}],
#   'include_in_default_catalog_list': True},
#  'dc2_object_run1.2p': {'subclass_name': 'dc2_object.DC2ObjectCatalog',
#   'base_dir': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run1.2p/dpdd/object_catalog_v4',
#   'schema_filename': 'trim_schema.yaml',
#   'filename_pattern': 'trim_object_tract_\\d+\\.hdf5$',
#   'description': 'DC2 Run 1.2p Object Catalog DPDD-columns (with only DPDD columns and native columns needed for the DPDD columns)',
#   'creators': ['Micahel Wood-Vasey'],
#   'pixel_scale': 0.2},
#  'dc2_object_run1.2p_all_columns': {'subclass_name': 'dc2_object.DC2ObjectCatalog',
#   'base_dir': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run1.2p/dpdd/object_catalog_v4',
#   'description': 'DC2 Run 1.2p Object Catalog',
#   'creators': ['Michael Wood-Vasey'],
#   'pixel_scale': 0.2},
#  'dc2_object_run1.2p_tract4850': {'subclass_name': 'dc2_object.DC2ObjectCatalog',
#   'base_dir': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run1.2p/dpdd/object_catalog_v4',
#   'filename_pattern': 'object_tract_4850\\.hdf5$',
#   'description': 'DC2 Run 1.2p Object Catalog Tract 4850',
#   'creators': ['Michael Wood-Vasey'],
#   'pixel_scale': 0.2},
#  'dc2_object_run2.2i_dr2_wfd': {'subclass_name': 'dc2_object.DC2ObjectParquetCatalog',
#   'base_dir': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run2.2i/dpdd/Run2.2i-dr2-v1/object_table_summary',
#   'pixel_scale': 0.2,
#   'description': 'DC2 Run 2.2i DR2 WFD Object Table v1',
#   'creators': ['DESC DC2 Team']},
#  'dc2_object_run2.2i_dr2_wfd_with_addons': {'subclass_name': 'composite.CompositeReader',
#   'catalogs': [{'catalog_name': 'dc2_object_run2.2i_dr2_wfd_v1'},
#    {'subclass_name': 'dc2_truth_match.DC2TruthMatchCatalog',
#     'base_dir': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run2.2i/truth/tract_partition/match_dr2_wfd_v1',
#     'as_object_addon': True,
#     'matching_partition': True,
#     'matching_row_order': True,
#     'overwrite_quantities': False,
#     'overwrite_attributes': False,
#     'include_native_quantities': False}],
#   'description': 'DC2 Run 2.2i DR2 WFD Object Table v1 with all available add-ons (currently only truth-match)',
#   'creators': ['DESC DC2 Team']},
#  'dc2_object_run2.2i_dr3a': {'subclass_name': 'dc2_object.DC2ObjectParquetCatalog',
#   'base_dir': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run2.2i/dpdd/Run2.2i-dr3/object_table_summary',
#   'filename_pattern': 'object_tract_\\d+\\.parquet$',
#   'description': 'DC2 Run 2.2i DR3 Object Table',
#   'creators': ['DESC DC2 Team'],
#   'pixel_scale': 0.2,
#   'tracts': [2723,
#    2724,
#    2725,
#    2726,
#    2727,
#    2728,
#    2729,
#    2730,
#    2731,
#    2732,
#    2733,
#    2734,
#    2896,
#    2897,
#    2898,
#    2899,
#    2900,
#    2901,
#    2902,
#    2903,
#    2904,
#    2905,
#    2906,
#    2907,
#    2908,
#    3074,
#    3075,
#    3076,
#    3077,
#    3078,
#    3079,
#    3080,
#    3081,
#    3082,
#    3083,
#    3084,
#    3085,
#    3086,
#    3256,
#    3257,
#    3258,
#    3259,
#    3260,
#    3261,
#    3262,
#    3263,
#    3264,
#    3265,
#    3266,
#    3267,
#    3268,
#    3441,
#    3442,
#    3443,
#    3444,
#    3445,
#    3446,
#    3447,
#    3448,
#    3449,
#    3450,
#    3451,
#    3452,
#    3453,
#    3454,
#    3631,
#    3632,
#    3633,
#    3634,
#    3635,
#    3636,
#    3637,
#    3638,
#    3639,
#    3640,
#    3641,
#    3642,
#    3643,
#    3825,
#    3826,
#    3827,
#    3828,
#    3829,
#    3830,
#    3831,
#    3832,
#    3833,
#    3834,
#    3835,
#    3836,
#    3837,
#    4022,
#    4023,
#    4024,
#    4025,
#    4026,
#    4027,
#    4028,
#    4029,
#    4030,
#    4031,
#    4032,
#    4033,
#    4034,
#    4035,
#    4224,
#    4225,
#    4226,
#    4227,
#    4228,
#    4229,
#    4230,
#    4231,
#    4232,
#    4233,
#    4234,
#    4235,
#    4236,
#    4429,
#    4430,
#    4431,
#    4432,
#    4433,
#    4434,
#    4435,
#    4436,
#    4437,
#    4438,
#    4439,
#    4440,
#    4441,
#    4636,
#    4637,
#    4638,
#    4639,
#    4640,
#    4641,
#    4642,
#    4643,
#    4644,
#    4645,
#    4646,
#    4647,
#    4648,
#    4850,
#    4851,
#    4852,
#    4853,
#    4854,
#    4855,
#    4856,
#    4857,
#    4858,
#    4859,
#    4860,
#    5065,
#    5066,
#    5067,
#    5068,
#    5069,
#    5070,
#    5071,
#    5072,
#    5073,
#    5074],
#   'include_in_default_catalog_list': True},
#  'dc2_object_run2.2i_dr3a_with_metacal': {'subclass_name': 'composite.CompositeReader',
#   'description': 'DC2 Run 2.2i DR3 Object Catalog with metacal',
#   'catalogs': [{'catalog_name': 'dc2_object_run2.2i_dr3',
#     'filename_pattern': 'object_tract_(?!3079|4034|4232|4636|5066|5073)\\d+\\.parquet$',
#     'matching_method': 'MATCHING_FORMAT',
#     'tracts': [2723,
#      2724,
#      2725,
#      2726,
#      2727,
#      2728,
#      2729,
#      2730,
#      2731,
#      2732,
#      2733,
#      2734,
#      2896,
#      2897,
#      2898,
#      2899,
#      2900,
#      2901,
#      2902,
#      2903,
#      2904,
#      2905,
#      2906,
#      2907,
#      2908,
#      3074,
#      3075,
#      3076,
#      3077,
#      3078,
#      3079,
#      3080,
#      3081,
#      3082,
#      3083,
#      3084,
#      3085,
#      3086,
#      3256,
#      3257,
#      3258,
#      3259,
#      3260,
#      3261,
#      3262,
#      3263,
#      3264,
#      3265,
#      3266,
#      3267,
#      3268,
#      3441,
#      3442,
#      3443,
#      3444,
#      3445,
#      3446,
#      3447,
#      3448,
#      3449,
#      3450,
#      3451,
#      3452,
#      3453,
#      3454,
#      3631,
#      3632,
#      3633,
#      3634,
#      3635,
#      3636,
#      3637,
#      3638,
#      3639,
#      3640,
#      3641,
#      3642,
#      3643,
#      3825,
#      3826,
#      3827,
#      3828,
#      3829,
#      3830,
#      3831,
#      3832,
#      3833,
#      3834,
#      3835,
#      3836,
#      3837,
#      4022,
#      4023,
#      4024,
#      4025,
#      4026,
#      4027,
#      4028,
#      4029,
#      4030,
#      4031,
#      4032,
#      4033,
#      4034,
#      4035,
#      4224,
#      4225,
#      4226,
#      4227,
#      4228,
#      4229,
#      4230,
#      4231,
#      4232,
#      4233,
#      4234,
#      4235,
#      4236,
#      4429,
#      4430,
#      4431,
#      4432,
#      4433,
#      4434,
#      4435,
#      4436,
#      4437,
#      4438,
#      4439,
#      4440,
#      4441,
#      4636,
#      4637,
#      4638,
#      4639,
#      4640,
#      4641,
#      4642,
#      4643,
#      4644,
#      4645,
#      4646,
#      4647,
#      4648,
#      4850,
#      4851,
#      4852,
#      4853,
#      4854,
#      4855,
#      4856,
#      4857,
#      4858,
#      4859,
#      4860,
#      5065,
#      5066,
#      5067,
#      5068,
#      5069,
#      5070,
#      5071,
#      5072,
#      5073,
#      5074]},
#    {'catalog_name': 'dc2_metacal_run2.2i_dr3',
#     'filename_pattern': 'metacal_tract_(?!3079|4034|4232|4636|5066|5073)\\d+\\.parquet$',
#     'matching_method': 'MATCHING_FORMAT',
#     'tracts': [2723,
#      2724,
#      2725,
#      2726,
#      2727,
#      2728,
#      2729,
#      2730,
#      2731,
#      2732,
#      2733,
#      2734,
#      2896,
#      2897,
#      2898,
#      2899,
#      2900,
#      2901,
#      2902,
#      2903,
#      2904,
#      2905,
#      2906,
#      2907,
#      2908,
#      3074,
#      3075,
#      3076,
#      3077,
#      3078,
#      3079,
#      3080,
#      3081,
#      3082,
#      3083,
#      3084,
#      3085,
#      3086,
#      3256,
#      3257,
#      3258,
#      3259,
#      3260,
#      3261,
#      3262,
#      3263,
#      3264,
#      3265,
#      3266,
#      3267,
#      3268,
#      3441,
#      3442,
#      3443,
#      3444,
#      3445,
#      3446,
#      3447,
#      3448,
#      3449,
#      3450,
#      3451,
#      3452,
#      3453,
#      3454,
#      3631,
#      3632,
#      3633,
#      3634,
#      3635,
#      3636,
#      3637,
#      3638,
#      3639,
#      3640,
#      3641,
#      3642,
#      3643,
#      3825,
#      3826,
#      3827,
#      3828,
#      3829,
#      3830,
#      3831,
#      3832,
#      3833,
#      3834,
#      3835,
#      3836,
#      3837,
#      4022,
#      4023,
#      4024,
#      4025,
#      4026,
#      4027,
#      4028,
#      4029,
#      4030,
#      4031,
#      4032,
#      4033,
#      4034,
#      4035,
#      4224,
#      4225,
#      4226,
#      4227,
#      4228,
#      4229,
#      4230,
#      4231,
#      4232,
#      4233,
#      4234,
#      4235,
#      4236,
#      4429,
#      4430,
#      4431,
#      4432,
#      4433,
#      4434,
#      4435,
#      4436,
#      4437,
#      4438,
#      4439,
#      4440,
#      4441,
#      4636,
#      4637,
#      4638,
#      4639,
#      4640,
#      4641,
#      4642,
#      4643,
#      4644,
#      4645,
#      4646,
#      4647,
#      4648,
#      4850,
#      4851,
#      4852,
#      4853,
#      4854,
#      4855,
#      4856,
#      4857,
#      4858,
#      4859,
#      4860,
#      5065,
#      5066,
#      5067,
#      5068,
#      5069,
#      5070,
#      5071,
#      5072,
#      5073,
#      5074]}],
#   'include_in_default_catalog_list': True},
#  'dc2_object_run2.2i_dr3a_with_photoz': {'subclass_name': 'composite.CompositeReader',
#   'description': 'DC2 Run 2.2i DR3 Object Catalog with metacal',
#   'catalogs': [{'catalog_name': 'dc2_object_run2.2i_dr3',
#     'matching_method': 'MATCHING_FORMAT',
#     'tracts': [2723,
#      2724,
#      2725,
#      2726,
#      2727,
#      2728,
#      2729,
#      2730,
#      2731,
#      2732,
#      2733,
#      2734,
#      2896,
#      2897,
#      2898,
#      2899,
#      2900,
#      2901,
#      2902,
#      2903,
#      2904,
#      2905,
#      2906,
#      2907,
#      2908,
#      3074,
#      3075,
#      3076,
#      3077,
#      3078,
#      3079,
#      3080,
#      3081,
#      3082,
#      3083,
#      3084,
#      3085,
#      3086,
#      3256,
#      3257,
#      3258,
#      3259,
#      3260,
#      3261,
#      3262,
#      3263,
#      3264,
#      3265,
#      3266,
#      3267,
#      3268,
#      3441,
#      3442,
#      3443,
#      3444,
#      3445,
#      3446,
#      3447,
#      3448,
#      3449,
#      3450,
#      3451,
#      3452,
#      3453,
#      3454,
#      3631,
#      3632,
#      3633,
#      3634,
#      3635,
#      3636,
#      3637,
#      3638,
#      3639,
#      3640,
#      3641,
#      3642,
#      3643,
#      3825,
#      3826,
#      3827,
#      3828,
#      3829,
#      3830,
#      3831,
#      3832,
#      3833,
#      3834,
#      3835,
#      3836,
#      3837,
#      4022,
#      4023,
#      4024,
#      4025,
#      4026,
#      4027,
#      4028,
#      4029,
#      4030,
#      4031,
#      4032,
#      4033,
#      4034,
#      4035,
#      4224,
#      4225,
#      4226,
#      4227,
#      4228,
#      4229,
#      4230,
#      4231,
#      4232,
#      4233,
#      4234,
#      4235,
#      4236,
#      4429,
#      4430,
#      4431,
#      4432,
#      4433,
#      4434,
#      4435,
#      4436,
#      4437,
#      4438,
#      4439,
#      4440,
#      4441,
#      4636,
#      4637,
#      4638,
#      4639,
#      4640,
#      4641,
#      4642,
#      4643,
#      4644,
#      4645,
#      4646,
#      4647,
#      4648,
#      4850,
#      4851,
#      4852,
#      4853,
#      4854,
#      4855,
#      4856,
#      4857,
#      4858,
#      4859,
#      4860,
#      5065,
#      5066,
#      5067,
#      5068,
#      5069,
#      5070,
#      5071,
#      5072,
#      5073,
#      5074]},
#    {'catalog_name': 'photoz_dc2_object_run2.2i_dr3',
#     'matching_method': 'MATCHING_FORMAT',
#     'tracts': [2723,
#      2724,
#      2725,
#      2726,
#      2727,
#      2728,
#      2729,
#      2730,
#      2731,
#      2732,
#      2733,
#      2734,
#      2896,
#      2897,
#      2898,
#      2899,
#      2900,
#      2901,
#      2902,
#      2903,
#      2904,
#      2905,
#      2906,
#      2907,
#      2908,
#      3074,
#      3075,
#      3076,
#      3077,
#      3078,
#      3079,
#      3080,
#      3081,
#      3082,
#      3083,
#      3084,
#      3085,
#      3086,
#      3256,
#      3257,
#      3258,
#      3259,
#      3260,
#      3261,
#      3262,
#      3263,
#      3264,
#      3265,
#      3266,
#      3267,
#      3268,
#      3441,
#      3442,
#      3443,
#      3444,
#      3445,
#      3446,
#      3447,
#      3448,
#      3449,
#      3450,
#      3451,
#      3452,
#      3453,
#      3454,
#      3631,
#      3632,
#      3633,
#      3634,
#      3635,
#      3636,
#      3637,
#      3638,
#      3639,
#      3640,
#      3641,
#      3642,
#      3643,
#      3825,
#      3826,
#      3827,
#      3828,
#      3829,
#      3830,
#      3831,
#      3832,
#      3833,
#      3834,
#      3835,
#      3836,
#      3837,
#      4022,
#      4023,
#      4024,
#      4025,
#      4026,
#      4027,
#      4028,
#      4029,
#      4030,
#      4031,
#      4032,
#      4033,
#      4034,
#      4035,
#      4224,
#      4225,
#      4226,
#      4227,
#      4228,
#      4229,
#      4230,
#      4231,
#      4232,
#      4233,
#      4234,
#      4235,
#      4236,
#      4429,
#      4430,
#      4431,
#      4432,
#      4433,
#      4434,
#      4435,
#      4436,
#      4437,
#      4438,
#      4439,
#      4440,
#      4441,
#      4636,
#      4637,
#      4638,
#      4639,
#      4640,
#      4641,
#      4642,
#      4643,
#      4644,
#      4645,
#      4646,
#      4647,
#      4648,
#      4850,
#      4851,
#      4852,
#      4853,
#      4854,
#      4855,
#      4856,
#      4857,
#      4858,
#      4859,
#      4860,
#      5065,
#      5066,
#      5067,
#      5068,
#      5069,
#      5070,
#      5071,
#      5072,
#      5073,
#      5074]}],
#   'include_in_default_catalog_list': True},
#  'dc2_object_run2.2i_dr6': {'subclass_name': 'dc2_object.DC2ObjectParquetCatalog',
#   'base_dir': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run2.2i/dpdd/Run2.2i-dr6-v2/object_table_summary',
#   'pixel_scale': 0.2,
#   'description': 'DC2 Run 2.2i DR6 Object Table v2',
#   'creators': ['DESC DC2 Team']},
#  'dc2_object_run2.2i_dr6_v2_with_addons_v2': {'subclass_name': 'composite.CompositeReader',
#   'catalogs': [{'catalog_name': 'dc2_object_run2.2i_dr6_v2'},
#    {'subclass_name': 'dc2_metacal.DC2MetacalCatalog',
#     'base_dir': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run2.2i/dpdd/Run2.2i-dr6-v2/metacal_table_summary',
#     'bands': 'griz',
#     'apply_metacal_test3_fix': True,
#     'matching_partition': True,
#     'matching_row_order': True,
#     'overwrite_quantities': False,
#     'overwrite_attributes': False,
#     'include_native_quantities': True},
#    {'subclass_name': 'dc2_truth_match.DC2TruthMatchCatalog',
#     'base_dir': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run2.2i/truth/truth_merged_summary_v1-0-0/match_dr6_v2',
#     'as_object_addon': True,
#     'matching_partition': True,
#     'matching_row_order': True,
#     'overwrite_quantities': False,
#     'overwrite_attributes': False,
#     'include_native_quantities': False},
#    {'subclass_name': 'dc2_photoz_parquet.DC2PhotozCatalog',
#     'base_dir': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run2.2i/addons/photoz/dr6_v2',
#     'filename_pattern': 'photoz_pdf_Run2.2i_dr6_tract_\\d+\\.parquet$',
#     'matching_partition': True,
#     'matching_row_order': True,
#     'overwrite_quantities': False,
#     'overwrite_attributes': False,
#     'include_native_quantities': False}],
#   'description': 'DC2 Run 2.2i DR6 Object Table v2 with all available add-ons (currently only metacal and truth-match).\nThe truth-match addon was updated in May 2022.\n',
#   'creators': ['DESC DC2 Team'],
#   'include_in_default_catalog_list': True},
#  'dc2_object_run2.2i_dr6_with_addons': {'subclass_name': 'composite.CompositeReader',
#   'catalogs': [{'catalog_name': 'dc2_object_run2.2i_dr6_v2'},
#    {'subclass_name': 'dc2_metacal.DC2MetacalCatalog',
#     'base_dir': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run2.2i/dpdd/Run2.2i-dr6-v2/metacal_table_summary',
#     'bands': 'griz',
#     'apply_metacal_test3_fix': True,
#     'matching_partition': True,
#     'matching_row_order': True,
#     'overwrite_quantities': False,
#     'overwrite_attributes': False,
#     'include_native_quantities': True},
#    {'subclass_name': 'dc2_truth_match.DC2TruthMatchCatalog',
#     'base_dir': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run2.2i/truth/tract_partition/match_dr6_v2',
#     'as_object_addon': True,
#     'matching_partition': True,
#     'matching_row_order': True,
#     'overwrite_quantities': False,
#     'overwrite_attributes': False,
#     'include_native_quantities': False},
#    {'subclass_name': 'dc2_photoz_parquet.DC2PhotozCatalog',
#     'base_dir': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run2.2i/addons/photoz/dr6_v2',
#     'filename_pattern': 'photoz_pdf_Run2.2i_dr6_tract_\\d+\\.parquet$',
#     'matching_partition': True,
#     'matching_row_order': True,
#     'overwrite_quantities': False,
#     'overwrite_attributes': False,
#     'include_native_quantities': False}],
#   'description': 'DC2 Run 2.2i DR6 Object Table v2 with all available add-ons (currently only metacal and truth-match)',
#   'creators': ['DESC DC2 Team'],
#   'deprecated': 'Use dc2_object_run2.2i_dr6_v2_with_addons_v2 instead!'},
#  'dc2_redmagic_run2.2i_dr6_wfd_v0.8.1_highdens': {'subclass_name': 'redmagic.RedmagicCatalog',
#   'catalog_root_dir': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run2.2i/addons/redmagic/dr6-wfd',
#   'catalog_path_template': {'redmagic': 'dc2_dr6_run_redmapper_v0.8.1_redmagic_highdens-chi.fit'},
#   'sky_area': 302.65,
#   'cosmology': {'H0': 71.0,
#    'Om0': 0.2648,
#    'Ob0': 0.0448,
#    'sigma8': 0.8,
#    'n_s': 0.963},
#   'creators': ['Eli Rykoff'],
#   'description': 'RedMaGiC high density red galaxy catalog computed from the redMaPPer\ncluster finder (v0.8.1) run on run2.2i DR6 (WFD).\n',
#   'include_in_default_catalog_list': True},
#  'dc2_redmagic_run2.2i_dr6_wfd_v0.8.1_highlum': {'subclass_name': 'redmagic.RedmagicCatalog',
#   'catalog_root_dir': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run2.2i/addons/redmagic/dr6-wfd',
#   'catalog_path_template': {'redmagic': 'dc2_dr6_run_redmapper_v0.8.1_redmagic_highlum-chi.fit'},
#   'sky_area': 302.65,
#   'cosmology': {'H0': 71.0,
#    'Om0': 0.2648,
#    'Ob0': 0.0448,
#    'sigma8': 0.8,
#    'n_s': 0.963},
#   'creators': ['Eli Rykoff'],
#   'description': 'RedMaGiC high luminosity red galaxy catalog computed from the redMaPPer\ncluster finder (v0.8.1) run on run2.2i DR6 (WFD).\n',
#   'include_in_default_catalog_list': True},
#  'dc2_redmapper_run2.2i_dr6_wfd_v0.8.1': {'subclass_name': 'redmapper.RedmapperCatalog',
#   'catalog_root_dir': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run2.2i/addons/redmapper/dr6-wfd',
#   'catalog_path_template': {'clusters': 'dc2_dr6_run_redmapper_v0.8.1_lgt20_vl50_catalog.fit',
#    'members': 'dc2_dr6_run_redmapper_v0.8.1_lgt20_vl50_catalog_members.fit'},
#   'sky_area': 302.65,
#   'cosmology': {'H0': 71.0,
#    'Om0': 0.2648,
#    'Ob0': 0.0448,
#    'sigma8': 0.8,
#    'n_s': 0.963},
#   'creators': ['Eli Rykoff'],
#   'description': 'Cluster and member catalogs computed from the redMaPPer cluster finder\n(v0.8.1) and run on run2.2i DR6.  The red-sequence calibration was\nperformed with extra terms to account for the underestimation of color\nerrors from the cmodel fluxes.  This catalog can be compared to the\ncosmoDC2_v1.1.4_redmapper_v0.8.1 catalog.\n',
#   'include_in_default_catalog_list': True},
#  'dc2_run2.2i_truth_galaxy_summary': {'subclass_name': 'dc2_truth_parquet.DC2TruthParquetCatalog',
#   'base_dir': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run2.2i/truth/truth_galaxy_summary_v1-0-0',
#   'filename_pattern': 'truth_summary_hp{healpix}.parquet$',
#   'description': 'DC2 Run 2.2i  Summary truth table for galaxies',
#   'creators': ['DESC DC2 Team', 'Joanne Bogart']},
#  'dc2_run2.2i_truth_merged_summary': {'subclass_name': 'dc2_truth_match.DC2TruthMatchCatalog',
#   'base_dir': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run2.2i/truth/truth_merged_summary_v1-0-0/raw',
#   'description': 'DC2 Run 2.2i Truth Summary Table (all types merged), partitioned in tracts. Updated May 2022.',
#   'creators': ['DESC DC2 Team', 'Yao-Yuan Mao', 'Joanne Bogart']},
#  'dc2_run2.2i_truth_sn_summary': {'subclass_name': 'dc2_truth_parquet.DC2TruthParquetCatalog',
#   'base_dir': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run2.2i/truth/sntruth',
#   'filename_pattern': 'truth_sn_summary_v1-0-0.parquet$',
#   'description': 'DC2 Run 2.2i  Summary truth table for SNe restricted to DC2 footprint',
#   'creators': ['DESC DC2 Team', 'Joanne Bogart']},
#  'dc2_run2.2i_truth_sn_variability': {'subclass_name': 'dc2_truth_parquet.DC2TruthParquetCatalog',
#   'base_dir': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run2.2i/truth/sntruth',
#   'filename_pattern': 'truth_sn_variability_v1-0-0.parquet$',
#   'description': 'DC2 Run 2.2i  Variability truth table for SNe restricted to DC2 footprint',
#   'creators': ['DESC DC2 Team', 'Joanne Bogart']},
#  'dc2_run2.2i_truth_star_summary': {'subclass_name': 'dc2_truth_parquet.DC2TruthParquetCatalog',
#   'base_dir': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run2.2i/truth/startruth',
#   'filename_pattern': 'truth_star_summary_v1-0-0.parquet$',
#   'description': 'DC2 Run 2.2i  Summary truth table for stars restricted to DC2 footprint',
#   'creators': ['DESC DC2 Team', 'Joanne Bogart']},
#  'dc2_run2.2i_truth_star_variability': {'subclass_name': 'dc2_truth_parquet.DC2TruthParquetCatalog',
#   'base_dir': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run2.2i/truth/startruth',
#   'filename_pattern': 'truth_star_variability_v1-0-0.parquet$',
#   'description': 'DC2 Run 2.2i  Variability truth table for SNe restricted to DC2 footprint',
#   'creators': ['DESC DC2 Team', 'Joanne Bogart']},
#  'dc2_truth_run1.2_static': {'subclass_name': 'dc2_truth.DC2TruthCatalogReader',
#   'filename': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run1.2/truth/run_1.2_trial_static.db',
#   'description': 'Truth catalog for Run 1.2. Static objects.\nNo internal or MW extinction is applied.\n'},
#  'dc2_truth_run1.2_variable_lightcurve': {'subclass_name': 'dc2_truth.DC2TruthCatalogLightCurveReader',
#   'filename': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run1.2/truth/run_1.2_trial_light_curves_181004.db',
#   'table_light_curves': 'light_curves',
#   'table_summary': 'variables_and_transients',
#   'table_obs_metadata': 'obs_metadata',
#   'description': 'Truth catalog for Run 1.2, light curve tables for variable objects.\n',
#   'include_in_default_catalog_list': True},
#  'dc2_truth_run1.2_variable_summary': {'subclass_name': 'dc2_truth.DC2TruthLCSummaryReader',
#   'filename': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run1.2/truth/run1p2_light_curve_reference_190311.h5',
#   'description': 'Truth catalog for Run 1.2, summary table for variable objects.\n',
#   'include_in_default_catalog_list': True},
#  'dc2_truth_run3.1i_agn_auxiliary_info': {'subclass_name': 'dc2_truth_parquet.DC2TruthParquetCatalog',
#   'base_dir': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run3.1i/truth/agntruth',
#   'filename_pattern': 'agn_auxiliary_info.parquet$',
#   'description': 'DC2 Run 3.1i  Auxiliary info truth table for agn',
#   'creators': ['DESC DC2 Team', 'Joanne Bogart'],
#   'include_in_default_catalog_list': True},
#  'dc2_truth_run3.1i_agn_truth_summary': {'subclass_name': 'dc2_truth_parquet.DC2TruthParquetCatalog',
#   'base_dir': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run3.1i/truth/agntruth',
#   'filename_pattern': 'agn_truth_summary.parquet$',
#   'description': 'DC2 Run 3.1i  Summary truth table for agn',
#   'creators': ['DESC DC2 Team', 'Joanne Bogart'],
#   'include_in_default_catalog_list': True},
#  'dc2_truth_run3.1i_agn_variability_truth': {'subclass_name': 'dc2_truth_parquet.DC2TruthParquetCatalog',
#   'base_dir': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run3.1i/truth/agntruth',
#   'filename_pattern': 'agn_variability_truth.parquet$',
#   'description': 'DC2 Run 3.1i  Variability truth table for agn',
#   'creators': ['DESC DC2 Team', 'Joanne Bogart'],
#   'include_in_default_catalog_list': True},
#  'dc2_truth_run3.1i_lensed_agn_truth_summary': {'subclass_name': 'dc2_truth_parquet.DC2TruthParquetCatalog',
#   'base_dir': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run3.1i/truth/lensed_agntruth',
#   'filename_pattern': 'lensed_agn_truth_summary.parquet$',
#   'description': 'DC2 Run 3.1i  Summary truth table for lensed agn',
#   'creators': ['DESC DC2 Team', 'Joanne Bogart'],
#   'include_in_default_catalog_list': True},
#  'dc2_truth_run3.1i_lensed_agn_variability_truth': {'subclass_name': 'dc2_truth_parquet.DC2TruthParquetCatalog',
#   'base_dir': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run3.1i/truth/lensed_agntruth',
#   'filename_pattern': 'lensed_agn_variability_truth.parquet$',
#   'description': 'DC2 Run 3.1i  Variability truth table for lensed agn',
#   'creators': ['DESC DC2 Team', 'Joanne Bogart'],
#   'include_in_default_catalog_list': True},
#  'dc2_truth_run3.1i_lensed_host_truth_summary': {'subclass_name': 'dc2_truth_parquet.DC2TruthParquetCatalog',
#   'base_dir': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run3.1i/truth/lensed_hosttruth',
#   'filename_pattern': 'lensed_host_truth_summary.parquet$',
#   'description': 'DC2 Run 3.1i  Summary truth table for lensed host galaxies',
#   'creators': ['DESC DC2 Team', 'Joanne Bogart'],
#   'include_in_default_catalog_list': True},
#  'dc2_truth_run3.1i_lensed_sn_variability_truth': {'subclass_name': 'dc2_truth_parquet.DC2TruthParquetCatalog',
#   'base_dir': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run3.1i/truth/lensed_snetruth',
#   'filename_pattern': 'lensed_sn_variability_truth.parquet$',
#   'description': 'DC2 Run 3.1i  Variability truth table for lensed SNe',
#   'creators': ['DESC DC2 Team', 'Joanne Bogart'],
#   'include_in_default_catalog_list': True},
#  'dc2_truth_run3.1i_lensed_sne_truth_summary': {'subclass_name': 'dc2_truth_parquet.DC2TruthParquetCatalog',
#   'base_dir': '/global/cfs/cdirs/lsst/shared/DC2-prod/Run3.1i/truth/lensed_snetruth',
#   'filename_pattern': 'lensed_sne_truth_summary.parquet$',
#   'description': 'DC2 Run 3.1i  Summary truth table for lensed SNe',
#   'creators': ['DESC DC2 Team', 'Joanne Bogart'],
#   'include_in_default_catalog_list': True},
#  'protoDC2': {'subclass_name': 'alphaq.AlphaQGalaxyCatalog',
#   'filename': '/global/cfs/cdirs/lsst/shared/xgal/protoDC2/v5.0.all.hdf5',
#   'lightcone': True,
#   'version': '5.0',
#   'md5': 'd2f5ad1bb91ad4549b6f58072f9f88af',
#   'creators': ['Andrew Benson',
#    'Andrew Hearin',
#    'Katrin Heitmann',
#    'Joe Hollowed',
#    'Danila Korytov',
#    'Eve Kovacs',
#    'Patricia Larsen'],
#   'description': 'ProtoDC2 is a down-scaled version of the catalog to be generated for LSST-DESC DC2.\nFor a description of the catalog and the methods, please see https://goo.gl/fXDQwP\n'},
#  'protoDC2_run1.2': {'subclass_name': 'alphaq.AlphaQGalaxyCatalog',
#   'filename': '/global/cfs/cdirs/lsst/shared/xgal/protoDC2/ANL_AlphaQ_v3.0.hdf5',
#   'lightcone': True,
#   'version': '3.0.0',
#   'creators': ['Andrew Benson',
#    'Andrew Hearin',
#    'Katrin Heitmann',
#    'Danila Korytov',
#    'Eve Kovacs'],
#   'description': 'ProtoDC2 is a down-scaled version of the catalog to be generated for LSST-DESC DC2.\nFor a description of the catalog and the methods, please see https://goo.gl/fXDQwP\n'},
#  'skysim5000_v1.1.1': {'subclass_name': 'cosmodc2.SkySim5000GalaxyCatalog',
#   'catalog_root_dir': '/global/cfs/cdirs/lsst/shared/xgal/skysim//skysim5000_v1.1.1',
#   'catalog_filename_template': 'z_{}_{}.step_all.healpix_{}.hdf5',
#   'cosmology': {'H0': 71.0,
#    'Om0': 0.2648,
#    'Ob0': 0.0448,
#    'sigma8': 0.8,
#    'n_s': 0.963},
#   'lightcone': True,
#   'version': '1.1.1',
#   'check_md5': False,
#   'check_size': False,
#   'check_cosmology': False,
#   'ensure_meta_consistent': False,
#   'sky_area': 5264.05,
#   'creators': ['Andrew Hearin',
#    'Danila Korytov',
#    'Eve Kovacs',
#    'Esteban Rangel',
#    'Patricia Larsen',
#    'Joe Hollowed',
#    'Andrew Benson',
#    'Katrin Heitmann'],
#   'description': 'This is the 5000 sq. deg. extra-galactic catalog for LSST DESC\n',
#   'include_in_default_catalog_list': True},
#  'skysim5000_v1.1.1_redmagic_v0.8.5_highdens': {'subclass_name': 'redmagic.RedmagicCatalog',
#   'catalog_root_dir': '/global/cfs/cdirs/lsst/shared/xgal/skysim/addons/redmagic_v1.1.1',
#   'catalog_path_template': {'redmagic': 'skysim_5000_v1.1.1_run_redmapper_v0.8.5_redmagic_highdens-chi.fit'},
#   'sky_area': 5000.0,
#   'cosmology': {'H0': 71.0,
#    'Om0': 0.2648,
#    'Ob0': 0.0448,
#    'sigma8': 0.8,
#    'n_s': 0.963},
#   'creators': ['Eli Rykoff'],
#   'description': 'RedMaGiC high density red galaxy catalog computed from the redMaPPer\ncluster finder (v0.8.5) run on skysim5000 v1.1.1.\n',
#   'include_in_default_catalog_list': True},
#  'skysim5000_v1.1.1_redmagic_v0.8.5_highlum': {'subclass_name': 'redmagic.RedmagicCatalog',
#   'catalog_root_dir': '/global/cfs/cdirs/lsst/shared/xgal/skysim/addons/redmagic_v1.1.1',
#   'catalog_path_template': {'redmagic': 'skysim_5000_v1.1.1_run_redmapper_v0.8.5_redmagic_highlum-chi.fit'},
#   'sky_area': 5000.0,
#   'cosmology': {'H0': 71.0,
#    'Om0': 0.2648,
#    'Ob0': 0.0448,
#    'sigma8': 0.8,
#    'n_s': 0.963},
#   'creators': ['Eli Rykoff'],
#   'description': 'RedMaGiC high luminosity red galaxy catalog computed from the redMaPPer\ncluster finder (v0.8.5) run on skysim5000 v1.1.1.\n',
#   'include_in_default_catalog_list': True},
#  'skysim5000_v1.1.1_redmapper_v0.8.5': {'subclass_name': 'redmapper.RedmapperCatalog',
#   'catalog_root_dir': '/global/cfs/cdirs/lsst/shared/xgal/skysim/addons/redmapper_v1.1.1',
#   'catalog_path_template': {'clusters': 'skysim_5000_v1.1.1_run_redmapper_v0.8.5_lgt20_catalog.fit',
#    'members': 'skysim_5000_v1.1.1_run_redmapper_v0.8.5_lgt20_catalog_members.fit'},
#   'sky_area': 5000.0,
#   'cosmology': {'H0': 71.0,
#    'Om0': 0.2648,
#    'Ob0': 0.0448,
#    'sigma8': 0.8,
#    'n_s': 0.963},
#   'creators': ['Eli Rykoff'],
#   'description': 'Cluster and member catalogs computed from the redMaPPer cluster finder\n(v0.8.5) run on skysim5000 v1.1.1.  Richness selection is lambda > 20.\n',
#   'include_in_default_catalog_list': True},
#  'skysim5000_v1.1.2': {'subclass_name': 'cosmodc2.SkySim5000GalaxyCatalog',
#   'catalog_root_dir': '/global/cfs/cdirs/lsst/shared/xgal/skysim/skysim5000_v1.1.2',
#   'catalog_filename_template': 'z_{}_{}.step_all.healpix_{}.hdf5',
#   'cosmology': {'H0': 71.0,
#    'Om0': 0.2648,
#    'Ob0': 0.0448,
#    'sigma8': 0.8,
#    'n_s': 0.963},
#   'lightcone': True,
#   'version': '1.1.1',
#   'check_md5': False,
#   'check_size': False,
#   'check_cosmology': False,
#   'ensure_meta_consistent': False,
#   'sky_area': 5264.05,
#   'creators': ['Andrew Hearin',
#    'Danila Korytov',
#    'Eve Kovacs',
#    'Esteban Rangel',
#    'Patricia Larsen',
#    'Joe Hollowed',
#    'Andrew Benson',
#    'Katrin Heitmann'],
#   'description': 'This is the 5000 sq. deg. extra-galactic catalog for LSST DESC\n',
#   'include_in_default_catalog_list': True},
#  'skysim5000_v1.2': {'subclass_name': 'cosmodc2.SkySim5000GalaxyCatalog',
#   'catalog_root_dir': '/global/cfs/cdirs/lsst/shared/xgal/skysim/skysim5000_v1.2',
#   'catalog_filename_template': 'z_{}_{}.step_all.healpix_{}.hdf5',
#   'cosmology': {'H0': 71.0,
#    'Om0': 0.2648,
#    'Ob0': 0.0448,
#    'sigma8': 0.8,
#    'n_s': 0.963},
#   'lightcone': True,
#   'version': '1.2',
#   'check_md5': False,
#   'check_size': False,
#   'check_cosmology': False,
#   'ensure_meta_consistent': False,
#   'sky_area': 5264.05,
#   'creators': ['Andrew Hearin',
#    'Danila Korytov',
#    'Eve Kovacs',
#    'Esteban Rangel',
#    'Patricia Larsen',
#    'Joe Hollowed',
#    'Andrew Benson',
#    'Katrin Heitmann'],
#   'description': 'This is the 5000 sq. deg. extra-galactic catalog for LSST DESC\n',
#   'include_in_default_catalog_list': True},
#  'skysim_v3.1.0': {'subclass_name': 'cosmodc2.DiffSkyGalaxyCatalog',
#   'catalog_root_dir': '/global/cfs/cdirs/lsst/shared/xgal/skysim/skysim_v3.1.0',
#   'catalog_filename_template': 'skysim_z_{}_{}_cutout_{}.hdf5',
#   'cosmology': {'H0': 71.0,
#    'Om0': 0.2648,
#    'Ob0': 0.0448,
#    'sigma8': 0.8,
#    'n_s': 0.963},
#   'lightcone': True,
#   'version': '3.1.0',
#   'check_md5': False,
#   'check_size': False,
#   'check_cosmology': False,
#   'ensure_meta_consistent': False,
#   'sky_area': 439.78986,
#   'creators': ['Andrew Hearin',
#    'Eve Kovacs',
#    'Esteban Rangel',
#    'Patricia Larsen',
#    'Katrin Heitmann'],
#   'description': 'This is the 440 sq. deg. (DC2 area) extra-galactic catalog for LSST DESC that has been created with fully forward modeled SEDs  \n',
#   'include_in_default_catalog_list': True}}

# %%
R_min = min(dt_halos["richness"])
R_max = max(dt_halos["richness"])

print(R_min, R_max)
# Out:
# 3.0552082 66.10402

# %%
lnM = np.log(dt_halos["m200c"])  # ln(mass)
z = dt_halos["redshift_true"]  # redshift
lnR = np.log(dt_halos["richness"])  # ln(richness)

# %% [markdown]
# ## Training and test sets

# %%
X = pd.DataFrame({'m200c': list(dt_halos["m200c"]), 'redshift_true': list(dt_halos["redshift_true"])})
y = pd.DataFrame({'richness': list(dt_halos["richness"])})

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=0)

#Training data
data_train = pd.concat([X_train, y_train], axis=1)

#Test  data
data_test = pd.concat([X_test, y_test], axis=1)

# print( data_test.shape, X_test.shape, y_test.shape )
# print( data_train.shape, X_train.shape, y_train.shape )

# print( data_test.shape[0] + data_train.shape[0] )

# print( len(dt_halos) )

# %% [markdown]
# ## Bins
#
# Nestas células fazemos um recorte de intervalos de z de largura 0.05 e esses intervalos são colocados em **halos_bin_z**. Depois, pegamos cada *bin* em z e cortamos em intervalos de lnM de largura 0.25. Os bins são colocados em **halos_bin_mz**.
#
# Para cada intervalo em **halos_bin_mz** é calculado lnR médio, z médio e lnM médio e as listas desses valores são colocadas na tabela **halos_mean**.

# %%
# redshift bins
def Binningf(data_set):
    
    z_ds = data_set["redshift_true"]
    lnm_ds = np.log(data_set["m200c"])
    
    d = 0.05
    d_m = 0.25
    
    z_bins = int((max(z_ds) - min (z_ds)) // d  + 1)
    m_bins = int((max(lnm_ds) - min (lnm_ds)) // d_m + 1)

    z_0 = 0.0
    z_1 = d
    halos_bin_z =[]

    for i in range(z_bins):
        cut_z = np.logical_and (data_set['redshift_true'] > z_0, data_set['redshift_true'] < z_1)
        halos_bin_z.append(data_set[cut_z])
        z_0 = z_0 + d
        z_1 = z_1 + d

    # mass bins
    label = []
    halos_bin_mz =[]
    for i in range(z_bins):

        lnM_0 = min(lnM)
        lnM_1 = min(lnM) + d_m
        for j in range(m_bins):

            cut = np.logical_and (np.log(halos_bin_z[i]["m200c"]) > lnM_0, np.log(halos_bin_z[i]["m200c"]) < lnM_1)
            halos_bin_mz.append(halos_bin_z[i][cut])
            #label.append(f"{min(halos_bin_z[i]['redshift_true']):.3f} < z < {max(halos_bin_z[i]['redshift_true']):.3f}\n{lnM_0:.3f} < lnM < {lnM_1:.3f}")

            lnM_0 = lnM_0 + d_m
            lnM_1 = lnM_1 + d_m
    
            lnM_1 = lnM_1 + d_m
    
    return halos_bin_mz

print(f'Total bins in halos_bin_mz: {len(Binningf(data_train))}')
# Out:
# Total bins in halos_bin_mz: 144

# %%
def bin_meanf(data_set):
    lnM_binned, z_binned, lnR_binned = [], [], [] 

    binned_halos = Binningf(data_set)

    for i in range(len(binned_halos)):

        halos = binned_halos[i]
        lnM_binned.append(np.log(halos["m200c"]))
        z_binned.append(halos["redshift_true"])
        lnR_binned.append(np.log(halos["richness"]))   

    lnR_mean, lnM_mean, z_mean = [np.mean(l) for l in lnR_binned if len(l) > 0], [np.mean(l) for l in lnM_binned if len(l) > 0], [np.mean(k) for k in z_binned if len(k) > 0]
    
    lnR_std = np.array([np.std(l) for l in lnR_binned if len(l) > 0])

    
    halos_mean = Table([np.exp(np.array(lnR_mean)), np.exp(np.array(lnM_mean)), z_mean],
               names=('richness', 'm200c', 'redshift_true'))
    
    return halos_mean, lnM_binned, z_binned, lnR_binned, lnR_std

print(f'Total bins in halos_mean: {len(bin_meanf(data_train)[0])}')
# Out:
# Total bins in halos_mean: 89

# %% [markdown]
# ## Models fit

# %%
def Model_fit(mod, data_set):
    
    #data_set
    dt_halos = protoDC2_v3_redmapper
    rmdata = create_richness_mass_calib(data_set)
    
    fixed_parameters = [] 
    
    #Swicth
    match mod:
        case "ext_ln1pz":
            model = Nc.ClusterMassLnrichExt(use_ln1pz = True)
            fixed_parameters = [12, 13, 14] #fixing cut parameters
            
        case "ext_z":
            model = Nc.ClusterMassLnrichExt(use_ln1pz = False)
            fixed_parameters = [12, 13, 14] #fixing cut parameters
            
        case "ascaso":
            model = Nc.ClusterMassAscaso()
            fixed_parameters = [6] #fixing cut parameter
    
    #Model
    model.param_set_by_name("cut", 1e15) #Set cut parameter value 
    mset = Ncm.MSet()
    mset.set(model)
    rmdata.m2lnL_val(mset)  
    mset.param_set_all_ftype(Ncm.ParamType.FREE) #All parameters free
    
    #Data
    dset = Ncm.Dataset.new()
    dset.append_data(rmdata)
    
    #Likelihood
    lh = Ncm.Likelihood.new(dset)
  
    #All parameters free except cut parameters:
    for par in fixed_parameters:
        mset.param_set_ftype(7000, par, Ncm.ParamType.FIXED)
    
    mset.prepare_fparam_map()
    
    #Fit
    fit = Ncm.Fit.factory( Ncm.FitType.NLOPT, "ln-neldermead", lh, mset, Ncm.FitGradType.NUMDIFF_CENTRAL )
    fit.log_info()
    fit.run_restart(Ncm.FitRunMsgs.SIMPLE, 1.0e-3, 0.0, None, None)
    fit.log_info()
    
    #Binning data_set
    bin_f= bin_meanf(data_set)
    halos_mean = bin_f[0]
    lnM_mean = np.log(halos_mean["m200c"])
    z_mean = halos_mean["redshift_true"]
    
    # Mean and std of data_set z mean and lnM mean
    lnR_mean_model = np.array([model.get_mean_richness(lnM_mean[i], z_mean[i]) for i in range(len(halos_mean))])
    lnR_std_model = np.array( [model.get_std_richness(lnM_mean[i], z_mean[i]) for i in range(len(halos_mean))])
    
    return lnR_mean_model, lnR_std_model, model

# %% [markdown]
# ## Ascaso Fit Params
#
# Aqui fazemos o ajuste do modelo de ascaso e encontramos os valores dos parâmetros usando todos os dados em **dt_halos** (sem dividir em intervalos).
#
# \begin{equation}
#     \left< \ln R | M, z \right> = \mu_0 + \mu_1 \ln\left( \frac{M}{M_0} \right) +  \mu_2\ln\left(\frac{1 + z}{1 + z_0}\right);
# \end{equation}
#
# $$\textbf{p}_{1} = \{\mu_0, \mu_1, \mu_2, \sigma_0, \sigma_1, \sigma_2\}. $$

# %%
lnR_mean_ascaso, lnR_std_ascaso, ascaso = Model_fit('ascaso', data_train)
# Out:
# #----------------------------------------------------------------------------------
# # Data used:
# #   - NcDataClusterMassRich
# #----------------------------------------------------------------------------------
# # Model[07000]:
# #   - NcClusterMass : Ascaso Ln-normal richness distribution
# #----------------------------------------------------------------------------------
# # Model parameters
# #   -    mup0[00]:  3.19                [FREE]
# #   -    mup1[01]:  0.868588963806504   [FREE]
# #   -    mup2[02]: -0.304006137332276   [FREE]
# #   - sigmap0[03]:  0.33                [FREE]
# #   - sigmap1[04]: -0.0347435585522601  [FREE]
# #   - sigmap2[05]:  0                   [FREE]
# #   -     cut[06]:  1e+15               [FIXED]
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #................................................................................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0312210
# #  iteration            [000714]
# #  function evaluations [000716]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000372]
# #  m2lnL     =     264.611785950538 (     264.61179 )
# #  Fit parameters:
# #     3.82276426371363       0.800082638442411      1.13566406003146       0.233531191721754     -0.121967658211954      0.153119136915398
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 1516.04638530585
# #  - relative improvement: 0.851396640735468
# #  - m2lnL_0  :            1780.65817125639
# #  - m2lnL_1  :            264.611785950538
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.....................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0076120
# #  iteration            [000124]
# #  function evaluations [000126]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000372]
# #  m2lnL     =     264.611785950538 (     264.61179 )
# #  Fit parameters:
# #     3.82276426371363       0.800082638442411      1.13566406003146       0.233531191721754     -0.121967658211954      0.153119136915398
# #----------------------------------------------------------------------------------
# # Restarting:              no
# #  - absolute improvement: 0
# #  - relative improvement: 0
# #  - m2lnL_1  :            264.611785950538
# #  - m2lnL_2  :            264.611785950538
# #----------------------------------------------------------------------------------
# # Data used:
# #   - NcDataClusterMassRich
# #----------------------------------------------------------------------------------
# # Model[07000]:
# #   - NcClusterMass : Ascaso Ln-normal richness distribution
# #----------------------------------------------------------------------------------
# # Model parameters
# #   -    mup0[00]:  3.82276426371363    [FREE]
# #   -    mup1[01]:  0.800082638442411   [FREE]
# #   -    mup2[02]:  1.13566406003146    [FREE]
# #   - sigmap0[03]:  0.233531191721754   [FREE]
# #   - sigmap1[04]: -0.121967658211954   [FREE]
# #   - sigmap2[05]:  0.153119136915398   [FREE]
# #   -     cut[06]:  1e+15               [FIXED]

# %% [markdown]
# ## Ext (ln(1+z)) Fit Params
#
# Aqui fazemos o ajuste do modelo extendido considerando a dependencia em $\ln (1 + z)$, também usando todos os dados em **dt_halos** .
#
# \begin{equation}\label{M_R_3}
# \begin{split}
#     \left<\ln R | M, z \right> = \mu_0 +
#     \mu_{M1} \ln\left( \frac{M}{M_0} \right) +
#     \mu_{M2} (\ln\left(\frac{M}{M_0} \right))^2 +\\
#     + \mu_{z1} \ln\left(\frac{1 + z}{1 + z_0}\right) +
#     \mu_{z2} (\ln\left(\frac{1 + z}{1 + z_0}\right))^2 +\\
#     + \mu_{Mz} \ln\left(\frac{1 + z}{1 + z_0}\right)\ln\left(\frac{M}{M_0} \right);
# \end{split}
# \end{equation}
#
# $$\textbf{p}_{2} = \{\mu_0, \mu_{M1}, \mu_{M2}, \mu_{Z1}, \mu_{Z2}, \mu_{MZ}, \sigma_0, \sigma_{M1}, \sigma_{M2}, \sigma_{Z1}, \sigma_{Z2}, \sigma_{MZ} \}.$$

# %%
lnR_mean_ext_ln1pz, lnR_std_ext_ln1pz, ext_ln1pz = Model_fit('ext_ln1pz', data_train)
# Out:
# #----------------------------------------------------------------------------------
# # Data used:
# #   - NcDataClusterMassRich
# #----------------------------------------------------------------------------------
# # Model[07000]:
# #   - NcClusterMass : LnrichExt Ln-normal richness distribution
# #----------------------------------------------------------------------------------
# # Model parameters
# #   -      mu[00]:  3.19                [FREE]
# #   -    muM1[01]:  0.868588963806504   [FREE]
# #   -    muZ1[02]: -0.304006137332276   [FREE]
# #   -    muM2[03]:  0                   [FREE]
# #   -    muZ2[04]:  0                   [FREE]
# #   -    muMZ[05]:  0                   [FREE]
# #   -  sigma0[06]:  0.33                [FREE]
# #   - sigmaM1[07]: -0.0347435585522601  [FREE]
# #   - sigmaZ1[08]:  0                   [FREE]
# #   - sigmaM2[09]:  0                   [FREE]
# #   - sigmaZ2[10]:  0                   [FREE]
# #   - sigmaMZ[11]:  0                   [FREE]
# #   -     cut[12]:  1e+15               [FIXED]
# #   -   cutM1[13]:  0                   [FIXED]
# #   -   cutZ1[14]:  0                   [FIXED]
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #................................................................................................................................................................................................................................................................................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.1751130
# #  iteration            [002634]
# #  function evaluations [002636]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000366]
# #  m2lnL     =     281.646637932195 (     281.64664 )
# #  Fit parameters:
# #     2.93223874600638      -0.5098878687757       -0.140168884566106     -0.443275740798778     -0.378027037212205     -0.538121595871302      0.499992759480178      0.172732436134032      0.476766598071855      0.078586951311996      0.17915190060568       0.14881239541266
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 1499.01153332419
# #  - relative improvement: 0.841830036512021
# #  - m2lnL_0  :            1780.65817125639
# #  - m2lnL_1  :            281.646637932195
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #..................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.3543860
# #  iteration            [005055]
# #  function evaluations [005057]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000366]
# #  m2lnL     =     248.221669096313 (     248.22167 )
# #  Fit parameters:
# #     3.67776132578409       0.575040134406559      2.70113523558129      -0.0975976789898694     2.95271410130578       0.87633239120908       0.0732523737329931    -0.377677231610491      0.117591686313041     -0.0914241426418477    -0.376954121499619     -0.0107546791776994
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 33.4249688358825
# #  - relative improvement: 0.11867696728526
# #  - m2lnL_1  :            281.646637932195
# #  - m2lnL_2  :            248.221669096313
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #...............................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0155340
# #  iteration            [000223]
# #  function evaluations [000225]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000366]
# #  m2lnL     =     248.221668940198 (     248.22167 )
# #  Fit parameters:
# #     3.67771544363824       0.575024702406026      2.70120860426639      -0.0975918510168142     2.95298829416754       0.876374001859659      0.0732443243151312    -0.377683737642824      0.117836577966729     -0.0914207730099925    -0.376373022692634     -0.010633699671327
# #----------------------------------------------------------------------------------
# # Restarting:              no
# #  - absolute improvement: 1.56115163463255e-07
# #  - relative improvement: 6.28934468258211e-10
# #  - m2lnL_2  :            248.221669096313
# #  - m2lnL_3  :            248.221668940198
# #----------------------------------------------------------------------------------
# # Data used:
# #   - NcDataClusterMassRich
# #----------------------------------------------------------------------------------
# # Model[07000]:
# #   - NcClusterMass : LnrichExt Ln-normal richness distribution
# #----------------------------------------------------------------------------------
# # Model parameters
# #   -      mu[00]:  3.67771544363824    [FREE]
# #   -    muM1[01]:  0.575024702406026   [FREE]
# #   -    muZ1[02]:  2.70120860426639    [FREE]
# #   -    muM2[03]: -0.0975918510168142  [FREE]
# #   -    muZ2[04]:  2.95298829416754    [FREE]
# #   -    muMZ[05]:  0.876374001859659   [FREE]
# #   -  sigma0[06]:  0.0732443243151312  [FREE]
# #   - sigmaM1[07]: -0.377683737642824   [FREE]
# #   - sigmaZ1[08]:  0.117836577966729   [FREE]
# #   - sigmaM2[09]: -0.0914207730099925  [FREE]
# #   - sigmaZ2[10]: -0.376373022692634   [FREE]
# #   - sigmaMZ[11]: -0.010633699671327   [FREE]
# #   -     cut[12]:  1e+15               [FIXED]
# #   -   cutM1[13]:  0                   [FIXED]
# #   -   cutZ1[14]:  0                   [FIXED]

# %% [markdown]
# ## Ext (z) Fit Params
#
#
# Aqui consideramos o ajuste do modelo extendido considerando a dependência em $ z$, também usando todos os dados em **dt_halos** .
#
# \begin{equation}\label{M_R_3}
# \begin{split}
#     \left<\ln R | M, z \right> = \mu_0 +
#     \mu_{M1} \ln\left( \frac{M}{M_0} \right) +
#     \mu_{M2} (\ln\left(\frac{M}{M_0} \right))^2 +\\
#     + \mu_{z1} \left(\frac{ z}{z_0}\right) +
#     \mu_{z2} \left(\frac{z}{z_0}\right)^2 +
#     \mu_{Mz} \left(\frac{z}{z_0}\right)\ln\left(\frac{M}{M_0} \right);
# \end{split}
# \end{equation}
#
# $$\textbf{p}_{2} = \{\mu_0, \mu_{M1}, \mu_{M2}, \mu_{Z1}, \mu_{Z2}, \mu_{MZ}, \sigma_0, \sigma_{M1}, \sigma_{M2}, \sigma_{Z1}, \sigma_{Z2}, \sigma_{MZ} \}.$$

# %%
lnR_mean_ext_z, lnR_std_ext_z, ext_z = Model_fit('ext_z', data_train)
# Out:
# #----------------------------------------------------------------------------------
# # Data used:
# #   - NcDataClusterMassRich
# #----------------------------------------------------------------------------------
# # Model[07000]:
# #   - NcClusterMass : LnrichExt Ln-normal richness distribution
# #----------------------------------------------------------------------------------
# # Model parameters
# #   -      mu[00]:  3.19                [FREE]
# #   -    muM1[01]:  0.868588963806504   [FREE]
# #   -    muZ1[02]: -0.304006137332276   [FREE]
# #   -    muM2[03]:  0                   [FREE]
# #   -    muZ2[04]:  0                   [FREE]
# #   -    muMZ[05]:  0                   [FREE]
# #   -  sigma0[06]:  0.33                [FREE]
# #   - sigmaM1[07]: -0.0347435585522601  [FREE]
# #   - sigmaZ1[08]:  0                   [FREE]
# #   - sigmaM2[09]:  0                   [FREE]
# #   - sigmaZ2[10]:  0                   [FREE]
# #   - sigmaMZ[11]:  0                   [FREE]
# #   -     cut[12]:  1e+15               [FIXED]
# #   -   cutM1[13]:  0                   [FIXED]
# #   -   cutZ1[14]:  0                   [FIXED]
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #..........................................................................................................................................................................................................................................................................................................................................................................................................................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.1837080
# #  iteration            [004015]
# #  function evaluations [004017]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000366]
# #  m2lnL     =     248.321203771859 (      248.3212 )
# #  Fit parameters:
# #     2.96070149973208       0.176462659953072      0.348751412355587     -0.112189106648747      0.323814459337346      0.343811074878164      0.000101668249191912  -0.281541758607231      0.214821920137878     -0.0534173430399129    -0.0695313283792408     0.0137024647625315
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 3032.65281019447
# #  - relative improvement: 0.924314791060577
# #  - m2lnL_0  :            3280.97401396633
# #  - m2lnL_1  :            248.321203771859
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #..................................................................................................................................................................................................................................................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.1087970
# #  iteration            [002337]
# #  function evaluations [002339]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000366]
# #  m2lnL     =     247.974204632449 (      247.9742 )
# #  Fit parameters:
# #     3.04622421324217       0.229266418935978      0.233941294574628     -0.0971072933244696     0.377184862134084      0.33666389503415       0.0001                -0.335370650302375      0.138299008383306     -0.0778971106401067    -0.0434706649110516    -0.00360581173447653
# #----------------------------------------------------------------------------------
# # Restarting:              yes
# #  - absolute improvement: 0.34699913940949
# #  - relative improvement: 0.00139738022423687
# #  - m2lnL_1  :            248.321203771859
# #  - m2lnL_2  :            247.974204632449
# #----------------------------------------------------------------------------------
# # Model fitting. Interating using:
# #  - solver:            NLOpt:ln-neldermead
# #  - differentiation:   Numerical differentiantion (central)
# #.......................................................
# #  Minimum found with precision: |df|/f =  1.00000e-08 and |dx| =  1.00000e-05
# #  Elapsed time: 00 days, 00:00:00.0237820
# #  iteration            [000463]
# #  function evaluations [000465]
# #  gradient evaluations [000000]
# #  degrees of freedom   [000366]
# #  m2lnL     =     247.974120162661 (     247.97412 )
# #  Fit parameters:
# #     3.04606290290428       0.230028949897397      0.235028512795952     -0.0965415663896367     0.377297356764241      0.337474545584795      0.000102529686846224  -0.335565052013578      0.137771600962785     -0.078031022066962     -0.0433670450322633    -0.00390090634197439
# #----------------------------------------------------------------------------------
# # Restarting:              no
# #  - absolute improvement: 8.44697883621848e-05
# #  - relative improvement: 3.40639416456187e-07
# #  - m2lnL_2  :            247.974204632449
# #  - m2lnL_3  :            247.974120162661
# #----------------------------------------------------------------------------------
# # Data used:
# #   - NcDataClusterMassRich
# #----------------------------------------------------------------------------------
# # Model[07000]:
# #   - NcClusterMass : LnrichExt Ln-normal richness distribution
# #----------------------------------------------------------------------------------
# # Model parameters
# #   -      mu[00]:  3.04606290290428    [FREE]
# #   -    muM1[01]:  0.230028949897397   [FREE]
# #   -    muZ1[02]:  0.235028512795952   [FREE]
# #   -    muM2[03]: -0.0965415663896367  [FREE]
# #   -    muZ2[04]:  0.377297356764241   [FREE]
# #   -    muMZ[05]:  0.337474545584795   [FREE]
# #   -  sigma0[06]:  0.000102529686846224 [FREE]
# #   - sigmaM1[07]: -0.335565052013578   [FREE]
# #   - sigmaZ1[08]:  0.137771600962785   [FREE]
# #   - sigmaM2[09]: -0.078031022066962   [FREE]
# #   - sigmaZ2[10]: -0.0433670450322633  [FREE]
# #   - sigmaMZ[11]: -0.00390090634197439 [FREE]
# #   -     cut[12]:  1e+15               [FIXED]
# #   -   cutM1[13]:  0                   [FIXED]
# #   -   cutZ1[14]:  0                   [FIXED]

# %% [markdown]
# ## Comparison I

# %%
def Plot_model(lnR_mean_model, data_set):

    fig = plt.figure(figsize=(6,8))
    gs = gridspec.GridSpec(nrows=2, ncols=2, width_ratios=[1, 1], height_ratios=[2.5, 1], wspace=0.4)
    
    ax1 = fig.add_subplot(gs[0, :], projection='3d')
    ax2 = fig.add_subplot(gs[1, 0])
    ax3 = fig.add_subplot(gs[1, 1])

    #lnR model, z_mean, y_mean
    halos_mean = bin_meanf(data_set)[0]
    lnR_mean = np.log(halos_mean["richness"])
    
    xs = halos_mean["redshift_true"]
    ys = np.log(halos_mean["m200c"])
    zs = lnR_mean_model
    
    p1 =ax1.scatter(xs, ys, zs, c=zs, cmap='cool')
    ax1.set_xlabel('z')
    ax1.set_ylabel('lnM')
    fig.colorbar(p1, ax=ax1, label='<$Ln\lambda$| M, z>')

    ax2.scatter(ys, lnR_mean, c='k', s=2.0, label='$\ln \lambda_i$ médio')
    p2 = ax2.scatter(ys, zs , c= xs, s=2.0, cmap='cool')
    ax2.set_xlabel('lnM')
    ax2.set_ylabel('<$\ln\lambda$| M, z>')
    fig.colorbar(p2, ax=ax2, label='z')
    ax2.legend()

    ax3.scatter(xs, lnR_mean, c='k', s=2.0, label='$\ln \lambda_i$ médio')
    p3 = ax3.scatter(xs, zs , c=ys, s=2.0, cmap='cool') 
    ax3.set_xlabel('z')
    ax3.set_ylabel('<$\ln\lambda$| M, z>')
    fig.colorbar(p3, ax=ax3, label='lnM')
    ax3.legend()

    
    if f'{lnR_mean_model}' == f'{lnR_mean_ascaso}': 
        fig.suptitle('Modelo de Ascaso')
    elif f'{lnR_mean_model}' == f'{lnR_mean_ext_ln1pz}': 
        fig.suptitle('Modelo Estendido (ln(1 + z))')
    elif f'{lnR_mean_model}' == f'{lnR_mean_ext_z}': 
        fig.suptitle('Modelo Estendido (z)')
    else: 
        pass
        
    plt.show()

# %%
#Plot_model(lnR_mean_ascaso, data_train) #Ascaso
Plot_model(lnR_mean_ext_ln1pz, data_train) #Extended (ln(1 + z)) 
#Plot_model(lnR_mean_ext_z, data_train)

plt.show()

# %%
def Plot_model_std(lnR_std_model, data_set):

    fig = plt.figure(figsize=(6,8))
    gs = gridspec.GridSpec(nrows=2, ncols=2, width_ratios=[1, 1], height_ratios=[2.5, 1], wspace=0.4)
   
    ax1 = fig.add_subplot(gs[0, :], projection='3d')
    ax2 = fig.add_subplot(gs[1, 0])
    ax3 = fig.add_subplot(gs[1, 1])

    #lnR model, z_mean, y_mean
    halos_mean = bin_meanf(data_set)[0]
    std_mean = bin_meanf(data_set)[4]
    
    xs = halos_mean["redshift_true"]
    ys = np.log(halos_mean["m200c"])
    zs = lnR_std_model
    
    p1 =ax1.scatter(xs, ys, zs, c=zs, cmap='cool')
    ax1.set_xlabel('z')
    ax1.set_ylabel('lnM')
    fig.colorbar(p1, ax=ax1, label='$\sigma_{\ln \lambda}$')

    ax2.scatter(ys, std_mean, c='k',s=2.0, label='$\sigma^{i}$')
    p2 = ax2.scatter(ys, zs , c= xs,s=2.0, cmap='cool')
    ax2.set_xlabel('lnM')
    ax2.set_ylabel('$\sigma_{\ln \lambda}$')
    fig.colorbar(p2, ax=ax2, label='z')
    ax2.set_yscale('log')
    ax2.legend()

    ax3.scatter(xs, std_mean, c='k',s=2.0, label='$\sigma^{i}$')
    p3 = ax3.scatter(xs, zs , c=ys,s=2.0, cmap='cool') 
    ax3.set_xlabel('z')
    ax3.set_ylabel('$\sigma_{\ln \lambda}$')
    fig.colorbar(p3, ax=ax3, label='lnM')
    ax3.legend()

    
    if f'{lnR_std_model}' == f'{lnR_std_ascaso}': 
        fig.suptitle('Modelo de Ascaso', size=16)
    elif f'{lnR_std_model}' == f'{lnR_std_ext_ln1pz}': 
        fig.suptitle('Modelo Estendido (ln(1 + z))', size=16)
    elif f'{lnR_std_model}' == f'{lnR_std_ext_z}': 
        fig.suptitle('Modelo Estendido (z)', size=16)
    else: 
        pass
        
    plt.show()

# %%
Plot_model_std(lnR_std_ascaso, data_train) #Ascaso
Plot_model_std(lnR_std_ext_ln1pz, data_train) #Extended (ln(1 + z)) 
Plot_model_std(lnR_std_ext_z, data_train)

plt.show()

# %% [markdown]
# ## Cross Validation
#
# - Relative error:
#
# \begin{equation}
# Rel\_err = \frac{\left<\ln R_i | M_i, z_i \right> - {\mu^{i}}_{lnR}}{{\mu^{i}}_{lnR}}
# \end{equation}
#
# - Mean Square Error (MSE):
#
# \begin{equation}
# MSE = \frac{1}{N} \sum^{N} ({\mu^{i}}_{lnR} - \left<\ln R_i | M_i, z_i \right> )^2
# \end{equation}
#
# - Root Mean Square Error (RMSE):
#
# \begin{equation}
# RMSE = \sqrt{MSE}
# \end{equation}

# %%
bin_f= bin_meanf(data_test)

# %%
# MEAN 
halos_mean = bin_f[0]

lnR_test = np.log(halos_mean["richness"])
lnM_test = np.log(halos_mean["m200c"])
z_test = halos_mean["redshift_true"]

ascaso_mean_valid = np.array( [ascaso.get_mean_richness(lnM_test[i], z_test[i]) for i in range(len(lnR_test))])
ext_ln1pz_mean_valid = np.array([ext_ln1pz.get_mean_richness(lnM_test[i], z_test[i]) for i in range(len(lnR_test))])

#Relative Error: mean
plt.scatter(ascaso_mean_valid, (ascaso_mean_valid - lnR_test)/ lnR_test, c='#a0d995', alpha=0.7, label='Ascaso')
plt.scatter(ext_ln1pz_mean_valid, (ext_ln1pz_mean_valid - lnR_test)/ lnR_test, c='#b186f1', alpha=0.7, label='Modelo Estendido (ln(1 + z))')
plt.xlabel('Predição', size=14)
plt.ylabel('Erro Relativo', size=14)
# plt.yscale('log')
plt.axhline(y=0.0, color='black', linestyle='dotted')

plt.title('Erro relativo da média', size=14)
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(10,3))
ax1=plt.subplot(121)
ax2=plt.subplot(122)

Rel_as = (ascaso_mean_valid - lnR_test) / lnR_test
Rel_ex = (ext_ln1pz_mean_valid - lnR_test) / lnR_test

ax1.hist(Rel_as, bins=70, color='#a0d995')
ax1.set_title('Ascaso')

ax2.hist(Rel_ex, bins=70, color='#b186f1')
ax2.set_title('Modelo Estendido (ln(1 + z))')

plt.show()


print(stats.kstest(Rel_as, stats.norm.cdf, args=(np.mean(Rel_as), np.std(Rel_as))).pvalue)
print(stats.kstest(Rel_ex, stats.norm.cdf, args=(np.mean(Rel_ex), np.std(Rel_ex))).pvalue)
# Out:
# 0.6747573860071331
# 0.2759913694433567

# %%
MSE_ascaso = sum((lnR_test - ascaso_mean_valid) ** 2) / len(ascaso_mean_valid)
RMSE_ascaso = np.sqrt(MSE_ascaso)

MSE_ext_ln1pz = sum((lnR_test - ext_ln1pz_mean_valid) ** 2) / len(ext_ln1pz_mean_valid)
RMSE_ext_ln1pz = np.sqrt(MSE_ext_ln1pz )

print(MSE_ascaso, RMSE_ascaso)
print(MSE_ext_ln1pz, RMSE_ext_ln1pz)
# Out:
# 0.19571331824657642 0.4423949799066174
# 0.22712126402976007 0.476572412157649

# %%
from sklearn.metrics import mean_absolute_percentage_error

print(mean_absolute_percentage_error(lnR_test, ascaso_mean_valid) * 100) 
print(mean_absolute_percentage_error(lnR_test, ext_ln1pz_mean_valid) * 100)
# Out:
# 13.405138289330583
# 13.794207634621088

# %%
bin_f= bin_meanf(data_test)
lnR_test_std = bin_f[4]

ascaso_std_valid = np.array([ascaso.get_std_richness(lnM_test[i], z_test[i]) for i in range(len(lnR_test_std))])
ext_ln1pz_std_valid = np.array([ext_ln1pz.get_std_richness(lnM_test[i], z_test[i]) for i in range(len(lnR_test_std))])

# %%
MSE_ascaso_std = sum((lnR_test_std - ascaso_std_valid) ** 2) / len(ascaso_std_valid)
RMSE_ascaso_std = np.sqrt(MSE_ascaso_std)

MSE_ext_ln1pz_std = sum((lnR_test_std - ext_ln1pz_std_valid) ** 2) / len(ext_ln1pz_std_valid)
RMSE_ext_ln1pz_std = np.sqrt(MSE_ext_ln1pz_std )

print(f"Std Erros\n\nAscaso: \tMSE: {MSE_ascaso_std: .3f},\t RMSE:{RMSE_ascaso_std: .3f}")
print(f"Extended:\tMSE: {MSE_ext_ln1pz_std: .3f},\t RMSE:{RMSE_ext_ln1pz_std: .3f}\n")
# Out:
# Std Erros
#
# Ascaso: 	MSE:  0.073,	 RMSE: 0.270
# Extended:	MSE:  0.066,	 RMSE: 0.256

# %%
# STD 
#Relative Error: std
a_err = (ascaso_std_valid - lnR_test_std)/ lnR_test_std
e_err = (ext_ln1pz_std_valid - lnR_test_std)/ lnR_test_std

# #CUT 1
# cut =np.abs(a_err) < 1000
# a_err = a_err[cut]
# ascaso_std_valid2 = ascaso_std_valid[cut]
# lnR_test_std1 = lnR_test_std[cut]

# #CUT 2
# cut2 = np.abs(e_err) < 1000
# lnR_test_std2 = lnR_test_std[cut2]
# e_err = e_err[cut2]
# ext_ln1pz_std_valid2 = ext_ln1pz_std_valid[cut2]

#Plot
plt.scatter(ascaso_std_valid, a_err, c='#a0d995', alpha=0.7, label='Ascaso')
plt.scatter(ext_ln1pz_std_valid, e_err, c='#b186f1', alpha=0.7, label='Modelo Estendido (ln(1 + z))')

plt.xlabel('Predição', size=14)
plt.ylabel('Erro Relativo', size=14)
plt.axhline(y=0.0, color='black', linestyle='dotted')
#plt.title('Erro relativo do desvio padrão (< 10)', size=16)
plt.yscale('log')
plt.legend()
plt.show()

# print(f"MAPE:STD\n\nMAPE (Ascaso): {mean_absolute_percentage_error(lnR_test_std1, ascaso_std_valid2) * 100: .2f}%") 
# print(f"MAPE (Extended): {mean_absolute_percentage_error(lnR_test_std2, ext_ln1pz_std_valid2) * 100: .2f}%")
# Out:
# /tmp/ipykernel_558640/1138155046.py:3: RuntimeWarning: divide by zero encountered in divide
#   a_err = (ascaso_std_valid - lnR_test_std)/ lnR_test_std
# /tmp/ipykernel_558640/1138155046.py:4: RuntimeWarning: divide by zero encountered in divide
#   e_err = (ext_ln1pz_std_valid - lnR_test_std)/ lnR_test_std

# %%
lnR_test_std = bin_f[4]
ascaso_std_valid = np.array([ascaso.get_std_richness(lnM_test[i], z_test[i]) for i in range(len(lnR_test_std))])
ext_ln1pz_std_valid = np.array([ext_ln1pz.get_std_richness(lnM_test[i], z_test[i]) for i in range(len(lnR_test_std))])

a_err = (ascaso_std_valid - lnR_test_std)/ lnR_test_std
e_err = (ext_ln1pz_std_valid - lnR_test_std)/ lnR_test_std

cut =np.abs(a_err) < 300.0
a_err = a_err[cut]
ascaso_std_valid = ascaso_std_valid[cut]
lnR_test_std = lnR_test_std[cut]

MSE_ascaso_std = sum((ascaso_std_valid - lnR_test_std) ** 2) / len(ascaso_std_valid)
RMSE_ascaso_std = np.sqrt(MSE_ascaso_std)

lnR_test_std = bin_f[4]
cut2 = np.abs(e_err) < 300.0
e_err = e_err[cut2]
ext_ln1pz_std_valid = ext_ln1pz_std_valid[cut2]
lnR_test_std = lnR_test_std[cut2]

MSE_ext_ln1pz_std = sum((ext_ln1pz_std_valid - lnR_test_std) ** 2) / len(ext_ln1pz_std_valid)
RMSE_ext_ln1pz_std = np.sqrt(MSE_ext_ln1pz_std )

print(MSE_ascaso_std, RMSE_ascaso_std)
print(MSE_ext_ln1pz_std, RMSE_ext_ln1pz_std)
# Out:
# 0.04875356010152171 0.2208020835533979
# 0.04847321207360765 0.22016632820122076
# /tmp/ipykernel_558640/3820996510.py:5: RuntimeWarning: divide by zero encountered in divide
#   a_err = (ascaso_std_valid - lnR_test_std)/ lnR_test_std
# /tmp/ipykernel_558640/3820996510.py:6: RuntimeWarning: divide by zero encountered in divide
#   e_err = (ext_ln1pz_std_valid - lnR_test_std)/ lnR_test_std

# %%
bin_f= bin_meanf(data_test)
lnR_test_std = bin_f[4]

ascaso_std_valid = np.array([ascaso.get_std_richness(lnM_test[i], z_test[i]) for i in range(len(lnR_test_std))])
ext_ln1pz_std_valid = np.array([ext_ln1pz.get_std_richness(lnM_test[i], z_test[i]) for i in range(len(lnR_test_std))])
